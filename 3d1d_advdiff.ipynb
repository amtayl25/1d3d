# %% [markdown]
# <a href="https://colab.research.google.com/github/amtayl25/1d3d/blob/main/3d1d_advdiff.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Install required libraries (try-catch safe)
"""
NOTE: You can save the Docker image state after running this block so that you don't have to run it every time you start a new environment.
"""
import os, re

def replace_in_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()

    # Replace 'ufl' with 'ufl_legacy'
    content = re.sub(r'\bufl\b', 'ufl_legacy', content)

    with open(file_path, 'w', encoding='utf-8') as file:
        file.write(content)

def process_directory(directory):
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith('.py'):
                file_path = os.path.join(root, file)
                replace_in_file(file_path)

# ipywidgets
try:
    import ipywidgets
except ImportError:
    # !pip install ipywidgets

# dolfin
try:
    import dolfin
except ImportError:
    # !wget "https://fem-on-colab.github.io/releases/fenics-install-release-real.sh" -O "/tmp/fenics-install.sh" && bash "/tmp/fenics-install.sh"
    import dolfin

# block
try:
    import block
except ImportError:
    # !git clone "https://bitbucket.org/fenics-apps/cbc.block/src/master/"
    # !pip install master/

# fenics_ii
try:
    import xii
except ImportError:
    # !git clone "https://github.com/MiroK/fenics_ii"
    process_directory("fenics_ii/")
    # !pip install fenics_ii/

# vtk
try:
    import vtk
except ImportError:
    # !pip install vtk

# graphnics
try:
    import graphnics
except ImportError:
    # !git clone "https://github.com/IngeborgGjerde/graphnics"
    # !pip install graphnics/

# meshio
try:
    import meshio
except ImportError:
    # !pip install meshio

# pyvista
try:
    import pyvista
except ImportError:
    # !pip install pyvista

# %%
# @title Convergence test: 3D-FEM,1D-dG time-dependent advection-diffusion

from math import gamma
from argparse import RawDescriptionHelpFormatter
from petsc4py import PETSc
from ast import Constant
from dolfin import *
from xii import *
import numpy as np
import time

# @title Testing

conv_study3d = open("conv_study3d.txt", "w")
conv_study1d = open("conv_study1d.txt", "w")

H1_error_3d   = np.ones(6)
H1_rates_3d   = np.ones(6)
L2_error_3d   = np.ones(6)
L2_rates_3d   = np.ones(6)
err_interface     = np.ones(6)
rates_interface   = np.ones(6)
h_out             = np.ones(6)

H1_error_1d = np.ones(6)
H1_rates_1d = np.ones(6)
L2_error_1d = np.ones(6)
L2_rates_1d = np.ones(6)

kappa     = 1.0
gamma_in  = 1.0
gamma_out = 1.0

mesh_vec = [0,1,2,3,4]

T    = 1.0

for i in mesh_vec:
  ncell   = 4*(2**i)
  mesh_3d = BoxMesh(Point(-0.5,-0.5,-0.5),Point(0.5,0.5,0.5),ncell,ncell,ncell)
  radius  = 0.05
  dt      = 0.1#/ncell
  inv_dt  = Constant(1.0/dt)
  tpts    = int(T/dt)

  # === Perimeter and Area ===
  D_perimeter = 2*np.pi*radius
  D_area = np.pi*(radius**2)

  # === Create Meshes ===
  Omega = MeshFunction("size_t",mesh_3d,1,0)
  CompiledSubDomain("near(x[0],0.0) && near(x[1],0.0)").mark(Omega,1)
  Lambda = EmbeddedMesh(Omega,1)
  Lambda_boundaries = MeshFunction("size_t", Lambda, Lambda.topology().dim() - 1, 0)
  CompiledSubDomain("near(x[2], -0.5)").mark(Lambda_boundaries, 1)
  CompiledSubDomain("near(x[2],  0.5)").mark(Lambda_boundaries, 2)

  # === Function Spaces ===
  V3 = FunctionSpace(mesh_3d, "CG", 1)
  V1 = FunctionSpace(Lambda, "DG", 1)
  W = [V3, V1]
  u3, u1 = map(TrialFunction, W)
  v3, v1 = map(TestFunction, W)

  # === Velocity terms ===
  q1 = Constant(1.0)
  q3 = as_vector((0,0,q1))

  # === Initial concentration ===
  cinlet = Expression("(sin(pi*x[2])+2)*t", degree=4, t=0.0)#Constant(1.0)


  # === Mesh Measures ===
  dxOmega = Measure("dx", domain=mesh_3d)
  dxLambda = Measure("dx", domain=Lambda)
  dsLambda = Measure("ds", domain=Lambda, subdomain_data=Lambda_boundaries)
  dSLambda = Measure("dS", domain=Lambda)
  n = FacetNormal(Lambda)
  h = CellDiameter(Lambda)
  alpha = Constant(50.0)
  epsilon = Constant(-1.0)
  perf1 = 1.0
  perf3 = 1.0

  # === Upwind ===
  u1_up = conditional(ge(q1, 0.0), u1('-'), u1('+'))  # upstream trace


  # === Cylinder ===
  cylinder = Circle(radius=radius, degree=20)

  # === Averages ===
  u3_avg = Average(u3, Lambda, cylinder)
  v3_avg = Average(v3, Lambda, cylinder)

  # === Initialize time step ===
  uh3d_prev = interpolate(Expression('0.0',degree=1), V3)
  uh1d_prev = interpolate(Expression('0.0',degree=1), V1)

  r = Expression('sqrt(pow(x[0] - 0.0, 2)+ pow(x[1] - 0.0,2))', degree  = 7)

  # === Begin time-stepping ===
  t = 0.0
  for step in range(tpts):
    t += dt
    print(f"[INFO] Time step {step+1}/{tpts}, t = {t:.3}")

    cinlet.t = t

    # === Exact solutions ===
    u3_exact_expr = Expression('(r > radius ? (kappa/(1+kappa))*(1-radius*std::log(r/radius))*((sin(pi*x[2])+2)*t) : (kappa/(1+kappa))*((sin(pi*x[2])+2)*t))',
                              degree = 7,
                              radius = radius,
                              kappa = kappa ,
                              r = r,
                              t = t)
    u3_exact = interpolate(u3_exact_expr, V3)

    u1_exact_expr = Expression('(sin(pi*x[2])+2)*t', degree = 7, t=t)
    u1_exact = interpolate(u1_exact_expr, V1)
    u1_inlet_expr    = Expression('(sin(pi*x[2])+2)*t', degree=7, t=t)  # right now same as u1_exact but can be changed in future for diff circumstance
    du1ds_exact_expr = Expression('pi*t*cos(pi*x[2])', degree=7, t=t)

    theta0 = Expression('area*(du - q*(u - uin))',
                    degree=7, area=D_area, q=q1,
                    du=du1ds_exact_expr, u=u1_exact_expr, uin=u1_inlet_expr)

    thetaN = Expression('area*du', degree=7, area=D_area, du=du1ds_exact_expr)

    vtkfile = File('u3_exact.pvd')
    vtkfile << u3_exact
    vtkfile = File('u1_exact.pvd')
    vtkfile << u1_exact

    # === Forcing terms ===
    f3 = Expression('(r > radius ? '
                    '((kappa/(1+kappa))*(1-radius*std::log(r/radius))*(sin(pi*x[2])+2) '             # time derivative
                    '+ (kappa/(1+kappa))*(1-radius*std::log(r/radius))*pow(pi,2)*t*sin(pi*x[2]) '    # diffusion
                    '+ (kappa/(1+kappa))*(1-radius*std::log(r/radius))*pi*t*q*cos(pi*x[2]) )'        # advection
                    ': ((kappa/(1+kappa))*pow(pi,2)*t*sin(pi*x[2]) '            # diffusion
                    '+ (kappa/(1+kappa))*(sin(pi*x[2])+2) '                     # time derivative
                    '+ (kappa/(1+kappa))*pi*t*q*cos(pi*x[2]) ) )',                  # advection
                    degree = 4,
                    kappa = kappa,
                    radius = radius,
                    area = D_area,
                    r = r,
                    t = t,
                    q = q1)

    f1 = Expression(
        'area * (sin(pi*x[2])+2)'                             # time derivative
        ' + area * pow(pi,2) * t * sin(pi*x[2])'               # diffusion
        ' + (kappa / (1 + kappa)) * perimeter * t * (sin(pi*x[2]) + 2)'  # coupling
        ' + area * pi * t * q * cos(pi*x[2])',                # advection
        degree=4,
        area=D_area,
        perimeter=D_perimeter,
        kappa=kappa,
        t=t,
        q=q1
    )

    # === Variational Forms ===
    a00 = inv_dt * (inner(u3, v3) * dxOmega) + inner(grad(u3), grad(v3)) * dxOmega \
          + D_perimeter * kappa * inner(u3_avg, v3_avg) * dxLambda - inner(q3, grad(v3)) * u3 * dxOmega
    a01 = -kappa * D_perimeter * inner(u1, v3_avg) * dxLambda
    a10 = -kappa * D_perimeter * inner(u3_avg, v1) * dxLambda
    a11 = D_area * inv_dt * u1 * v1 * dxLambda \
        + D_area * inner(grad(u1), grad(v1)) * dxLambda \
        - D_area * inner(avg(grad(u1)), jump(v1, n)) * dSLambda \
        - D_area * inner(avg(grad(v1)), jump(u1, n)) * dSLambda \
        + (alpha/avg(h)) * jump(u1) * jump(v1) * dSLambda \
        + kappa * D_perimeter * u1 * v1 * dxLambda \
        - D_area * q1 * u1 * v1.dx(2) * dxLambda \
        + D_area*q1*u1_up*jump(v1)*dSLambda + D_area * q1 * u1 * v1 * dsLambda(2)


    L0 = inner(f3, v3) * dxOmega + inv_dt * (inner(uh3d_prev, v3) * dxOmega)
    L1 = inner(f1, v1) * dxLambda \
        + D_area * inv_dt * uh1d_prev * v1 * dxLambda \
        + D_area * q1 * cinlet * v1 * dsLambda(1)  \
        - theta0*v1*dsLambda(1) + thetaN*v1*dsLambda(2)


    a = [[a00, a01], [a10, a11]]
    L = [L0, L1]

    bc3d = DirichletBC(V3, u3_exact, "on_boundary")
    W_bcs = [bc3d, []]  # No Dirichlet BCs on 1D

    A, b = map(ii_assemble, (a, L))
    A, b = apply_bc(A, b, W_bcs)
    A, b = map(ii_convert, (A, b))

    solver = PETScKrylovSolver()
    solver.set_operators(A, A)
    ksp = solver.ksp()

    opts = PETSc.Options()
    opts.setValue('ksp_type', 'gmres')
    opts.setValue('ksp_norm_type', 'unpreconditioned')
    opts.setValue('ksp_atol', 1E-14)
    opts.setValue('ksp_rtol', 1E-30)
    opts.setValue('ksp_monitor_true_residual', None)
    opts.setValue('pc_type', 'hypre')
    ksp.setFromOptions()

    x = b.copy()
    solver.solve(A,x,b)

    wh = ii_Function(W)
    wh.vector()[:] = x
    uh3d, uh1d = wh

    uh3d_prev.assign(uh3d)
    uh1d_prev.assign(uh1d)

    avg_uh3d = Average(uh3d, Lambda, cylinder)
    avg_u3d_exact = Average(u3_exact, Lambda, cylinder)

    # === Store Model Predictions ===
    vtkfile = File('3d_Prediction.pvd')
    vtkfile << uh3d

    vtkfile = File('1d_Prediction.pvd')
    vtkfile << uh1d


  # === Computer Errors ===
  h_out[i] =uh3d.function_space().mesh().hmax()
  H1_error_3d[i] = errornorm(u3_exact_expr, uh3d, 'H1')
  L2_error_3d[i] = errornorm(u3_exact_expr, uh3d, 'L2')
  err_interface[i] = 1.0
  H1_rates_3d[i] = ln(H1_error_3d[i]/H1_error_3d[i-1])/ln(h_out[i]/h_out[i-1])
  L2_rates_3d[i] = ln(L2_error_3d[i]/L2_error_3d[i-1])/ln(h_out[i]/h_out[i-1])
  rates_interface[i] = ln(err_interface[i]/err_interface[i-1])/ln(h_out[i]/h_out[i-1])

  H1_error_1d[i] = errornorm(u1_exact_expr, uh1d, 'H1')
  L2_error_1d[i] = errornorm(u1_exact_expr, uh1d, 'L2')
  H1_rates_1d[i] = ln(H1_error_1d[i]/H1_error_1d[i-1])/ln(h_out[i]/h_out[i-1])
  L2_rates_1d[i] = ln(L2_error_1d[i]/L2_error_1d[i-1])/ln(h_out[i]/h_out[i-1])

  print(i,"{:.3e}".format(h_out[i]),"{:.3e}".format(H1_error_3d[i]), "{:.3e}".format(H1_rates_3d[i]), "{:.3e}".format(err_interface[i]),"{:.3e}".format(rates_interface[i]), "{:.3e}".format(L2_error_3d[i]),"{:.3e}".format(L2_rates_3d[i]),  file= conv_study3d,flush = True)
  print(i,"{:.3e}".format(ncell),"{:.3e}".format(H1_error_1d[i]), "{:.3e}".format(H1_rates_1d[i]), "{:.3e}".format(L2_error_1d[i]),"{:.3e}".format(L2_rates_1d[i]),  file= conv_study1d,flush = True)
# Out:
# [INFO] Time step 1/10, t = 0.1
# Averaging over 4 cells: 100%|██████████| 4/4 [00:00<00:00, 357.43it/s]
#   0 KSP unpreconditioned resid norm 1.005605394005e+00 true resid norm 1.005605394005e+00 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 3.292179726944e-04 true resid norm 3.292179726902e-04 ||r(i)||/||b|| 3.273828627538e-04
#   2 KSP unpreconditioned resid norm 1.363379425031e-06 true resid norm 1.363379423433e-06 ||r(i)||/||b|| 1.355779743784e-06
#   3 KSP unpreconditioned resid norm 3.790447539773e-10 true resid norm 3.790457514908e-10 ||r(i)||/||b|| 3.769328941057e-10
#   4 KSP unpreconditioned resid norm 8.306159822007e-14 true resid norm 8.130084639104e-14 ||r(i)||/||b|| 8.084766338336e-14
#   5 KSP unpreconditioned resid norm 3.249897033146e-16 true resid norm 1.442626344164e-14 ||r(i)||/||b|| 1.434584930395e-14
# [INFO] Time step 2/10, t = 0.2
#   0 KSP unpreconditioned resid norm 2.010464787039e+00 true resid norm 2.010464787039e+00 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 6.592239883693e-04 true resid norm 6.592239883596e-04 ||r(i)||/||b|| 3.278963116436e-04
#   2 KSP unpreconditioned resid norm 2.722092772020e-06 true resid norm 2.722092771222e-06 ||r(i)||/||b|| 1.353961924014e-06
#   3 KSP unpreconditioned resid norm 7.609638394307e-10 true resid norm 7.609537936792e-10 ||r(i)||/||b|| 3.784964544441e-10
#   4 KSP unpreconditioned resid norm 1.655247067969e-13 true resid norm 1.675180331248e-13 ||r(i)||/||b|| 8.332303764021e-14
#   5 KSP unpreconditioned resid norm 4.958981782976e-16 true resid norm 1.343130003455e-14 ||r(i)||/||b|| 6.680693997294e-15
# [INFO] Time step 3/10, t = 0.3
#   0 KSP unpreconditioned resid norm 3.016166752927e+00 true resid norm 3.016166752927e+00 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 9.898152073582e-04 true resid norm 9.898152073691e-04 ||r(i)||/||b|| 3.281699217752e-04
#   2 KSP unpreconditioned resid norm 4.087545220126e-06 true resid norm 4.087545232294e-06 ||r(i)||/||b|| 1.355211951835e-06
#   3 KSP unpreconditioned resid norm 1.144017013051e-09 true resid norm 1.144032103477e-09 ||r(i)||/||b|| 3.793000179339e-10
#   4 KSP unpreconditioned resid norm 2.489809267578e-13 true resid norm 2.207925221885e-13 ||r(i)||/||b|| 7.320302233762e-14
#   5 KSP unpreconditioned resid norm 4.004759580484e-16 true resid norm 2.859048672612e-14 ||r(i)||/||b|| 9.479080259197e-15
# [INFO] Time step 4/10, t = 0.4
#   0 KSP unpreconditioned resid norm 4.022933363065e+00 true resid norm 4.022933363065e+00 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 1.321244281494e-03 true resid norm 1.321244281490e-03 ||r(i)||/||b|| 3.284280802710e-04
#   2 KSP unpreconditioned resid norm 5.462156461110e-06 true resid norm 5.462156464059e-06 ||r(i)||/||b|| 1.357754645953e-06
#   3 KSP unpreconditioned resid norm 1.527962434762e-09 true resid norm 1.527989991312e-09 ||r(i)||/||b|| 3.798198611344e-10
#   4 KSP unpreconditioned resid norm 3.336810642923e-13 true resid norm 3.611586749523e-13 ||r(i)||/||b|| 8.977495830982e-14
#   5 KSP unpreconditioned resid norm 3.809614174073e-17 true resid norm 8.116311909500e-14 ||r(i)||/||b|| 2.017510899886e-14
# [INFO] Time step 5/10, t = 0.5
#   0 KSP unpreconditioned resid norm 5.030816484868e+00 true resid norm 5.030816484868e+00 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 1.653622225428e-03 true resid norm 1.653622225405e-03 ||r(i)||/||b|| 3.286985781293e-04
#   2 KSP unpreconditioned resid norm 6.846453027001e-06 true resid norm 6.846453018002e-06 ||r(i)||/||b|| 1.360902954539e-06
#   3 KSP unpreconditioned resid norm 1.912821582840e-09 true resid norm 1.912895024413e-09 ||r(i)||/||b|| 3.802355005727e-10
#   4 KSP unpreconditioned resid norm 4.196665502449e-13 true resid norm 4.403573772370e-13 ||r(i)||/||b|| 8.753198979957e-14
#   5 KSP unpreconditioned resid norm 5.754731493462e-16 true resid norm 8.630593106586e-14 ||r(i)||/||b|| 1.715545206736e-14
# [INFO] Time step 6/10, t = 0.6
#   0 KSP unpreconditioned resid norm 6.039840174681e+00 true resid norm 6.039840174681e+00 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 1.986983905738e-03 true resid norm 1.986983905745e-03 ||r(i)||/||b|| 3.289795504978e-04
#   2 KSP unpreconditioned resid norm 8.240547088194e-06 true resid norm 8.240547088992e-06 ||r(i)||/||b|| 1.364365090907e-06
#   3 KSP unpreconditioned resid norm 2.298618336732e-09 true resid norm 2.298556032760e-09 ||r(i)||/||b|| 3.805657047673e-10
#   4 KSP unpreconditioned resid norm 5.069432177406e-13 true resid norm 5.142108198612e-13 ||r(i)||/||b|| 8.513649450804e-14
#   5 KSP unpreconditioned resid norm 9.079523509990e-16 true resid norm 8.610073334094e-14 ||r(i)||/||b|| 1.425546551743e-14
# [INFO] Time step 7/10, t = 0.7
#   0 KSP unpreconditioned resid norm 7.050023286945e+00 true resid norm 7.050023286945e+00 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 2.321339220731e-03 true resid norm 2.321339220674e-03 ||r(i)||/||b|| 3.292668869580e-04
#   2 KSP unpreconditioned resid norm 9.644457976073e-06 true resid norm 9.644457988212e-06 ||r(i)||/||b|| 1.368003706608e-06
#   3 KSP unpreconditioned resid norm 2.685363128539e-09 true resid norm 2.685359913519e-09 ||r(i)||/||b|| 3.809008572342e-10
#   4 KSP unpreconditioned resid norm 5.955141495455e-13 true resid norm 5.641862682693e-13 ||r(i)||/||b|| 8.002615669569e-14
#   5 KSP unpreconditioned resid norm 2.076829679033e-15 true resid norm 8.752737837058e-14 ||r(i)||/||b|| 1.241518996578e-14
# [INFO] Time step 8/10, t = 0.8
#   0 KSP unpreconditioned resid norm 8.061383635634e+00 true resid norm 8.061383635634e+00 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 2.656691027427e-03 true resid norm 2.656691027444e-03 ||r(i)||/||b|| 3.295576972296e-04
#   2 KSP unpreconditioned resid norm 1.105818391865e-05 true resid norm 1.105818391183e-05 ||r(i)||/||b|| 1.371747631876e-06
#   3 KSP unpreconditioned resid norm 3.073060532202e-09 true resid norm 3.073010048396e-09 ||r(i)||/||b|| 3.812013157161e-10
#   4 KSP unpreconditioned resid norm 6.853725436474e-13 true resid norm 7.140057461003e-13 ||r(i)||/||b|| 8.857111612256e-14
#   5 KSP unpreconditioned resid norm 1.784643160412e-15 true resid norm 1.361580566035e-13 ||r(i)||/||b|| 1.689015964972e-14
# [INFO] Time step 9/10, t = 0.9
#   0 KSP unpreconditioned resid norm 9.073938808954e+00 true resid norm 9.073938808954e+00 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 2.993040330745e-03 true resid norm 2.993040330696e-03 ||r(i)||/||b|| 3.298501779341e-04
#   2 KSP unpreconditioned resid norm 1.248171830083e-05 true resid norm 1.248171827791e-05 ||r(i)||/||b|| 1.375556805121e-06
#   3 KSP unpreconditioned resid norm 3.461713272782e-09 true resid norm 3.461723151031e-09 ||r(i)||/||b|| 3.815017076835e-10
#   4 KSP unpreconditioned resid norm 7.765218678323e-13 true resid norm 8.896114741324e-13 ||r(i)||/||b|| 9.804027698033e-14
#   5 KSP unpreconditioned resid norm 1.192664275545e-15 true resid norm 1.988564240438e-13 ||r(i)||/||b|| 2.191511627206e-14
# [INFO] Time step 10/10, t = 1.0
#   0 KSP unpreconditioned resid norm 1.008770632866e+01 true resid norm 1.008770632866e+01 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 3.330387664385e-03 true resid norm 3.330387664372e-03 ||r(i)||/||b|| 3.301432016225e-04
#   2 KSP unpreconditioned resid norm 1.391505339685e-05 true resid norm 1.391505340347e-05 ||r(i)||/||b|| 1.379407067386e-06
#   3 KSP unpreconditioned resid norm 3.851323563188e-09 true resid norm 3.851329736707e-09 ||r(i)||/||b|| 3.817844821438e-10
#   4 KSP unpreconditioned resid norm 8.689633318229e-13 true resid norm 7.906771970318e-13 ||r(i)||/||b|| 7.838027508643e-14
#   5 KSP unpreconditioned resid norm 1.454031875460e-15 true resid norm 2.077034226486e-13 ||r(i)||/||b|| 2.058975706484e-14
# [INFO] Time step 1/10, t = 0.1
# Averaging over 8 cells: 100%|██████████| 8/8 [00:00<00:00, 256.64it/s]
#   0 KSP unpreconditioned resid norm 1.903748119154e+00 true resid norm 1.903748119154e+00 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 2.100741078502e-03 true resid norm 2.100741078502e-03 ||r(i)||/||b|| 1.103476377660e-03
#   2 KSP unpreconditioned resid norm 9.322446408302e-06 true resid norm 9.322446409617e-06 ||r(i)||/||b|| 4.896890673625e-06
#   3 KSP unpreconditioned resid norm 2.489584992778e-08 true resid norm 2.489586798060e-08 ||r(i)||/||b|| 1.307729091371e-08
#   4 KSP unpreconditioned resid norm 2.108296019469e-10 true resid norm 2.108404719623e-10 ||r(i)||/||b|| 1.107501931800e-10
#   5 KSP unpreconditioned resid norm 5.436057279237e-13 true resid norm 5.535614855974e-13 ||r(i)||/||b|| 2.907745410372e-13
#   6 KSP unpreconditioned resid norm 1.494319409302e-15 true resid norm 4.389073346968e-14 ||r(i)||/||b|| 2.305490575570e-14
# [INFO] Time step 2/10, t = 0.2
#   0 KSP unpreconditioned resid norm 3.807284709187e+00 true resid norm 3.807284709187e+00 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 4.196430950852e-03 true resid norm 4.196430950843e-03 ||r(i)||/||b|| 1.102210964343e-03
#   2 KSP unpreconditioned resid norm 1.860029583526e-05 true resid norm 1.860029583587e-05 ||r(i)||/||b|| 4.885449147260e-06
#   3 KSP unpreconditioned resid norm 4.996230610420e-08 true resid norm 4.996228478739e-08 ||r(i)||/||b|| 1.312281287156e-08
#   4 KSP unpreconditioned resid norm 4.237706833772e-10 true resid norm 4.237237841261e-10 ||r(i)||/||b|| 1.112929072795e-10
#   5 KSP unpreconditioned resid norm 1.085564720827e-12 true resid norm 1.106855179379e-12 ||r(i)||/||b|| 2.907203595013e-13
#   6 KSP unpreconditioned resid norm 3.325323296321e-15 true resid norm 8.630084151723e-14 ||r(i)||/||b|| 2.266729391395e-14
# [INFO] Time step 3/10, t = 0.3
#   0 KSP unpreconditioned resid norm 5.710972678118e+00 true resid norm 5.710972678118e+00 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 6.307478280225e-03 true resid norm 6.307478280223e-03 ||r(i)||/||b|| 1.104449037970e-03
#   2 KSP unpreconditioned resid norm 2.793172568369e-05 true resid norm 2.793172567785e-05 ||r(i)||/||b|| 4.890887638961e-06
#   3 KSP unpreconditioned resid norm 7.480704105155e-08 true resid norm 7.480701263470e-08 ||r(i)||/||b|| 1.309882166331e-08
#   4 KSP unpreconditioned resid norm 6.333170842452e-10 true resid norm 6.333019596146e-10 ||r(i)||/||b|| 1.108921361227e-10
#   5 KSP unpreconditioned resid norm 1.635171393559e-12 true resid norm 1.614589696166e-12 ||r(i)||/||b|| 2.827171109315e-13
#   6 KSP unpreconditioned resid norm 4.995203216174e-15 true resid norm 1.715159175368e-13 ||r(i)||/||b|| 3.003269796649e-14
# [INFO] Time step 4/10, t = 0.4
#   0 KSP unpreconditioned resid norm 7.614845865707e+00 true resid norm 7.614845865707e+00 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 8.438295445031e-03 true resid norm 8.438295445033e-03 ||r(i)||/||b|| 1.108137392910e-03
#   2 KSP unpreconditioned resid norm 3.733109328825e-05 true resid norm 3.733109328394e-05 ||r(i)||/||b|| 4.902409574967e-06
#   3 KSP unpreconditioned resid norm 9.940794107340e-08 true resid norm 9.940790778830e-08 ||r(i)||/||b|| 1.305448718745e-08
#   4 KSP unpreconditioned resid norm 8.388189681295e-10 true resid norm 8.388257018066e-10 ||r(i)||/||b|| 1.101566225502e-10
#   5 KSP unpreconditioned resid norm 2.193695862909e-12 true resid norm 2.217756624064e-12 ||r(i)||/||b|| 2.912411706259e-13
#   6 KSP unpreconditioned resid norm 6.382110013464e-15 true resid norm 2.378394021217e-13 ||r(i)||/||b|| 3.123364626365e-14
# [INFO] Time step 5/10, t = 0.5
#   0 KSP unpreconditioned resid norm 9.518911182215e+00 true resid norm 9.518911182215e+00 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 1.058996198856e-02 true resid norm 1.058996198858e-02 ||r(i)||/||b|| 1.112518205692e-03
#   2 KSP unpreconditioned resid norm 4.680155377859e-05 true resid norm 4.680155378405e-05 ||r(i)||/||b|| 4.916691929166e-06
#   3 KSP unpreconditioned resid norm 1.237839095521e-07 true resid norm 1.237840153624e-07 ||r(i)||/||b|| 1.300400991173e-08
#   4 KSP unpreconditioned resid norm 1.040008283962e-09 true resid norm 1.040082144941e-09 ||r(i)||/||b|| 1.092648229437e-10
#   5 KSP unpreconditioned resid norm 2.761488084294e-12 true resid norm 2.821926436255e-12 ||r(i)||/||b|| 2.964547501533e-13
#   6 KSP unpreconditioned resid norm 8.054651218924e-15 true resid norm 2.725143068130e-13 ||r(i)||/||b|| 2.862872671006e-14
# [INFO] Time step 6/10, t = 0.6
#   0 KSP unpreconditioned resid norm 1.142317190769e+01 true resid norm 1.142317190769e+01 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 1.276283303211e-02 true resid norm 1.276283303210e-02 ||r(i)||/||b|| 1.117275756264e-03
#   2 KSP unpreconditioned resid norm 5.634429578176e-05 true resid norm 5.634429577851e-05 ||r(i)||/||b|| 4.932456259418e-06
#   3 KSP unpreconditioned resid norm 1.479541148923e-07 true resid norm 1.479540568078e-07 ||r(i)||/||b|| 1.295209929461e-08
#   4 KSP unpreconditioned resid norm 1.236596421492e-09 true resid norm 1.236392258807e-09 ||r(i)||/||b|| 1.082354593626e-10
#   5 KSP unpreconditioned resid norm 3.338748153465e-12 true resid norm 3.312514595572e-12 ||r(i)||/||b|| 2.899820314655e-13
#   6 KSP unpreconditioned resid norm 9.936671150827e-15 true resid norm 4.820977572190e-13 ||r(i)||/||b|| 4.220349313787e-14
# [INFO] Time step 7/10, t = 0.7
#   0 KSP unpreconditioned resid norm 1.332763067056e+01 true resid norm 1.332763067056e+01 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 1.495709800165e-02 true resid norm 1.495709800163e-02 ||r(i)||/||b|| 1.122262341398e-03
#   2 KSP unpreconditioned resid norm 6.596008507461e-05 true resid norm 6.596008507687e-05 ||r(i)||/||b|| 4.949123119278e-06
#   3 KSP unpreconditioned resid norm 1.719363120078e-07 true resid norm 1.719362361737e-07 ||r(i)||/||b|| 1.290073535377e-08
#   4 KSP unpreconditioned resid norm 1.428268202858e-09 true resid norm 1.428178130614e-09 ||r(i)||/||b|| 1.071591917511e-10
#   5 KSP unpreconditioned resid norm 3.925633844349e-12 true resid norm 3.920702043827e-12 ||r(i)||/||b|| 2.941784733342e-13
#   6 KSP unpreconditioned resid norm 1.361105959855e-14 true resid norm 2.661505007550e-13 ||r(i)||/||b|| 1.996982864650e-14
#   7 KSP unpreconditioned resid norm 6.125235897228e-15 true resid norm 3.619886880735e-13 ||r(i)||/||b|| 2.716076825816e-14
# [INFO] Time step 8/10, t = 0.8
#   0 KSP unpreconditioned resid norm 1.523228996637e+01 true resid norm 1.523228996637e+01 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 1.717290554365e-02 true resid norm 1.717290554365e-02 ||r(i)||/||b|| 1.127401433506e-03
#   2 KSP unpreconditioned resid norm 7.564958096139e-05 true resid norm 7.564958095695e-05 ||r(i)||/||b|| 4.966395802862e-06
#   3 KSP unpreconditioned resid norm 1.957478191311e-07 true resid norm 1.957477368583e-07 ||r(i)||/||b|| 1.285084102854e-08
#   4 KSP unpreconditioned resid norm 1.614696953791e-09 true resid norm 1.614787871054e-09 ||r(i)||/||b|| 1.060108410895e-10
#   5 KSP unpreconditioned resid norm 4.522247809504e-12 true resid norm 4.553684079521e-12 ||r(i)||/||b|| 2.989494087609e-13
#   6 KSP unpreconditioned resid norm 1.382446284875e-14 true resid norm 3.427688727471e-13 ||r(i)||/||b|| 2.250278017973e-14
#   7 KSP unpreconditioned resid norm 1.360665492658e-15 true resid norm 3.195875263910e-13 ||r(i)||/||b|| 2.098092454232e-14
# [INFO] Time step 9/10, t = 0.9
#   0 KSP unpreconditioned resid norm 1.713715226304e+01 true resid norm 1.713715226304e+01 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 1.941039250082e-02 true resid norm 1.941039250081e-02 ||r(i)||/||b|| 1.132649824363e-03
#   2 KSP unpreconditioned resid norm 8.541340859736e-05 true resid norm 8.541340863836e-05 ||r(i)||/||b|| 4.984107471729e-06
#   3 KSP unpreconditioned resid norm 2.194059718847e-07 true resid norm 2.194060174341e-07 ||r(i)||/||b|| 1.280294497397e-08
#   4 KSP unpreconditioned resid norm 1.795552292896e-09 true resid norm 1.795810634052e-09 ||r(i)||/||b|| 1.047904929879e-10
#   5 KSP unpreconditioned resid norm 5.128697269453e-12 true resid norm 5.229518814696e-12 ||r(i)||/||b|| 3.051568156966e-13
#   6 KSP unpreconditioned resid norm 1.625970049553e-14 true resid norm 4.755529276097e-13 ||r(i)||/||b|| 2.774982215893e-14
#   7 KSP unpreconditioned resid norm 3.592328395211e-15 true resid norm 4.937187074242e-13 ||r(i)||/||b|| 2.880984540758e-14
# [INFO] Time step 10/10, t = 1.0
#   0 KSP unpreconditioned resid norm 1.904222002333e+01 true resid norm 1.904222002333e+01 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 2.166969083424e-02 true resid norm 2.166969083424e-02 ||r(i)||/||b|| 1.137981328211e-03
#   2 KSP unpreconditioned resid norm 9.525217636722e-05 true resid norm 9.525217637008e-05 ||r(i)||/||b|| 5.002157114736e-06
#   3 KSP unpreconditioned resid norm 2.429282550892e-07 true resid norm 2.429282466782e-07 ||r(i)||/||b|| 1.275734900555e-08
#   4 KSP unpreconditioned resid norm 1.970503816577e-09 true resid norm 1.970459739799e-09 ||r(i)||/||b|| 1.034784671842e-10
#   5 KSP unpreconditioned resid norm 5.745042217509e-12 true resid norm 5.762044797175e-12 ||r(i)||/||b|| 3.025931215014e-13
#   6 KSP unpreconditioned resid norm 2.142216723673e-14 true resid norm 4.778883965518e-13 ||r(i)||/||b|| 2.509625432152e-14
#   7 KSP unpreconditioned resid norm 1.021509569156e-14 true resid norm 4.103223303604e-13 ||r(i)||/||b|| 2.154803010666e-14
#   8 KSP unpreconditioned resid norm 7.865184028877e-15 true resid norm 4.103214543390e-13 ||r(i)||/||b|| 2.154798410250e-14
# [INFO] Time step 1/10, t = 0.1
# Averaging over 16 cells: 100%|██████████| 16/16 [00:00<00:00, 411.99it/s]
#   0 KSP unpreconditioned resid norm 3.767167014479e+00 true resid norm 3.767167014479e+00 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 2.173192790422e-03 true resid norm 2.173192790427e-03 ||r(i)||/||b|| 5.768772082772e-04
#   2 KSP unpreconditioned resid norm 2.395461468667e-05 true resid norm 2.395461469256e-05 ||r(i)||/||b|| 6.358787545254e-06
#   3 KSP unpreconditioned resid norm 2.380153498460e-07 true resid norm 2.380153368369e-07 ||r(i)||/||b|| 6.318151967304e-08
#   4 KSP unpreconditioned resid norm 2.939841048497e-09 true resid norm 2.939819377859e-09 ||r(i)||/||b|| 7.803793584304e-10
#   5 KSP unpreconditioned resid norm 3.927925655140e-11 true resid norm 3.925597867283e-11 ||r(i)||/||b|| 1.042055701856e-11
#   6 KSP unpreconditioned resid norm 4.153156171801e-13 true resid norm 4.312860597598e-13 ||r(i)||/||b|| 1.144855160661e-13
#   7 KSP unpreconditioned resid norm 5.294549440177e-15 true resid norm 1.467057403858e-13 ||r(i)||/||b|| 3.894325359666e-14
# [INFO] Time step 2/10, t = 0.2
#   0 KSP unpreconditioned resid norm 7.534297006881e+00 true resid norm 7.534297006881e+00 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 4.337728056899e-03 true resid norm 4.337728056910e-03 ||r(i)||/||b|| 5.757309610901e-04
#   2 KSP unpreconditioned resid norm 4.789837675695e-05 true resid norm 4.789837673765e-05 ||r(i)||/||b|| 6.357378358446e-06
#   3 KSP unpreconditioned resid norm 4.762515566046e-07 true resid norm 4.762515538693e-07 ||r(i)||/||b|| 6.321114676450e-08
#   4 KSP unpreconditioned resid norm 5.886326508648e-09 true resid norm 5.886380014269e-09 ||r(i)||/||b|| 7.812779359366e-10
#   5 KSP unpreconditioned resid norm 7.857758621941e-11 true resid norm 7.857376982747e-11 ||r(i)||/||b|| 1.042881237038e-11
#   6 KSP unpreconditioned resid norm 8.314732192918e-13 true resid norm 8.466010021810e-13 ||r(i)||/||b|| 1.123662899681e-13
#   7 KSP unpreconditioned resid norm 9.125785663728e-15 true resid norm 2.581900667036e-13 ||r(i)||/||b|| 3.426863401692e-14
# [INFO] Time step 3/10, t = 0.3
#   0 KSP unpreconditioned resid norm 1.130144803766e+01 true resid norm 1.130144803766e+01 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 6.512347825786e-03 true resid norm 6.512347825758e-03 ||r(i)||/||b|| 5.762401246336e-04
#   2 KSP unpreconditioned resid norm 7.194914239869e-05 true resid norm 7.194914238318e-05 ||r(i)||/||b|| 6.366364924517e-06
#   3 KSP unpreconditioned resid norm 7.144175199920e-07 true resid norm 7.144174988908e-07 ||r(i)||/||b|| 6.321468687113e-08
#   4 KSP unpreconditioned resid norm 8.822987574485e-09 true resid norm 8.822891937621e-09 ||r(i)||/||b|| 7.806868560758e-10
#   5 KSP unpreconditioned resid norm 1.177497616261e-10 true resid norm 1.177255873302e-10 ||r(i)||/||b|| 1.041685870147e-11
#   6 KSP unpreconditioned resid norm 1.247498200898e-12 true resid norm 1.313365033556e-12 ||r(i)||/||b|| 1.162121021288e-13
#   7 KSP unpreconditioned resid norm 1.463176315140e-14 true resid norm 3.268456279555e-13 ||r(i)||/||b|| 2.892068581535e-14
#   8 KSP unpreconditioned resid norm 4.860183476023e-15 true resid norm 4.183525404497e-13 ||r(i)||/||b|| 3.701760509412e-14
# [INFO] Time step 4/10, t = 0.4
#   0 KSP unpreconditioned resid norm 1.506862335307e+01 true resid norm 1.506862335307e+01 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 8.699591854399e-03 true resid norm 8.699591854416e-03 ||r(i)||/||b|| 5.773315617874e-04
#   2 KSP unpreconditioned resid norm 9.613426323892e-05 true resid norm 9.613426319796e-05 ||r(i)||/||b|| 6.379764159301e-06
#   3 KSP unpreconditioned resid norm 9.524978052716e-07 true resid norm 9.524977924613e-07 ||r(i)||/||b|| 6.321067095137e-08
#   4 KSP unpreconditioned resid norm 1.174594262239e-08 true resid norm 1.174594032749e-08 ||r(i)||/||b|| 7.794965772432e-10
#   5 KSP unpreconditioned resid norm 1.567472748837e-10 true resid norm 1.566826473059e-10 ||r(i)||/||b|| 1.039794038478e-11
#   6 KSP unpreconditioned resid norm 1.663179495101e-12 true resid norm 1.708174198383e-12 ||r(i)||/||b|| 1.133596718398e-13
#   7 KSP unpreconditioned resid norm 1.844021872590e-14 true resid norm 4.407544520332e-13 ||r(i)||/||b|| 2.924981544139e-14
#   8 KSP unpreconditioned resid norm 2.414524232382e-15 true resid norm 4.520754868852e-13 ||r(i)||/||b|| 3.000111398982e-14
# [INFO] Time step 5/10, t = 0.5
#   0 KSP unpreconditioned resid norm 1.883582352633e+01 true resid norm 1.883582352633e+01 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 1.090007824205e-02 true resid norm 1.090007824203e-02 ||r(i)||/||b|| 5.786887006450e-04
#   2 KSP unpreconditioned resid norm 1.204634177544e-04 true resid norm 1.204634177605e-04 ||r(i)||/||b|| 6.395442046488e-06
#   3 KSP unpreconditioned resid norm 1.190561210672e-06 true resid norm 1.190561192760e-06 ||r(i)||/||b|| 6.320728112025e-08
#   4 KSP unpreconditioned resid norm 1.465473068972e-08 true resid norm 1.465465365327e-08 ||r(i)||/||b|| 7.780203309288e-10
#   5 KSP unpreconditioned resid norm 1.955537164470e-10 true resid norm 1.955944086822e-10 ||r(i)||/||b|| 1.038417080139e-11
#   6 KSP unpreconditioned resid norm 2.078446677141e-12 true resid norm 2.239286295453e-12 ||r(i)||/||b|| 1.188844380668e-13
#   7 KSP unpreconditioned resid norm 2.290603185835e-14 true resid norm 6.554238392234e-13 ||r(i)||/||b|| 3.479666489269e-14
#   8 KSP unpreconditioned resid norm 1.162380728354e-15 true resid norm 7.952010827940e-13 ||r(i)||/||b|| 4.221748423596e-14
# [INFO] Time step 6/10, t = 0.6
#   0 KSP unpreconditioned resid norm 2.260304882930e+01 true resid norm 2.260304882930e+01 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 1.311409970735e-02 true resid norm 1.311409970729e-02 ||r(i)||/||b|| 5.801916284095e-04
#   2 KSP unpreconditioned resid norm 1.449414542299e-04 true resid norm 1.449414541761e-04 ||r(i)||/||b|| 6.412473612330e-06
#   3 KSP unpreconditioned resid norm 1.428673511245e-06 true resid norm 1.428673483711e-06 ||r(i)||/||b|| 6.320711398274e-08
#   4 KSP unpreconditioned resid norm 1.754932355788e-08 true resid norm 1.754923415528e-08 ||r(i)||/||b|| 7.764100448492e-10
#   5 KSP unpreconditioned resid norm 2.341557626603e-10 true resid norm 2.340601489647e-10 ||r(i)||/||b|| 1.035524679579e-11
#   6 KSP unpreconditioned resid norm 2.493147786549e-12 true resid norm 2.633049725369e-12 ||r(i)||/||b|| 1.164909099323e-13
#   7 KSP unpreconditioned resid norm 2.751941982444e-14 true resid norm 6.849372545638e-13 ||r(i)||/||b|| 3.030287018962e-14
#   8 KSP unpreconditioned resid norm 1.320665592710e-15 true resid norm 8.005210721688e-13 ||r(i)||/||b|| 3.541650855220e-14
# [INFO] Time step 7/10, t = 0.7
#   0 KSP unpreconditioned resid norm 2.637029948289e+01 true resid norm 2.637029948289e+01 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 1.534187777958e-02 true resid norm 1.534187777959e-02 ||r(i)||/||b|| 5.817862550079e-04
#   2 KSP unpreconditioned resid norm 1.695718253861e-04 true resid norm 1.695718253247e-04 ||r(i)||/||b|| 6.430409538378e-06
#   3 KSP unpreconditioned resid norm 1.666894055370e-06 true resid norm 1.666894170284e-06 ||r(i)||/||b|| 6.321104435564e-08
#   4 KSP unpreconditioned resid norm 2.042971671277e-08 true resid norm 2.042970542740e-08 ||r(i)||/||b|| 7.747240580507e-10
#   5 KSP unpreconditioned resid norm 2.725393270957e-10 true resid norm 2.724525885747e-10 ||r(i)||/||b|| 1.033179728397e-11
#   6 KSP unpreconditioned resid norm 2.907104534046e-12 true resid norm 2.918355644886e-12 ||r(i)||/||b|| 1.106682784084e-13
#   7 KSP unpreconditioned resid norm 3.257579190229e-14 true resid norm 9.164208865736e-13 ||r(i)||/||b|| 3.475200906111e-14
#   8 KSP unpreconditioned resid norm 5.403941535486e-15 true resid norm 8.138046013190e-13 ||r(i)||/||b|| 3.086065070467e-14
# [INFO] Time step 8/10, t = 0.8
#   0 KSP unpreconditioned resid norm 3.013757569774e+01 true resid norm 3.013757569774e+01 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 1.758361525430e-02 true resid norm 1.758361525429e-02 ||r(i)||/||b|| 5.834449137728e-04
#   2 KSP unpreconditioned resid norm 1.943575594233e-04 true resid norm 1.943575594221e-04 ||r(i)||/||b|| 6.449011074128e-06
#   3 KSP unpreconditioned resid norm 1.905279797830e-06 true resid norm 1.905279861663e-06 ||r(i)||/||b|| 6.321941355772e-08
#   4 KSP unpreconditioned resid norm 2.329592345893e-08 true resid norm 2.329582426315e-08 ||r(i)||/||b|| 7.729826876851e-10
#   5 KSP unpreconditioned resid norm 3.106896710805e-10 true resid norm 3.106588583309e-10 ||r(i)||/||b|| 1.030802415717e-11
#   6 KSP unpreconditioned resid norm 3.320100296229e-12 true resid norm 3.434811310582e-12 ||r(i)||/||b|| 1.139710554370e-13
#   7 KSP unpreconditioned resid norm 3.699186482717e-14 true resid norm 1.073432773301e-12 ||r(i)||/||b|| 3.561775452899e-14
#   8 KSP unpreconditioned resid norm 4.214759769856e-15 true resid norm 1.434313651896e-12 ||r(i)||/||b|| 4.759220404061e-14
# [INFO] Time step 9/10, t = 0.9
#   0 KSP unpreconditioned resid norm 3.390487768239e+01 true resid norm 3.390487768239e+01 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 1.983950850938e-02 true resid norm 1.983950850939e-02 ||r(i)||/||b|| 5.851520449428e-04
#   2 KSP unpreconditioned resid norm 2.193015296629e-04 true resid norm 2.193015298077e-04 ||r(i)||/||b|| 6.468141010919e-06
#   3 KSP unpreconditioned resid norm 2.143887261791e-06 true resid norm 2.143886949730e-06 ||r(i)||/||b|| 6.323240478298e-08
#   4 KSP unpreconditioned resid norm 2.614799560563e-08 true resid norm 2.614794812785e-08 ||r(i)||/||b|| 7.712149376499e-10
#   5 KSP unpreconditioned resid norm 3.485917197015e-10 true resid norm 3.485021667095e-10 ||r(i)||/||b|| 1.027882094058e-11
#   6 KSP unpreconditioned resid norm 3.731922899478e-12 true resid norm 4.079953223269e-12 ||r(i)||/||b|| 1.203352880812e-13
#   7 KSP unpreconditioned resid norm 4.172039253615e-14 true resid norm 1.614042322007e-12 ||r(i)||/||b|| 4.760501828459e-14
#   8 KSP unpreconditioned resid norm 5.159300830158e-15 true resid norm 1.652432340077e-12 ||r(i)||/||b|| 4.873730427687e-14
# [INFO] Time step 10/10, t = 1.0
#   0 KSP unpreconditioned resid norm 3.767220564502e+01 true resid norm 3.767220564502e+01 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 2.210975053808e-02 true resid norm 2.210975053805e-02 ||r(i)||/||b|| 5.868982226946e-04
#   2 KSP unpreconditioned resid norm 2.444065273476e-04 true resid norm 2.444065273074e-04 ||r(i)||/||b|| 6.487714831735e-06
#   3 KSP unpreconditioned resid norm 2.382773163605e-06 true resid norm 2.382772932138e-06 ||r(i)||/||b|| 6.325015728014e-08
#   4 KSP unpreconditioned resid norm 2.898603425441e-08 true resid norm 2.898586998164e-08 ||r(i)||/||b|| 7.694232255677e-10
#   5 KSP unpreconditioned resid norm 3.862302470060e-10 true resid norm 3.861226486293e-10 ||r(i)||/||b|| 1.024953654871e-11
#   6 KSP unpreconditioned resid norm 4.142329497325e-12 true resid norm 4.415347346623e-12 ||r(i)||/||b|| 1.172043757732e-13
#   7 KSP unpreconditioned resid norm 4.649945228050e-14 true resid norm 1.447569323754e-12 ||r(i)||/||b|| 3.842539344243e-14
#   8 KSP unpreconditioned resid norm 6.369037312145e-15 true resid norm 1.057431503921e-12 ||r(i)||/||b|| 2.806927510126e-14
# [INFO] Time step 1/10, t = 0.1
# Averaging over 32 cells: 100%|██████████| 32/32 [00:00<00:00, 371.28it/s]
#   0 KSP unpreconditioned resid norm 7.517646353441e+00 true resid norm 7.517646353441e+00 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 2.076017632531e-03 true resid norm 2.076017632523e-03 ||r(i)||/||b|| 2.761526061375e-04
#   2 KSP unpreconditioned resid norm 2.914993423317e-05 true resid norm 2.914993422444e-05 ||r(i)||/||b|| 3.877534650336e-06
#   3 KSP unpreconditioned resid norm 3.546873454181e-07 true resid norm 3.546873214117e-07 ||r(i)||/||b|| 4.718063403572e-08
#   4 KSP unpreconditioned resid norm 4.833553782680e-09 true resid norm 4.833532396587e-09 ||r(i)||/||b|| 6.429582038499e-10
#   5 KSP unpreconditioned resid norm 6.005613069021e-11 true resid norm 6.006009777582e-11 ||r(i)||/||b|| 7.989215633737e-12
#   6 KSP unpreconditioned resid norm 6.940477074699e-13 true resid norm 8.177115327347e-13 ||r(i)||/||b|| 1.087722798187e-13
#   7 KSP unpreconditioned resid norm 9.865959820637e-15 true resid norm 3.958449345038e-13 ||r(i)||/||b|| 5.265543441301e-14
# [INFO] Time step 2/10, t = 0.2
#   0 KSP unpreconditioned resid norm 1.503528732003e+01 true resid norm 1.503528732003e+01 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 4.147076680298e-03 true resid norm 4.147076680311e-03 ||r(i)||/||b|| 2.758229086043e-04
#   2 KSP unpreconditioned resid norm 5.824202119343e-05 true resid norm 5.824202111143e-05 ||r(i)||/||b|| 3.873688601470e-06
#   3 KSP unpreconditioned resid norm 7.097165623358e-07 true resid norm 7.097164797118e-07 ||r(i)||/||b|| 4.720338658020e-08
#   4 KSP unpreconditioned resid norm 9.663233272080e-09 true resid norm 9.663241242188e-09 ||r(i)||/||b|| 6.427041290601e-10
#   5 KSP unpreconditioned resid norm 1.199965501276e-10 true resid norm 1.199121044717e-10 ||r(i)||/||b|| 7.975378316317e-12
#   6 KSP unpreconditioned resid norm 1.386138064443e-12 true resid norm 1.697897035338e-12 ||r(i)||/||b|| 1.129274751588e-13
#   7 KSP unpreconditioned resid norm 1.960016957751e-14 true resid norm 9.538944128473e-13 ||r(i)||/||b|| 6.344371028923e-14
#   8 KSP unpreconditioned resid norm 2.798060184310e-15 true resid norm 8.318271339709e-13 ||r(i)||/||b|| 5.532499088746e-14
# [INFO] Time step 3/10, t = 0.3
#   0 KSP unpreconditioned resid norm 2.255293102512e+01 true resid norm 2.255293102512e+01 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 6.221254259954e-03 true resid norm 6.221254259858e-03 ||r(i)||/||b|| 2.758512520136e-04
#   2 KSP unpreconditioned resid norm 8.742063226275e-05 true resid norm 8.742063212713e-05 ||r(i)||/||b|| 3.876242605883e-06
#   3 KSP unpreconditioned resid norm 1.064831936323e-06 true resid norm 1.064831826512e-06 ||r(i)||/||b|| 4.721478664242e-08
#   4 KSP unpreconditioned resid norm 1.449831405660e-08 true resid norm 1.449815100358e-08 ||r(i)||/||b|| 6.428499686995e-10
#   5 KSP unpreconditioned resid norm 1.801223390248e-10 true resid norm 1.800230209499e-10 ||r(i)||/||b|| 7.982245001739e-12
#   6 KSP unpreconditioned resid norm 2.081982692909e-12 true resid norm 2.576328456277e-12 ||r(i)||/||b|| 1.142347508360e-13
#   7 KSP unpreconditioned resid norm 2.916222704261e-14 true resid norm 1.313402088669e-12 ||r(i)||/||b|| 5.823642555399e-14
#   8 KSP unpreconditioned resid norm 1.289155981030e-15 true resid norm 1.217693886216e-12 ||r(i)||/||b|| 5.399271096334e-14
# [INFO] Time step 4/10, t = 0.4
#   0 KSP unpreconditioned resid norm 3.007057771860e+01 true resid norm 3.007057771860e+01 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 8.299135940638e-03 true resid norm 8.299135940759e-03 ||r(i)||/||b|| 2.759885765555e-04
#   2 KSP unpreconditioned resid norm 1.167041371893e-04 true resid norm 1.167041372358e-04 ||r(i)||/||b|| 3.881007486052e-06
#   3 KSP unpreconditioned resid norm 1.419915919030e-06 true resid norm 1.419915846167e-06 ||r(i)||/||b|| 4.721944019349e-08
#   4 KSP unpreconditioned resid norm 1.933920955726e-08 true resid norm 1.933932639633e-08 ||r(i)||/||b|| 6.431311888087e-10
#   5 KSP unpreconditioned resid norm 2.404758668419e-10 true resid norm 2.404640928186e-10 ||r(i)||/||b|| 7.996656900605e-12
#   6 KSP unpreconditioned resid norm 2.782531987411e-12 true resid norm 3.381503792262e-12 ||r(i)||/||b|| 1.124522389927e-13
#   7 KSP unpreconditioned resid norm 3.930009596310e-14 true resid norm 1.537898945202e-12 ||r(i)||/||b|| 5.114297967913e-14
#   8 KSP unpreconditioned resid norm 5.240531895563e-15 true resid norm 1.480175152101e-12 ||r(i)||/||b|| 4.922336929979e-14
# [INFO] Time step 5/10, t = 0.5
#   0 KSP unpreconditioned resid norm 3.758822744083e+01 true resid norm 3.758822744083e+01 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 1.038088218696e-02 true resid norm 1.038088218708e-02 ||r(i)||/||b|| 2.761737622084e-04
#   2 KSP unpreconditioned resid norm 1.460979879202e-04 true resid norm 1.460979881584e-04 ||r(i)||/||b|| 3.886801748990e-06
#   3 KSP unpreconditioned resid norm 1.774985427045e-06 true resid norm 1.774985467376e-06 ||r(i)||/||b|| 4.722184546131e-08
#   4 KSP unpreconditioned resid norm 2.418627967214e-08 true resid norm 2.418619067039e-08 ||r(i)||/||b|| 6.434512164338e-10
#   5 KSP unpreconditioned resid norm 3.010670721479e-10 true resid norm 3.010337384464e-10 ||r(i)||/||b|| 8.008723979345e-12
#   6 KSP unpreconditioned resid norm 3.487974089183e-12 true resid norm 4.159177586074e-12 ||r(i)||/||b|| 1.106510700091e-13
#   7 KSP unpreconditioned resid norm 4.906353276448e-14 true resid norm 2.639601422935e-12 ||r(i)||/||b|| 7.022415268424e-14
#   8 KSP unpreconditioned resid norm 4.800092387582e-15 true resid norm 2.894154660424e-12 ||r(i)||/||b|| 7.699630595722e-14
# [INFO] Time step 6/10, t = 0.6
#   0 KSP unpreconditioned resid norm 4.510588021110e+01 true resid norm 4.510588021110e+01 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 1.246659658466e-02 true resid norm 1.246659658465e-02 ||r(i)||/||b|| 2.763851747556e-04
#   2 KSP unpreconditioned resid norm 1.756049433917e-04 true resid norm 1.756049436381e-04 ||r(i)||/||b|| 3.893171861766e-06
#   3 KSP unpreconditioned resid norm 2.130067886672e-06 true resid norm 2.130067848013e-06 ||r(i)||/||b|| 4.722372865896e-08
#   4 KSP unpreconditioned resid norm 2.903975205278e-08 true resid norm 2.903956470454e-08 ||r(i)||/||b|| 6.438088463995e-10
#   5 KSP unpreconditioned resid norm 3.618991247845e-10 true resid norm 3.618208797050e-10 ||r(i)||/||b|| 8.021590045723e-12
#   6 KSP unpreconditioned resid norm 4.198385969858e-12 true resid norm 5.151940494411e-12 ||r(i)||/||b|| 1.142188218099e-13
#   7 KSP unpreconditioned resid norm 5.945344899711e-14 true resid norm 2.592627816804e-12 ||r(i)||/||b|| 5.747871019631e-14
#   8 KSP unpreconditioned resid norm 8.802479547474e-15 true resid norm 2.447239950448e-12 ||r(i)||/||b|| 5.425545270361e-14
# [INFO] Time step 7/10, t = 0.7
#   0 KSP unpreconditioned resid norm 5.262353604512e+01 true resid norm 5.262353604512e+01 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 1.455636820478e-02 true resid norm 1.455636820474e-02 ||r(i)||/||b|| 2.766132665859e-04
#   2 KSP unpreconditioned resid norm 2.052269559695e-04 true resid norm 2.052269560600e-04 ||r(i)||/||b|| 3.899908130157e-06
#   3 KSP unpreconditioned resid norm 2.485186154296e-06 true resid norm 2.485186392562e-06 ||r(i)||/||b|| 4.722575826966e-08
#   4 KSP unpreconditioned resid norm 3.389975607553e-08 true resid norm 3.389993590724e-08 ||r(i)||/||b|| 6.441972253285e-10
#   5 KSP unpreconditioned resid norm 4.229733551083e-10 true resid norm 4.230460039515e-10 ||r(i)||/||b|| 8.039102571685e-12
#   6 KSP unpreconditioned resid norm 4.913791344303e-12 true resid norm 6.236741761275e-12 ||r(i)||/||b|| 1.185162045349e-13
#   7 KSP unpreconditioned resid norm 6.988822161735e-14 true resid norm 2.715707515299e-12 ||r(i)||/||b|| 5.160632901921e-14
#   8 KSP unpreconditioned resid norm 1.201401926572e-14 true resid norm 3.068013274801e-12 ||r(i)||/||b|| 5.830116152153e-14
#   9 KSP unpreconditioned resid norm 8.604206906920e-15 true resid norm 2.705939287751e-12 ||r(i)||/||b|| 5.142070432953e-14
# [INFO] Time step 8/10, t = 0.8
#   0 KSP unpreconditioned resid norm 6.014119495781e+01 true resid norm 6.014119495781e+01 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 1.665028171023e-02 true resid norm 1.665028171015e-02 ||r(i)||/||b|| 2.768531905931e-04
#   2 KSP unpreconditioned resid norm 2.349657178618e-04 true resid norm 2.349657177437e-04 ||r(i)||/||b|| 3.906901382796e-06
#   3 KSP unpreconditioned resid norm 2.840360406988e-06 true resid norm 2.840359961327e-06 ||r(i)||/||b|| 4.722819297687e-08
#   4 KSP unpreconditioned resid norm 3.876637815608e-08 true resid norm 3.876610676038e-08 ||r(i)||/||b|| 6.445849103525e-10
#   5 KSP unpreconditioned resid norm 4.842905107734e-10 true resid norm 4.842459700232e-10 ||r(i)||/||b|| 8.051818231462e-12
#   6 KSP unpreconditioned resid norm 5.634283858684e-12 true resid norm 6.514931328127e-12 ||r(i)||/||b|| 1.083272677355e-13
#   7 KSP unpreconditioned resid norm 8.515190777548e-14 true resid norm 3.782128656014e-12 ||r(i)||/||b|| 6.288748766410e-14
#   8 KSP unpreconditioned resid norm 2.993418824599e-14 true resid norm 3.853061717559e-12 ||r(i)||/||b|| 6.406692983505e-14
#   9 KSP unpreconditioned resid norm 2.231265032824e-14 true resid norm 3.849926602618e-12 ||r(i)||/||b|| 6.401480059247e-14
#  10 KSP unpreconditioned resid norm 1.851536905917e-14 true resid norm 3.882226020274e-12 ||r(i)||/||b|| 6.455186038450e-14
#  11 KSP unpreconditioned resid norm 1.617021561610e-14 true resid norm 4.009347872596e-12 ||r(i)||/||b|| 6.666558380505e-14
#  12 KSP unpreconditioned resid norm 1.453721463735e-14 true resid norm 3.824171128094e-12 ||r(i)||/||b|| 6.358655046306e-14
#  13 KSP unpreconditioned resid norm 1.331629513706e-14 true resid norm 3.888659946488e-12 ||r(i)||/||b|| 6.465884073663e-14
#  14 KSP unpreconditioned resid norm 1.235898128097e-14 true resid norm 3.906808631179e-12 ||r(i)||/||b|| 6.496060867961e-14
#  15 KSP unpreconditioned resid norm 1.158229658642e-14 true resid norm 3.906765861626e-12 ||r(i)||/||b|| 6.495989752725e-14
#  16 KSP unpreconditioned resid norm 1.093575911640e-14 true resid norm 3.771361593393e-12 ||r(i)||/||b|| 6.270845792203e-14
#  17 KSP unpreconditioned resid norm 1.038666019131e-14 true resid norm 3.951626784548e-12 ||r(i)||/||b|| 6.570582422447e-14
#  18 KSP unpreconditioned resid norm 9.912751993275e-15 true resid norm 3.950455332998e-12 ||r(i)||/||b|| 6.568634586940e-14
# [INFO] Time step 9/10, t = 0.9
#   0 KSP unpreconditioned resid norm 6.765885696396e+01 true resid norm 6.765885696396e+01 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 1.874842031373e-02 true resid norm 1.874842031376e-02 ||r(i)||/||b|| 2.771022325095e-04
#   2 KSP unpreconditioned resid norm 2.648228293371e-04 true resid norm 2.648228291963e-04 ||r(i)||/||b|| 3.914089611909e-06
#   3 KSP unpreconditioned resid norm 3.195609905113e-06 true resid norm 3.195609013461e-06 ||r(i)||/||b|| 4.723120012452e-08
#   4 KSP unpreconditioned resid norm 4.363968821370e-08 true resid norm 4.363956420928e-08 ||r(i)||/||b|| 6.449941096777e-10
#   5 KSP unpreconditioned resid norm 5.458511037240e-10 true resid norm 5.455743438465e-10 ||r(i)||/||b|| 8.063605687828e-12
#   6 KSP unpreconditioned resid norm 6.359655367551e-12 true resid norm 7.326284441062e-12 ||r(i)||/||b|| 1.082827107908e-13
#   7 KSP unpreconditioned resid norm 8.966083298524e-14 true resid norm 3.685224057967e-12 ||r(i)||/||b|| 5.446772563612e-14
#   8 KSP unpreconditioned resid norm 9.890326994585e-15 true resid norm 4.010264801180e-12 ||r(i)||/||b|| 5.927183788098e-14
# [INFO] Time step 10/10, t = 1.0
#   0 KSP unpreconditioned resid norm 7.517652207830e+01 true resid norm 7.517652207830e+01 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 2.085086662605e-02 true resid norm 2.085086662596e-02 ||r(i)||/||b|| 2.773587557594e-04
#   2 KSP unpreconditioned resid norm 2.947998484815e-04 true resid norm 2.947998481112e-04 ||r(i)||/||b|| 3.921435043299e-06
#   3 KSP unpreconditioned resid norm 3.550953702382e-06 true resid norm 3.550953434706e-06 ||r(i)||/||b|| 4.723487249127e-08
#   4 KSP unpreconditioned resid norm 4.851974941036e-08 true resid norm 4.851972067513e-08 ||r(i)||/||b|| 6.454105528398e-10
#   5 KSP unpreconditioned resid norm 6.076555191401e-10 true resid norm 6.073520619683e-10 ||r(i)||/||b|| 8.079012505203e-12
#   6 KSP unpreconditioned resid norm 7.090161911166e-12 true resid norm 8.453748788199e-12 ||r(i)||/||b|| 1.124519804121e-13
#   7 KSP unpreconditioned resid norm 9.966459643664e-14 true resid norm 5.076918444872e-12 ||r(i)||/||b|| 6.753329769079e-14
#   8 KSP unpreconditioned resid norm 7.694980088106e-15 true resid norm 5.103858073401e-12 ||r(i)||/||b|| 6.789164931153e-14
