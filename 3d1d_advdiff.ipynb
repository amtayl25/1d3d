# %% [markdown]
# <a href="https://colab.research.google.com/github/amtayl25/1d3d/blob/main/3d1d_advdiff.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Install required libraries (try-catch safe)
"""
NOTE: You can save the Docker image state after running this block so that you don't have to run it every time you start a new environment.
"""
import os, re

def replace_in_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()

    # Replace 'ufl' with 'ufl_legacy'
    content = re.sub(r'\bufl\b', 'ufl_legacy', content)

    with open(file_path, 'w', encoding='utf-8') as file:
        file.write(content)

def process_directory(directory):
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith('.py'):
                file_path = os.path.join(root, file)
                replace_in_file(file_path)

# ipywidgets
try:
    import ipywidgets
except ImportError:
    # !pip install ipywidgets

# dolfin
try:
    import dolfin
except ImportError:
    # !wget "https://fem-on-colab.github.io/releases/fenics-install-release-real.sh" -O "/tmp/fenics-install.sh" && bash "/tmp/fenics-install.sh"
    import dolfin

# block
try:
    import block
except ImportError:
    # !git clone "https://bitbucket.org/fenics-apps/cbc.block/src/master/"
    # !pip install master/

# fenics_ii
try:
    import xii
except ImportError:
    # !git clone "https://github.com/MiroK/fenics_ii"
    process_directory("fenics_ii/")
    # !pip install fenics_ii/

# vtk
try:
    import vtk
except ImportError:
    # !pip install vtk

# graphnics
try:
    import graphnics
except ImportError:
    # !git clone "https://github.com/IngeborgGjerde/graphnics"
    # !pip install graphnics/

# meshio
try:
    import meshio
except ImportError:
    # !pip install meshio

# pyvista
try:
    import pyvista
except ImportError:
    # !pip install pyvista
# Out:
# --2025-08-06 14:16:12--  https://fem-on-colab.github.io/releases/fenics-install-release-real.sh
# Resolving fem-on-colab.github.io (fem-on-colab.github.io)... 185.199.108.153, 185.199.109.153, 185.199.110.153, ...
# Connecting to fem-on-colab.github.io (fem-on-colab.github.io)|185.199.108.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4180 (4.1K) [application/x-sh]
# Saving to: ‘/tmp/fenics-install.sh’
#
# /tmp/fenics-install 100%[===================>]   4.08K  --.-KB/s    in 0s
#
# 2025-08-06 14:16:12 (71.9 MB/s) - ‘/tmp/fenics-install.sh’ saved [4180/4180]
#
# + INSTALL_PREFIX=/usr/local
# ++ echo /usr/local
# ++ awk -F/ '{print NF-1}'
# + INSTALL_PREFIX_DEPTH=2
# + PROJECT_NAME=fem-on-colab
# + SHARE_PREFIX=/usr/local/share/fem-on-colab
# + FENICS_INSTALLED=/usr/local/share/fem-on-colab/fenics.installed
# + [[ ! -f /usr/local/share/fem-on-colab/fenics.installed ]]
# + PYBIND11_INSTALL_SCRIPT_PATH=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/ec24876d/releases/pybind11-install.sh
# + [[ https://github.com/fem-on-colab/fem-on-colab.github.io/raw/ec24876d/releases/pybind11-install.sh == http* ]]
# + PYBIND11_INSTALL_SCRIPT_DOWNLOAD=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/ec24876d/releases/pybind11-install.sh
# + PYBIND11_INSTALL_SCRIPT_PATH=/tmp/pybind11-install.sh
# + [[ ! -f /tmp/pybind11-install.sh ]]
# + wget https://github.com/fem-on-colab/fem-on-colab.github.io/raw/ec24876d/releases/pybind11-install.sh -O /tmp/pybind11-install.sh
# --2025-08-06 14:16:12--  https://github.com/fem-on-colab/fem-on-colab.github.io/raw/ec24876d/releases/pybind11-install.sh
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/ec24876d47d05335d368c19e1a243206c70a8817/releases/pybind11-install.sh [following]
# --2025-08-06 14:16:12--  https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/ec24876d47d05335d368c19e1a243206c70a8817/releases/pybind11-install.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1800 (1.8K) [text/plain]
# Saving to: ‘/tmp/pybind11-install.sh’
#
# /tmp/pybind11-insta 100%[===================>]   1.76K  --.-KB/s    in 0s
#
# 2025-08-06 14:16:13 (42.6 MB/s) - ‘/tmp/pybind11-install.sh’ saved [1800/1800]
#
# + source /tmp/pybind11-install.sh
# ++ set -e
# ++ set -x
# ++ INSTALL_PREFIX=/usr/local
# +++ echo /usr/local
# +++ awk -F/ '{print NF-1}'
# ++ INSTALL_PREFIX_DEPTH=2
# ++ PROJECT_NAME=fem-on-colab
# ++ SHARE_PREFIX=/usr/local/share/fem-on-colab
# ++ PYBIND11_INSTALLED=/usr/local/share/fem-on-colab/pybind11.installed
# ++ [[ ! -f /usr/local/share/fem-on-colab/pybind11.installed ]]
# ++ MPI4PY_INSTALL_SCRIPT_PATH=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/f548cd5b/releases/mpi4py-install.sh
# ++ [[ https://github.com/fem-on-colab/fem-on-colab.github.io/raw/f548cd5b/releases/mpi4py-install.sh == http* ]]
# ++ MPI4PY_INSTALL_SCRIPT_DOWNLOAD=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/f548cd5b/releases/mpi4py-install.sh
# ++ MPI4PY_INSTALL_SCRIPT_PATH=/tmp/mpi4py-install.sh
# ++ [[ ! -f /tmp/mpi4py-install.sh ]]
# ++ wget https://github.com/fem-on-colab/fem-on-colab.github.io/raw/f548cd5b/releases/mpi4py-install.sh -O /tmp/mpi4py-install.sh
# --2025-08-06 14:16:13--  https://github.com/fem-on-colab/fem-on-colab.github.io/raw/f548cd5b/releases/mpi4py-install.sh
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/f548cd5b15ea75a0a45ecb10cef3d3ea0cf50001/releases/mpi4py-install.sh [following]
# --2025-08-06 14:16:13--  https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/f548cd5b15ea75a0a45ecb10cef3d3ea0cf50001/releases/mpi4py-install.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2583 (2.5K) [text/plain]
# Saving to: ‘/tmp/mpi4py-install.sh’
#
# /tmp/mpi4py-install 100%[===================>]   2.52K  --.-KB/s    in 0s
#
# 2025-08-06 14:16:13 (44.1 MB/s) - ‘/tmp/mpi4py-install.sh’ saved [2583/2583]
#
# ++ source /tmp/mpi4py-install.sh
# +++ set -e
# +++ set -x
# +++ INSTALL_PREFIX=/usr/local
# ++++ echo /usr/local
# ++++ awk -F/ '{print NF-1}'
# +++ INSTALL_PREFIX_DEPTH=2
# +++ PROJECT_NAME=fem-on-colab
# +++ SHARE_PREFIX=/usr/local/share/fem-on-colab
# +++ MPI4PY_INSTALLED=/usr/local/share/fem-on-colab/mpi4py.installed
# +++ [[ ! -f /usr/local/share/fem-on-colab/mpi4py.installed ]]
# +++ GCC_INSTALL_SCRIPT_PATH=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/301ae99b/releases/gcc-install.sh
# +++ [[ https://github.com/fem-on-colab/fem-on-colab.github.io/raw/301ae99b/releases/gcc-install.sh == http* ]]
# +++ GCC_INSTALL_SCRIPT_DOWNLOAD=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/301ae99b/releases/gcc-install.sh
# +++ GCC_INSTALL_SCRIPT_PATH=/tmp/gcc-install.sh
# +++ [[ ! -f /tmp/gcc-install.sh ]]
# +++ wget https://github.com/fem-on-colab/fem-on-colab.github.io/raw/301ae99b/releases/gcc-install.sh -O /tmp/gcc-install.sh
# --2025-08-06 14:16:13--  https://github.com/fem-on-colab/fem-on-colab.github.io/raw/301ae99b/releases/gcc-install.sh
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/301ae99b4a0752a457b4d75b7d521109a32ab51e/releases/gcc-install.sh [following]
# --2025-08-06 14:16:13--  https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/301ae99b4a0752a457b4d75b7d521109a32ab51e/releases/gcc-install.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8358 (8.2K) [text/plain]
# Saving to: ‘/tmp/gcc-install.sh’
#
# /tmp/gcc-install.sh 100%[===================>]   8.16K  --.-KB/s    in 0s
#
# 2025-08-06 14:16:14 (119 MB/s) - ‘/tmp/gcc-install.sh’ saved [8358/8358]
#
# +++ source /tmp/gcc-install.sh
# ++++ set -e
# ++++ set -x
# ++++ INSTALL_PREFIX=/usr/local
# +++++ echo /usr/local
# +++++ awk -F/ '{print NF-1}'
# ++++ INSTALL_PREFIX_DEPTH=2
# ++++ PROJECT_NAME=fem-on-colab
# ++++ SHARE_PREFIX=/usr/local/share/fem-on-colab
# ++++ GCC_INSTALLED=/usr/local/share/fem-on-colab/gcc.installed
# ++++ [[ ! -L /usr/local/lib64 ]]
# ++++ [[ -e /usr/local/lib64 ]]
# ++++ ln -s /usr/local/lib /usr/local/lib64
# ++++ [[ ! -L /usr/local/lib64 ]]
# ++++ [[ ! -d /usr/local/lib64 ]]
# ++++ [[ ! -f /usr/local/share/fem-on-colab/gcc.installed ]]
# ++++ GCC_ARCHIVE_PATH=https://github.com/fem-on-colab/fem-on-colab/releases/download/gcc-20250801-023308-211daac/gcc-install.tar.gz
# ++++ [[ https://github.com/fem-on-colab/fem-on-colab/releases/download/gcc-20250801-023308-211daac/gcc-install.tar.gz == http* ]]
# ++++ GCC_ARCHIVE_DOWNLOAD=https://github.com/fem-on-colab/fem-on-colab/releases/download/gcc-20250801-023308-211daac/gcc-install.tar.gz
# ++++ GCC_ARCHIVE_PATH=/tmp/gcc-install.tar.gz
# ++++ wget https://github.com/fem-on-colab/fem-on-colab/releases/download/gcc-20250801-023308-211daac/gcc-install.tar.gz -O /tmp/gcc-install.tar.gz
# --2025-08-06 14:16:14--  https://github.com/fem-on-colab/fem-on-colab/releases/download/gcc-20250801-023308-211daac/gcc-install.tar.gz
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/370599515/8965547a-382b-456c-9eea-d2e1dba0ec51?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-08-06T15%3A00%3A18Z&rscd=attachment%3B+filename%3Dgcc-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-08-06T14%3A00%3A05Z&ske=2025-08-06T15%3A00%3A18Z&sks=b&skv=2018-11-09&sig=kxyRWEdrph0Rq0fy3pe2j3HL5goDo7rACrrQE91BnTA%3D&jwt=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc1NDQ5MDA3NCwibmJmIjoxNzU0NDg5Nzc0LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.0zwVREQISZhL_Ifsah3Ns90bUijfosNDQi8LDYnLMU4&response-content-disposition=attachment%3B%20filename%3Dgcc-install.tar.gz&response-content-type=application%2Foctet-stream [following]
# --2025-08-06 14:16:14--  https://release-assets.githubusercontent.com/github-production-release-asset/370599515/8965547a-382b-456c-9eea-d2e1dba0ec51?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-08-06T15%3A00%3A18Z&rscd=attachment%3B+filename%3Dgcc-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-08-06T14%3A00%3A05Z&ske=2025-08-06T15%3A00%3A18Z&sks=b&skv=2018-11-09&sig=kxyRWEdrph0Rq0fy3pe2j3HL5goDo7rACrrQE91BnTA%3D&jwt=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc1NDQ5MDA3NCwibmJmIjoxNzU0NDg5Nzc0LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.0zwVREQISZhL_Ifsah3Ns90bUijfosNDQi8LDYnLMU4&response-content-disposition=attachment%3B%20filename%3Dgcc-install.tar.gz&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 687969111 (656M) [application/octet-stream]
# Saving to: ‘/tmp/gcc-install.tar.gz’
#
# /tmp/gcc-install.ta 100%[===================>] 656.10M  16.4MB/s    in 33s
#
# 2025-08-06 14:16:48 (19.6 MB/s) - ‘/tmp/gcc-install.tar.gz’ saved [687969111/687969111]
#
# ++++ [[ /tmp/gcc-install.tar.gz != skip ]]
# ++++ tar -xzf /tmp/gcc-install.tar.gz --strip-components=2 --directory=/usr/local
# ++++ apt install -y -qq zlib1g-dev
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-2ubuntu9.2).
# zlib1g-dev set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
# ++++ [[ /tmp/gcc-install.tar.gz != skip ]]
# ++++ for LEGACY_GPP in /usr/bin/g++-*
# +++++ /usr/bin/g++-11 -dumpversion
# ++++ LEGACY_GCC_VERSION=11
# ++++ update-alternatives --install /usr/bin/g++ g++ /usr/bin/g++-11 11
# update-alternatives: using /usr/bin/g++-11 to provide /usr/bin/g++ (g++) in auto mode
# ++++ update-alternatives --install /usr/bin/gcc gcc /usr/bin/gcc-11 11
# update-alternatives: using /usr/bin/gcc-11 to provide /usr/bin/gcc (gcc) in auto mode
# ++++ update-alternatives --install /usr/bin/gcc-ar gcc-ar /usr/bin/gcc-ar-11 11
# update-alternatives: using /usr/bin/gcc-ar-11 to provide /usr/bin/gcc-ar (gcc-ar) in auto mode
# ++++ update-alternatives --install /usr/bin/gcc-nm gcc-nm /usr/bin/gcc-nm-11 11
# update-alternatives: using /usr/bin/gcc-nm-11 to provide /usr/bin/gcc-nm (gcc-nm) in auto mode
# ++++ update-alternatives --install /usr/bin/gcc-ranlib gcc-ranlib /usr/bin/gcc-ranlib-11 11
# update-alternatives: using /usr/bin/gcc-ranlib-11 to provide /usr/bin/gcc-ranlib (gcc-ranlib) in auto mode
# ++++ update-alternatives --install /usr/bin/x86_64-linux-gnu-g++ x86_64-linux-gnu-g++ /usr/bin/x86_64-linux-gnu-g++-11 11
# update-alternatives: using /usr/bin/x86_64-linux-gnu-g++-11 to provide /usr/bin/x86_64-linux-gnu-g++ (x86_64-linux-gnu-g++) in auto mode
# ++++ update-alternatives --install /usr/bin/x86_64-linux-gnu-gcc x86_64-linux-gnu-gcc /usr/bin/x86_64-linux-gnu-gcc-11 11
# update-alternatives: using /usr/bin/x86_64-linux-gnu-gcc-11 to provide /usr/bin/x86_64-linux-gnu-gcc (x86_64-linux-gnu-gcc) in auto mode
# ++++ update-alternatives --install /usr/bin/x86_64-linux-gnu-gcc-ar x86_64-linux-gnu-gcc-ar /usr/bin/x86_64-linux-gnu-gcc-ar-11 11
# update-alternatives: using /usr/bin/x86_64-linux-gnu-gcc-ar-11 to provide /usr/bin/x86_64-linux-gnu-gcc-ar (x86_64-linux-gnu-gcc-ar) in auto mode
# ++++ update-alternatives --install /usr/bin/x86_64-linux-gnu-gcc-nm x86_64-linux-gnu-gcc-nm /usr/bin/x86_64-linux-gnu-gcc-nm-11 11
# update-alternatives: using /usr/bin/x86_64-linux-gnu-gcc-nm-11 to provide /usr/bin/x86_64-linux-gnu-gcc-nm (x86_64-linux-gnu-gcc-nm) in auto mode
# ++++ update-alternatives --install /usr/bin/x86_64-linux-gnu-gcc-ranlib x86_64-linux-gnu-gcc-ranlib /usr/bin/x86_64-linux-gnu-gcc-ranlib-11 11
# update-alternatives: using /usr/bin/x86_64-linux-gnu-gcc-ranlib-11 to provide /usr/bin/x86_64-linux-gnu-gcc-ranlib (x86_64-linux-gnu-gcc-ranlib) in auto mode
# +++++ /usr/local/bin/g++ -dumpversion
# ++++ GCC_VERSION=12
# ++++ update-alternatives --install /usr/bin/g++ g++ /usr/local/bin/g++-12 12
# update-alternatives: using /usr/local/bin/g++-12 to provide /usr/bin/g++ (g++) in auto mode
# ++++ update-alternatives --install /usr/bin/gcc gcc /usr/local/bin/gcc-12 12
# update-alternatives: using /usr/local/bin/gcc-12 to provide /usr/bin/gcc (gcc) in auto mode
# ++++ update-alternatives --install /usr/bin/gcc-ar gcc-ar /usr/local/bin/gcc-ar-12 12
# update-alternatives: using /usr/local/bin/gcc-ar-12 to provide /usr/bin/gcc-ar (gcc-ar) in auto mode
# ++++ update-alternatives --install /usr/bin/gcc-nm gcc-nm /usr/local/bin/gcc-nm-12 12
# update-alternatives: using /usr/local/bin/gcc-nm-12 to provide /usr/bin/gcc-nm (gcc-nm) in auto mode
# ++++ update-alternatives --install /usr/bin/gcc-ranlib gcc-ranlib /usr/local/bin/gcc-ranlib-12 12
# update-alternatives: using /usr/local/bin/gcc-ranlib-12 to provide /usr/bin/gcc-ranlib (gcc-ranlib) in auto mode
# ++++ update-alternatives --install /usr/bin/gfortran gfortran /usr/local/bin/gfortran-12 12
# update-alternatives: using /usr/local/bin/gfortran-12 to provide /usr/bin/gfortran (gfortran) in auto mode
# ++++ update-alternatives --install /usr/bin/x86_64-linux-gnu-g++ x86_64-linux-gnu-g++ /usr/local/bin/x86_64-linux-gnu-g++-12 12
# update-alternatives: using /usr/local/bin/x86_64-linux-gnu-g++-12 to provide /usr/bin/x86_64-linux-gnu-g++ (x86_64-linux-gnu-g++) in auto mode
# ++++ update-alternatives --install /usr/bin/x86_64-linux-gnu-gcc x86_64-linux-gnu-gcc /usr/local/bin/x86_64-linux-gnu-gcc-12 12
# update-alternatives: using /usr/local/bin/x86_64-linux-gnu-gcc-12 to provide /usr/bin/x86_64-linux-gnu-gcc (x86_64-linux-gnu-gcc) in auto mode
# ++++ update-alternatives --install /usr/bin/x86_64-linux-gnu-gcc-ar x86_64-linux-gnu-gcc-ar /usr/local/bin/x86_64-linux-gnu-gcc-ar-12 12
# update-alternatives: using /usr/local/bin/x86_64-linux-gnu-gcc-ar-12 to provide /usr/bin/x86_64-linux-gnu-gcc-ar (x86_64-linux-gnu-gcc-ar) in auto mode
# ++++ update-alternatives --install /usr/bin/x86_64-linux-gnu-gcc-nm x86_64-linux-gnu-gcc-nm /usr/local/bin/x86_64-linux-gnu-gcc-nm-12 12
# update-alternatives: using /usr/local/bin/x86_64-linux-gnu-gcc-nm-12 to provide /usr/bin/x86_64-linux-gnu-gcc-nm (x86_64-linux-gnu-gcc-nm) in auto mode
# ++++ update-alternatives --install /usr/bin/x86_64-linux-gnu-gcc-ranlib x86_64-linux-gnu-gcc-ranlib /usr/local/bin/x86_64-linux-gnu-gcc-ranlib-12 12
# update-alternatives: using /usr/local/bin/x86_64-linux-gnu-gcc-ranlib-12 to provide /usr/bin/x86_64-linux-gnu-gcc-ranlib (x86_64-linux-gnu-gcc-ranlib) in auto mode
# ++++ update-alternatives --set g++ /usr/local/bin/g++-12
# ++++ update-alternatives --set gcc /usr/local/bin/gcc-12
# ++++ update-alternatives --set gcc-ar /usr/local/bin/gcc-ar-12
# ++++ update-alternatives --set gcc-nm /usr/local/bin/gcc-nm-12
# ++++ update-alternatives --set gcc-ranlib /usr/local/bin/gcc-ranlib-12
# ++++ update-alternatives --set gfortran /usr/local/bin/gfortran-12
# ++++ update-alternatives --set x86_64-linux-gnu-g++ /usr/local/bin/x86_64-linux-gnu-g++-12
# ++++ update-alternatives --set x86_64-linux-gnu-gcc /usr/local/bin/x86_64-linux-gnu-gcc-12
# ++++ update-alternatives --set x86_64-linux-gnu-gcc-ar /usr/local/bin/x86_64-linux-gnu-gcc-ar-12
# ++++ update-alternatives --set x86_64-linux-gnu-gcc-nm /usr/local/bin/x86_64-linux-gnu-gcc-nm-12
# ++++ update-alternatives --set x86_64-linux-gnu-gcc-ranlib /usr/local/bin/x86_64-linux-gnu-gcc-ranlib-12
# ++++ [[ /tmp/gcc-install.tar.gz != skip ]]
# +++++ which python3
# ++++ PYTHON_EXEC=/usr/bin/python3
# +++++ dirname /usr/bin/python3
# ++++ PYTHON_EXEC_DIR=/usr/bin
# +++++ objdump -x /usr/bin/python3
# +++++ grep 'R.*PATH'
# +++++ sed 's|R.*PATH||g'
# +++++ sed 's| ||g'
# +++++ sed 's|$ORIGIN|/usr/bin|g'
# ++++ PYTHON_RPATH=
# ++++ [[ -z '' ]]
# ++++ PYTHON_RPATH=/usr/lib/x86_64-linux-gnu
# ++++ INSTALL_PREFIX_RPATH=/usr/local/lib
# ++++ [[ -L /usr/lib/x86_64-linux-gnu/libstdc++.so ]]
# +++++ basename /usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.30
# ++++ LIBSTDCXX_SYSTEM_VERSION=libstdc++.so.6.0.30
# +++++ basename /usr/local/lib/libstdc++.so.6.0.30 /usr/local/lib/libstdc++.so.6.0.30-gdb.py
# ++++ LIBSTDCXX_INSTALL_PREFIX_VERSION=libstdc++.so.6.0.30
# ++++ [[ libstdc++.so.6.0.30 != \l\i\b\s\t\d\c\+\+\.\s\o\.\6\.\0\.\3\0 ]]
# ++++ mkdir -p /usr/local/share/fem-on-colab
# ++++ touch /usr/local/share/fem-on-colab/gcc.installed
# +++ MPI4PY_ARCHIVE_PATH=https://github.com/fem-on-colab/fem-on-colab/releases/download/mpi4py-20250801-025602-211daac/mpi4py-install.tar.gz
# +++ [[ https://github.com/fem-on-colab/fem-on-colab/releases/download/mpi4py-20250801-025602-211daac/mpi4py-install.tar.gz == http* ]]
# +++ MPI4PY_ARCHIVE_DOWNLOAD=https://github.com/fem-on-colab/fem-on-colab/releases/download/mpi4py-20250801-025602-211daac/mpi4py-install.tar.gz
# +++ MPI4PY_ARCHIVE_PATH=/tmp/mpi4py-install.tar.gz
# +++ wget https://github.com/fem-on-colab/fem-on-colab/releases/download/mpi4py-20250801-025602-211daac/mpi4py-install.tar.gz -O /tmp/mpi4py-install.tar.gz
# --2025-08-06 14:17:05--  https://github.com/fem-on-colab/fem-on-colab/releases/download/mpi4py-20250801-025602-211daac/mpi4py-install.tar.gz
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/370599515/ee250e90-c4e1-4de2-a47b-5306c52bf9b7?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-08-06T15%3A01%3A03Z&rscd=attachment%3B+filename%3Dmpi4py-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-08-06T14%3A00%3A30Z&ske=2025-08-06T15%3A01%3A03Z&sks=b&skv=2018-11-09&sig=djQ29F4O1SIBXiuJWMzjfY989oM2QPRCaIe9S3C4gLc%3D&jwt=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc1NDQ5MDEyNSwibmJmIjoxNzU0NDg5ODI1LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.NXIlXGSdY4qY9IYOLNopstXAKsBhxJowKVVoKkM_45U&response-content-disposition=attachment%3B%20filename%3Dmpi4py-install.tar.gz&response-content-type=application%2Foctet-stream [following]
# --2025-08-06 14:17:05--  https://release-assets.githubusercontent.com/github-production-release-asset/370599515/ee250e90-c4e1-4de2-a47b-5306c52bf9b7?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-08-06T15%3A01%3A03Z&rscd=attachment%3B+filename%3Dmpi4py-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-08-06T14%3A00%3A30Z&ske=2025-08-06T15%3A01%3A03Z&sks=b&skv=2018-11-09&sig=djQ29F4O1SIBXiuJWMzjfY989oM2QPRCaIe9S3C4gLc%3D&jwt=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc1NDQ5MDEyNSwibmJmIjoxNzU0NDg5ODI1LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.NXIlXGSdY4qY9IYOLNopstXAKsBhxJowKVVoKkM_45U&response-content-disposition=attachment%3B%20filename%3Dmpi4py-install.tar.gz&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14114970 (13M) [application/octet-stream]
# Saving to: ‘/tmp/mpi4py-install.tar.gz’
#
# /tmp/mpi4py-install 100%[===================>]  13.46M  43.6MB/s    in 0.3s
#
# 2025-08-06 14:17:06 (43.6 MB/s) - ‘/tmp/mpi4py-install.tar.gz’ saved [14114970/14114970]
#
# +++ [[ /tmp/mpi4py-install.tar.gz != skip ]]
# +++ tar -xzf /tmp/mpi4py-install.tar.gz --strip-components=2 --directory=/usr/local
# +++ [[ /tmp/mpi4py-install.tar.gz != skip ]]
# +++ command -v mpicc
# /usr/local/bin/mpicc
# +++ [[ /tmp/mpi4py-install.tar.gz != skip ]]
# +++ MPI_LIBS=('libhwloc*.so*' 'libmpi*.so*' 'libopen-pal*.so*' 'libpmix*.so*' 'libprrte*.so*')
# +++ for MPI_LIB in "${MPI_LIBS[@]}"
# +++ rm -f '/usr/lib/libhwloc*.so*'
# +++ rm -f /usr/lib/x86_64-linux-gnu/libhwloc.so /usr/lib/x86_64-linux-gnu/libhwloc.so.15 /usr/lib/x86_64-linux-gnu/libhwloc.so.15.5.2
# +++ ln -fs /usr/local/lib/libhwloc.so /usr/local/lib/libhwloc.so.15 /usr/local/lib/libhwloc.so.15.5.3 /usr/local/lib/libhwloc.so.15.8.1 /usr/lib
# +++ for MPI_LIB in "${MPI_LIBS[@]}"
# +++ rm -f '/usr/lib/libmpi*.so*'
# +++ rm -f /usr/lib/x86_64-linux-gnu/libmpi_cxx.so /usr/lib/x86_64-linux-gnu/libmpi_cxx.so.40 /usr/lib/x86_64-linux-gnu/libmpi_cxx.so.40.30.1 /usr/lib/x86_64-linux-gnu/libmpi_java.so /usr/lib/x86_64-linux-gnu/libmpi_java.so.40 /usr/lib/x86_64-linux-gnu/libmpi_java.so.40.30.0 /usr/lib/x86_64-linux-gnu/libmpi_mpifh-gfortran.so /usr/lib/x86_64-linux-gnu/libmpi_mpifh-gfortran.so.40 /usr/lib/x86_64-linux-gnu/libmpi_mpifh-gfortran.so.40.30.0 /usr/lib/x86_64-linux-gnu/libmpi_mpifh.so /usr/lib/x86_64-linux-gnu/libmpi_mpifh.so.40 /usr/lib/x86_64-linux-gnu/libmpi_mpifh.so.40.30.0 /usr/lib/x86_64-linux-gnu/libmpiseq_seq-5.4.0.so /usr/lib/x86_64-linux-gnu/libmpiseq_seq-5.4.so /usr/lib/x86_64-linux-gnu/libmpiseq_seq.so /usr/lib/x86_64-linux-gnu/libmpi++.so /usr/lib/x86_64-linux-gnu/libmpi.so /usr/lib/x86_64-linux-gnu/libmpi.so.40 /usr/lib/x86_64-linux-gnu/libmpi.so.40.30.2 /usr/lib/x86_64-linux-gnu/libmpi_usempif08-gfortran.so /usr/lib/x86_64-linux-gnu/libmpi_usempif08-gfortran.so.40 /usr/lib/x86_64-linux-gnu/libmpi_usempif08-gfortran.so.40.30.0 /usr/lib/x86_64-linux-gnu/libmpi_usempif08.so /usr/lib/x86_64-linux-gnu/libmpi_usempif08.so.40 /usr/lib/x86_64-linux-gnu/libmpi_usempif08.so.40.30.0 /usr/lib/x86_64-linux-gnu/libmpi_usempi_ignore_tkr-gfortran.so /usr/lib/x86_64-linux-gnu/libmpi_usempi_ignore_tkr-gfortran.so.40 /usr/lib/x86_64-linux-gnu/libmpi_usempi_ignore_tkr-gfortran.so.40.30.0 /usr/lib/x86_64-linux-gnu/libmpi_usempi_ignore_tkr.so /usr/lib/x86_64-linux-gnu/libmpi_usempi_ignore_tkr.so.40 /usr/lib/x86_64-linux-gnu/libmpi_usempi_ignore_tkr.so.40.30.0
# +++ ln -fs /usr/local/lib/libmpi_mpifh.so /usr/local/lib/libmpi_mpifh.so.40 /usr/local/lib/libmpi_mpifh.so.40.40.1 /usr/local/lib/libmpi.so /usr/local/lib/libmpi.so.40 /usr/local/lib/libmpi.so.40.40.7 /usr/local/lib/libmpi_usempif08.so /usr/local/lib/libmpi_usempif08.so.40 /usr/local/lib/libmpi_usempif08.so.40.40.3 /usr/local/lib/libmpi_usempi_ignore_tkr.so /usr/local/lib/libmpi_usempi_ignore_tkr.so.40 /usr/local/lib/libmpi_usempi_ignore_tkr.so.40.40.1 /usr/lib
# +++ for MPI_LIB in "${MPI_LIBS[@]}"
# +++ rm -f '/usr/lib/libopen-pal*.so*'
# +++ rm -f /usr/lib/x86_64-linux-gnu/libopen-pal.so /usr/lib/x86_64-linux-gnu/libopen-pal.so.40 /usr/lib/x86_64-linux-gnu/libopen-pal.so.40.30.2
# +++ ln -fs /usr/local/lib/libopen-pal.so /usr/local/lib/libopen-pal.so.80 /usr/local/lib/libopen-pal.so.80.0.5 /usr/lib
# +++ for MPI_LIB in "${MPI_LIBS[@]}"
# +++ rm -f '/usr/lib/libpmix*.so*'
# +++ rm -f /usr/lib/x86_64-linux-gnu/libpmix.so /usr/lib/x86_64-linux-gnu/libpmix.so.2 /usr/lib/x86_64-linux-gnu/libpmix.so.2.5.2
# +++ ln -fs /usr/local/lib/libpmix.so /usr/local/lib/libpmix.so.2 /usr/local/lib/libpmix.so.2.13.8 /usr/lib
# +++ for MPI_LIB in "${MPI_LIBS[@]}"
# +++ rm -f '/usr/lib/libprrte*.so*'
# +++ rm -f '/usr/lib/x86_64-linux-gnu/libprrte*.so*'
# +++ ln -fs /usr/local/lib/libprrte.so /usr/local/lib/libprrte.so.3 /usr/local/lib/libprrte.so.3.0.11 /usr/lib
# +++ mkdir -p /usr/local/share/fem-on-colab
# +++ touch /usr/local/share/fem-on-colab/mpi4py.installed
# ++ PYBIND11_ARCHIVE_PATH=https://github.com/fem-on-colab/fem-on-colab/releases/download/pybind11-20250801-031334-211daac/pybind11-install.tar.gz
# ++ [[ https://github.com/fem-on-colab/fem-on-colab/releases/download/pybind11-20250801-031334-211daac/pybind11-install.tar.gz == http* ]]
# ++ PYBIND11_ARCHIVE_DOWNLOAD=https://github.com/fem-on-colab/fem-on-colab/releases/download/pybind11-20250801-031334-211daac/pybind11-install.tar.gz
# ++ PYBIND11_ARCHIVE_PATH=/tmp/pybind11-install.tar.gz
# ++ wget https://github.com/fem-on-colab/fem-on-colab/releases/download/pybind11-20250801-031334-211daac/pybind11-install.tar.gz -O /tmp/pybind11-install.tar.gz
# --2025-08-06 14:17:07--  https://github.com/fem-on-colab/fem-on-colab/releases/download/pybind11-20250801-031334-211daac/pybind11-install.tar.gz
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/370599515/bbe4fc03-7842-4080-9f1b-c01acfb19681?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-08-06T15%3A01%3A38Z&rscd=attachment%3B+filename%3Dpybind11-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-08-06T14%3A01%3A05Z&ske=2025-08-06T15%3A01%3A38Z&sks=b&skv=2018-11-09&sig=IZpjWQSJoIwd5mY5Abe%2FMp%2BZqGJJxLT04pzB6eUVGns%3D&jwt=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc1NDQ5MDEyNywibmJmIjoxNzU0NDg5ODI3LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.uFNWDSvwPX6icDqUxALqq8q9sGcDISpMTMiVsBJ35M0&response-content-disposition=attachment%3B%20filename%3Dpybind11-install.tar.gz&response-content-type=application%2Foctet-stream [following]
# --2025-08-06 14:17:07--  https://release-assets.githubusercontent.com/github-production-release-asset/370599515/bbe4fc03-7842-4080-9f1b-c01acfb19681?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-08-06T15%3A01%3A38Z&rscd=attachment%3B+filename%3Dpybind11-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-08-06T14%3A01%3A05Z&ske=2025-08-06T15%3A01%3A38Z&sks=b&skv=2018-11-09&sig=IZpjWQSJoIwd5mY5Abe%2FMp%2BZqGJJxLT04pzB6eUVGns%3D&jwt=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc1NDQ5MDEyNywibmJmIjoxNzU0NDg5ODI3LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.uFNWDSvwPX6icDqUxALqq8q9sGcDISpMTMiVsBJ35M0&response-content-disposition=attachment%3B%20filename%3Dpybind11-install.tar.gz&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 663560 (648K) [application/octet-stream]
# Saving to: ‘/tmp/pybind11-install.tar.gz’
#
# /tmp/pybind11-insta 100%[===================>] 648.01K  --.-KB/s    in 0.005s
#
# 2025-08-06 14:17:07 (118 MB/s) - ‘/tmp/pybind11-install.tar.gz’ saved [663560/663560]
#
# ++ [[ /tmp/pybind11-install.tar.gz != skip ]]
# ++ rm -rf '/usr/lib/python*/*-packages/pybind11*'
# ++ rm -rf '/usr/local/lib/python*/*-packages/pybind11*'
# ++ tar -xzf /tmp/pybind11-install.tar.gz --strip-components=2 --directory=/usr/local
# ++ mkdir -p /usr/local/share/fem-on-colab
# ++ touch /usr/local/share/fem-on-colab/pybind11.installed
# + BOOST_INSTALL_SCRIPT_PATH=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/0f67f79c/releases/boost-install.sh
# + [[ https://github.com/fem-on-colab/fem-on-colab.github.io/raw/0f67f79c/releases/boost-install.sh == http* ]]
# + BOOST_INSTALL_SCRIPT_DOWNLOAD=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/0f67f79c/releases/boost-install.sh
# + BOOST_INSTALL_SCRIPT_PATH=/tmp/boost-install.sh
# + [[ ! -f /tmp/boost-install.sh ]]
# + wget https://github.com/fem-on-colab/fem-on-colab.github.io/raw/0f67f79c/releases/boost-install.sh -O /tmp/boost-install.sh
# --2025-08-06 14:17:07--  https://github.com/fem-on-colab/fem-on-colab.github.io/raw/0f67f79c/releases/boost-install.sh
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/0f67f79c04ad582aa19b688875617264c8924dc4/releases/boost-install.sh [following]
# --2025-08-06 14:17:08--  https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/0f67f79c04ad582aa19b688875617264c8924dc4/releases/boost-install.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1856 (1.8K) [text/plain]
# Saving to: ‘/tmp/boost-install.sh’
#
# /tmp/boost-install. 100%[===================>]   1.81K  --.-KB/s    in 0s
#
# 2025-08-06 14:17:08 (40.3 MB/s) - ‘/tmp/boost-install.sh’ saved [1856/1856]
#
# + source /tmp/boost-install.sh
# ++ set -e
# ++ set -x
# ++ INSTALL_PREFIX=/usr/local
# +++ echo /usr/local
# +++ awk -F/ '{print NF-1}'
# ++ INSTALL_PREFIX_DEPTH=2
# ++ PROJECT_NAME=fem-on-colab
# ++ SHARE_PREFIX=/usr/local/share/fem-on-colab
# ++ BOOST_INSTALLED=/usr/local/share/fem-on-colab/boost.installed
# ++ [[ ! -f /usr/local/share/fem-on-colab/boost.installed ]]
# ++ GCC_INSTALL_SCRIPT_PATH=/tmp/gcc-install.sh
# ++ [[ /tmp/gcc-install.sh == http* ]]
# ++ source /tmp/gcc-install.sh
# +++ set -e
# +++ set -x
# +++ INSTALL_PREFIX=/usr/local
# ++++ echo /usr/local
# ++++ awk -F/ '{print NF-1}'
# +++ INSTALL_PREFIX_DEPTH=2
# +++ PROJECT_NAME=fem-on-colab
# +++ SHARE_PREFIX=/usr/local/share/fem-on-colab
# +++ GCC_INSTALLED=/usr/local/share/fem-on-colab/gcc.installed
# +++ [[ ! -L /usr/local/lib64 ]]
# +++ [[ ! -L /usr/local/lib64 ]]
# +++ [[ ! -d /usr/local/lib64 ]]
# +++ [[ ! -f /usr/local/share/fem-on-colab/gcc.installed ]]
# ++ BOOST_ARCHIVE_PATH=https://github.com/fem-on-colab/fem-on-colab/releases/download/boost-20250801-025600-211daac/boost-install.tar.gz
# ++ [[ https://github.com/fem-on-colab/fem-on-colab/releases/download/boost-20250801-025600-211daac/boost-install.tar.gz == http* ]]
# ++ BOOST_ARCHIVE_DOWNLOAD=https://github.com/fem-on-colab/fem-on-colab/releases/download/boost-20250801-025600-211daac/boost-install.tar.gz
# ++ BOOST_ARCHIVE_PATH=/tmp/boost-install.tar.gz
# ++ wget https://github.com/fem-on-colab/fem-on-colab/releases/download/boost-20250801-025600-211daac/boost-install.tar.gz -O /tmp/boost-install.tar.gz
# --2025-08-06 14:17:08--  https://github.com/fem-on-colab/fem-on-colab/releases/download/boost-20250801-025600-211daac/boost-install.tar.gz
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/370599515/31244a5e-df61-4550-9229-a8eb8871909a?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-08-06T14%3A58%3A40Z&rscd=attachment%3B+filename%3Dboost-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-08-06T13%3A58%3A01Z&ske=2025-08-06T14%3A58%3A40Z&sks=b&skv=2018-11-09&sig=kBY5uv9v6lHJXjnbXWNxZwOCXhdoJlJti9OlkD4h4KM%3D&jwt=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc1NDQ5MDEyOCwibmJmIjoxNzU0NDg5ODI4LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.s3lXBXI7ohfxpMj2vWOCkOQNehf6uuEbd7E7UCR8CMM&response-content-disposition=attachment%3B%20filename%3Dboost-install.tar.gz&response-content-type=application%2Foctet-stream [following]
# --2025-08-06 14:17:08--  https://release-assets.githubusercontent.com/github-production-release-asset/370599515/31244a5e-df61-4550-9229-a8eb8871909a?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-08-06T14%3A58%3A40Z&rscd=attachment%3B+filename%3Dboost-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-08-06T13%3A58%3A01Z&ske=2025-08-06T14%3A58%3A40Z&sks=b&skv=2018-11-09&sig=kBY5uv9v6lHJXjnbXWNxZwOCXhdoJlJti9OlkD4h4KM%3D&jwt=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc1NDQ5MDEyOCwibmJmIjoxNzU0NDg5ODI4LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.s3lXBXI7ohfxpMj2vWOCkOQNehf6uuEbd7E7UCR8CMM&response-content-disposition=attachment%3B%20filename%3Dboost-install.tar.gz&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 26968389 (26M) [application/octet-stream]
# Saving to: ‘/tmp/boost-install.tar.gz’
#
# /tmp/boost-install. 100%[===================>]  25.72M  35.8MB/s    in 0.7s
#
# 2025-08-06 14:17:09 (35.8 MB/s) - ‘/tmp/boost-install.tar.gz’ saved [26968389/26968389]
#
# ++ [[ /tmp/boost-install.tar.gz != skip ]]
# ++ tar -xzf /tmp/boost-install.tar.gz --strip-components=2 --directory=/usr/local
# ++ [[ /tmp/boost-install.tar.gz != skip ]]
# ++ ln -fs /usr/local/lib/libboost_atomic.so /usr/local/lib/libboost_atomic.so.1.88.0 /usr/local/lib/libboost_charconv.so /usr/local/lib/libboost_charconv.so.1.88.0 /usr/local/lib/libboost_chrono.so /usr/local/lib/libboost_chrono.so.1.88.0 /usr/local/lib/libboost_container.so /usr/local/lib/libboost_container.so.1.88.0 /usr/local/lib/libboost_context.so /usr/local/lib/libboost_context.so.1.88.0 /usr/local/lib/libboost_contract.so /usr/local/lib/libboost_contract.so.1.88.0 /usr/local/lib/libboost_coroutine.so /usr/local/lib/libboost_coroutine.so.1.88.0 /usr/local/lib/libboost_date_time.so /usr/local/lib/libboost_date_time.so.1.88.0 /usr/local/lib/libboost_fiber.so /usr/local/lib/libboost_fiber.so.1.88.0 /usr/local/lib/libboost_filesystem.so /usr/local/lib/libboost_filesystem.so.1.88.0 /usr/local/lib/libboost_graph.so /usr/local/lib/libboost_graph.so.1.88.0 /usr/local/lib/libboost_iostreams.so /usr/local/lib/libboost_iostreams.so.1.88.0 /usr/local/lib/libboost_json.a /usr/local/lib/libboost_json.so /usr/local/lib/libboost_json.so.1.88.0 /usr/local/lib/libboost_log_setup.so /usr/local/lib/libboost_log_setup.so.1.88.0 /usr/local/lib/libboost_log.so /usr/local/lib/libboost_log.so.1.88.0 /usr/local/lib/libboost_math_c99f.so /usr/local/lib/libboost_math_c99f.so.1.88.0 /usr/local/lib/libboost_math_c99l.so /usr/local/lib/libboost_math_c99l.so.1.88.0 /usr/local/lib/libboost_math_c99.so /usr/local/lib/libboost_math_c99.so.1.88.0 /usr/local/lib/libboost_math_tr1f.so /usr/local/lib/libboost_math_tr1f.so.1.88.0 /usr/local/lib/libboost_math_tr1l.so /usr/local/lib/libboost_math_tr1l.so.1.88.0 /usr/local/lib/libboost_math_tr1.so /usr/local/lib/libboost_math_tr1.so.1.88.0 /usr/local/lib/libboost_nowide.so /usr/local/lib/libboost_nowide.so.1.88.0 /usr/local/lib/libboost_numpy311.so /usr/local/lib/libboost_numpy311.so.1.88.0 /usr/local/lib/libboost_prg_exec_monitor.so /usr/local/lib/libboost_prg_exec_monitor.so.1.88.0 /usr/local/lib/libboost_process.so /usr/local/lib/libboost_process.so.1.88.0 /usr/local/lib/libboost_program_options.so /usr/local/lib/libboost_program_options.so.1.88.0 /usr/local/lib/libboost_python311.so /usr/local/lib/libboost_python311.so.1.88.0 /usr/local/lib/libboost_random.so /usr/local/lib/libboost_random.so.1.88.0 /usr/local/lib/libboost_regex.so /usr/local/lib/libboost_regex.so.1.88.0 /usr/local/lib/libboost_serialization.so /usr/local/lib/libboost_serialization.so.1.88.0 /usr/local/lib/libboost_stacktrace_addr2line.so /usr/local/lib/libboost_stacktrace_addr2line.so.1.88.0 /usr/local/lib/libboost_stacktrace_basic.so /usr/local/lib/libboost_stacktrace_basic.so.1.88.0 /usr/local/lib/libboost_stacktrace_from_exception.so /usr/local/lib/libboost_stacktrace_from_exception.so.1.88.0 /usr/local/lib/libboost_stacktrace_noop.so /usr/local/lib/libboost_stacktrace_noop.so.1.88.0 /usr/local/lib/libboost_system.so /usr/local/lib/libboost_system.so.1.88.0 /usr/local/lib/libboost_thread.so /usr/local/lib/libboost_thread.so.1.88.0 /usr/local/lib/libboost_timer.so /usr/local/lib/libboost_timer.so.1.88.0 /usr/local/lib/libboost_type_erasure.so /usr/local/lib/libboost_type_erasure.so.1.88.0 /usr/local/lib/libboost_unit_test_framework.so /usr/local/lib/libboost_unit_test_framework.so.1.88.0 /usr/local/lib/libboost_url.so /usr/local/lib/libboost_url.so.1.88.0 /usr/local/lib/libboost_wave.so /usr/local/lib/libboost_wave.so.1.88.0 /usr/local/lib/libboost_wserialization.so /usr/local/lib/libboost_wserialization.so.1.88.0 /usr/lib
# ++ mkdir -p /usr/local/share/fem-on-colab
# ++ touch /usr/local/share/fem-on-colab/boost.installed
# + SLEPC4PY_INSTALL_SCRIPT_PATH=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/c9ec872d/releases/slepc4py-install-release-real.sh
# + [[ https://github.com/fem-on-colab/fem-on-colab.github.io/raw/c9ec872d/releases/slepc4py-install-release-real.sh == http* ]]
# + SLEPC4PY_INSTALL_SCRIPT_DOWNLOAD=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/c9ec872d/releases/slepc4py-install-release-real.sh
# + SLEPC4PY_INSTALL_SCRIPT_PATH=/tmp/slepc4py-install.sh
# + [[ ! -f /tmp/slepc4py-install.sh ]]
# + wget https://github.com/fem-on-colab/fem-on-colab.github.io/raw/c9ec872d/releases/slepc4py-install-release-real.sh -O /tmp/slepc4py-install.sh
# --2025-08-06 14:17:10--  https://github.com/fem-on-colab/fem-on-colab.github.io/raw/c9ec872d/releases/slepc4py-install-release-real.sh
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/c9ec872d28ce1e9d0dc7fdc38dfa18a954ca0eb3/releases/slepc4py-install-release-real.sh [following]
# --2025-08-06 14:17:11--  https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/c9ec872d28ce1e9d0dc7fdc38dfa18a954ca0eb3/releases/slepc4py-install-release-real.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1758 (1.7K) [text/plain]
# Saving to: ‘/tmp/slepc4py-install.sh’
#
# /tmp/slepc4py-insta 100%[===================>]   1.72K  --.-KB/s    in 0s
#
# 2025-08-06 14:17:11 (45.6 MB/s) - ‘/tmp/slepc4py-install.sh’ saved [1758/1758]
#
# + source /tmp/slepc4py-install.sh
# ++ set -e
# ++ set -x
# ++ INSTALL_PREFIX=/usr/local
# +++ echo /usr/local
# +++ awk -F/ '{print NF-1}'
# ++ INSTALL_PREFIX_DEPTH=2
# ++ PROJECT_NAME=fem-on-colab
# ++ SHARE_PREFIX=/usr/local/share/fem-on-colab
# ++ SLEPC4PY_INSTALLED=/usr/local/share/fem-on-colab/slepc4py.installed
# ++ [[ ! -f /usr/local/share/fem-on-colab/slepc4py.installed ]]
# ++ PETSC4PY_INSTALL_SCRIPT_PATH=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/800fb238/releases/petsc4py-install-release-real.sh
# ++ [[ https://github.com/fem-on-colab/fem-on-colab.github.io/raw/800fb238/releases/petsc4py-install-release-real.sh == http* ]]
# ++ PETSC4PY_INSTALL_SCRIPT_DOWNLOAD=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/800fb238/releases/petsc4py-install-release-real.sh
# ++ PETSC4PY_INSTALL_SCRIPT_PATH=/tmp/petsc4py-install.sh
# ++ [[ ! -f /tmp/petsc4py-install.sh ]]
# ++ wget https://github.com/fem-on-colab/fem-on-colab.github.io/raw/800fb238/releases/petsc4py-install-release-real.sh -O /tmp/petsc4py-install.sh
# --2025-08-06 14:17:11--  https://github.com/fem-on-colab/fem-on-colab.github.io/raw/800fb238/releases/petsc4py-install-release-real.sh
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/800fb238844c19b1a69be53a70666d3ee91d9ab2/releases/petsc4py-install-release-real.sh [following]
# --2025-08-06 14:17:11--  https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/800fb238844c19b1a69be53a70666d3ee91d9ab2/releases/petsc4py-install-release-real.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1802 (1.8K) [text/plain]
# Saving to: ‘/tmp/petsc4py-install.sh’
#
# /tmp/petsc4py-insta 100%[===================>]   1.76K  --.-KB/s    in 0s
#
# 2025-08-06 14:17:12 (29.1 MB/s) - ‘/tmp/petsc4py-install.sh’ saved [1802/1802]
#
# ++ source /tmp/petsc4py-install.sh
# +++ set -e
# +++ set -x
# +++ INSTALL_PREFIX=/usr/local
# ++++ echo /usr/local
# ++++ awk -F/ '{print NF-1}'
# +++ INSTALL_PREFIX_DEPTH=2
# +++ PROJECT_NAME=fem-on-colab
# +++ SHARE_PREFIX=/usr/local/share/fem-on-colab
# +++ PETSC4PY_INSTALLED=/usr/local/share/fem-on-colab/petsc4py.installed
# +++ [[ ! -f /usr/local/share/fem-on-colab/petsc4py.installed ]]
# +++ H5PY_INSTALL_SCRIPT_PATH=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/97ae1ad0/releases/h5py-install.sh
# +++ [[ https://github.com/fem-on-colab/fem-on-colab.github.io/raw/97ae1ad0/releases/h5py-install.sh == http* ]]
# +++ H5PY_INSTALL_SCRIPT_DOWNLOAD=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/97ae1ad0/releases/h5py-install.sh
# +++ H5PY_INSTALL_SCRIPT_PATH=/tmp/h5py-install.sh
# +++ [[ ! -f /tmp/h5py-install.sh ]]
# +++ wget https://github.com/fem-on-colab/fem-on-colab.github.io/raw/97ae1ad0/releases/h5py-install.sh -O /tmp/h5py-install.sh
# --2025-08-06 14:17:12--  https://github.com/fem-on-colab/fem-on-colab.github.io/raw/97ae1ad0/releases/h5py-install.sh
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/97ae1ad02d3f7a919c35862cf357497a11411ce6/releases/h5py-install.sh [following]
# --2025-08-06 14:17:12--  https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/97ae1ad02d3f7a919c35862cf357497a11411ce6/releases/h5py-install.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1724 (1.7K) [text/plain]
# Saving to: ‘/tmp/h5py-install.sh’
#
# /tmp/h5py-install.s 100%[===================>]   1.68K  --.-KB/s    in 0s
#
# 2025-08-06 14:17:12 (40.8 MB/s) - ‘/tmp/h5py-install.sh’ saved [1724/1724]
#
# +++ source /tmp/h5py-install.sh
# ++++ set -e
# ++++ set -x
# ++++ INSTALL_PREFIX=/usr/local
# +++++ echo /usr/local
# +++++ awk -F/ '{print NF-1}'
# ++++ INSTALL_PREFIX_DEPTH=2
# ++++ PROJECT_NAME=fem-on-colab
# ++++ SHARE_PREFIX=/usr/local/share/fem-on-colab
# ++++ H5PY_INSTALLED=/usr/local/share/fem-on-colab/h5py.installed
# ++++ [[ ! -f /usr/local/share/fem-on-colab/h5py.installed ]]
# ++++ MPI4PY_INSTALL_SCRIPT_PATH=/tmp/mpi4py-install.sh
# ++++ [[ /tmp/mpi4py-install.sh == http* ]]
# ++++ source /tmp/mpi4py-install.sh
# +++++ set -e
# +++++ set -x
# +++++ INSTALL_PREFIX=/usr/local
# ++++++ echo /usr/local
# ++++++ awk -F/ '{print NF-1}'
# +++++ INSTALL_PREFIX_DEPTH=2
# +++++ PROJECT_NAME=fem-on-colab
# +++++ SHARE_PREFIX=/usr/local/share/fem-on-colab
# +++++ MPI4PY_INSTALLED=/usr/local/share/fem-on-colab/mpi4py.installed
# +++++ [[ ! -f /usr/local/share/fem-on-colab/mpi4py.installed ]]
# ++++ H5PY_ARCHIVE_PATH=https://github.com/fem-on-colab/fem-on-colab/releases/download/h5py-20250801-031334-211daac/h5py-install.tar.gz
# ++++ [[ https://github.com/fem-on-colab/fem-on-colab/releases/download/h5py-20250801-031334-211daac/h5py-install.tar.gz == http* ]]
# ++++ H5PY_ARCHIVE_DOWNLOAD=https://github.com/fem-on-colab/fem-on-colab/releases/download/h5py-20250801-031334-211daac/h5py-install.tar.gz
# ++++ H5PY_ARCHIVE_PATH=/tmp/h5py-install.tar.gz
# ++++ wget https://github.com/fem-on-colab/fem-on-colab/releases/download/h5py-20250801-031334-211daac/h5py-install.tar.gz -O /tmp/h5py-install.tar.gz
# --2025-08-06 14:17:12--  https://github.com/fem-on-colab/fem-on-colab/releases/download/h5py-20250801-031334-211daac/h5py-install.tar.gz
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/370599515/6c9e5291-f73a-4fb0-b308-cee980981497?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-08-06T15%3A01%3A05Z&rscd=attachment%3B+filename%3Dh5py-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-08-06T14%3A00%3A46Z&ske=2025-08-06T15%3A01%3A05Z&sks=b&skv=2018-11-09&sig=oQw2P%2Fdnqmil2V73EoXhMkVamBU5USYy2A8KOLYFonE%3D&jwt=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc1NDQ5MDEzMiwibmJmIjoxNzU0NDg5ODMyLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.ckq7puGwx0_0YpjN969huW-wdZ3bVQNsXvEyZRadQ18&response-content-disposition=attachment%3B%20filename%3Dh5py-install.tar.gz&response-content-type=application%2Foctet-stream [following]
# ...
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/370599515/db1d0bfa-008d-4dc6-8fe3-85deb75f7ed0?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-08-06T14%3A59%3A05Z&rscd=attachment%3B+filename%3Dslepc4py-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-08-06T13%3A58%3A37Z&ske=2025-08-06T14%3A59%3A05Z&sks=b&skv=2018-11-09&sig=1KWLtuAw2BKHtkoa203FQicIGHnKZNxbinuYmKufW0Y%3D&jwt=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc1NDQ5MDE1MiwibmJmIjoxNzU0NDg5ODUyLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.H-WSXNN-lciJjCSxtoILykPhNx6pw03wgbM_x9PcIm0&response-content-disposition=attachment%3B%20filename%3Dslepc4py-install.tar.gz&response-content-type=application%2Foctet-stream [following]
# --2025-08-06 14:17:32--  https://release-assets.githubusercontent.com/github-production-release-asset/370599515/db1d0bfa-008d-4dc6-8fe3-85deb75f7ed0?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-08-06T14%3A59%3A05Z&rscd=attachment%3B+filename%3Dslepc4py-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-08-06T13%3A58%3A37Z&ske=2025-08-06T14%3A59%3A05Z&sks=b&skv=2018-11-09&sig=1KWLtuAw2BKHtkoa203FQicIGHnKZNxbinuYmKufW0Y%3D&jwt=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc1NDQ5MDE1MiwibmJmIjoxNzU0NDg5ODUyLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.H-WSXNN-lciJjCSxtoILykPhNx6pw03wgbM_x9PcIm0&response-content-disposition=attachment%3B%20filename%3Dslepc4py-install.tar.gz&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19603832 (19M) [application/octet-stream]
# Saving to: ‘/tmp/slepc4py-install.tar.gz’
#
# /tmp/slepc4py-insta 100%[===================>]  18.70M  57.6MB/s    in 0.3s
#
# 2025-08-06 14:17:33 (57.6 MB/s) - ‘/tmp/slepc4py-install.tar.gz’ saved [19603832/19603832]
#
# ++ [[ /tmp/slepc4py-install.tar.gz != skip ]]
# ++ tar -xzf /tmp/slepc4py-install.tar.gz --strip-components=2 --directory=/usr/local
# ++ mkdir -p /usr/local/share/fem-on-colab
# ++ touch /usr/local/share/fem-on-colab/slepc4py.installed
# + FENICS_ARCHIVE_PATH=https://github.com/fem-on-colab/fem-on-colab/releases/download/fenics-20250802-021230-211daac-release-real/fenics-install.tar.gz
# + [[ https://github.com/fem-on-colab/fem-on-colab/releases/download/fenics-20250802-021230-211daac-release-real/fenics-install.tar.gz == http* ]]
# + FENICS_ARCHIVE_DOWNLOAD=https://github.com/fem-on-colab/fem-on-colab/releases/download/fenics-20250802-021230-211daac-release-real/fenics-install.tar.gz
# + FENICS_ARCHIVE_PATH=/tmp/fenics-install.tar.gz
# + wget https://github.com/fem-on-colab/fem-on-colab/releases/download/fenics-20250802-021230-211daac-release-real/fenics-install.tar.gz -O /tmp/fenics-install.tar.gz
# --2025-08-06 14:17:33--  https://github.com/fem-on-colab/fem-on-colab/releases/download/fenics-20250802-021230-211daac-release-real/fenics-install.tar.gz
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/370599515/8be6c012-ec28-4793-9521-d9b59a1d5fb4?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-08-06T14%3A58%3A57Z&rscd=attachment%3B+filename%3Dfenics-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-08-06T13%3A58%3A24Z&ske=2025-08-06T14%3A58%3A57Z&sks=b&skv=2018-11-09&sig=JAC3dI80RDeyfqMdR4OtWa8teGp9w1I9j%2BscHaXcvDo%3D&jwt=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc1NDQ5MDE1MywibmJmIjoxNzU0NDg5ODUzLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.mY6zK3_AEVhoigOXOjU64-5n386xwlvJrkIUUFj9ib4&response-content-disposition=attachment%3B%20filename%3Dfenics-install.tar.gz&response-content-type=application%2Foctet-stream [following]
# --2025-08-06 14:17:34--  https://release-assets.githubusercontent.com/github-production-release-asset/370599515/8be6c012-ec28-4793-9521-d9b59a1d5fb4?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-08-06T14%3A58%3A57Z&rscd=attachment%3B+filename%3Dfenics-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-08-06T13%3A58%3A24Z&ske=2025-08-06T14%3A58%3A57Z&sks=b&skv=2018-11-09&sig=JAC3dI80RDeyfqMdR4OtWa8teGp9w1I9j%2BscHaXcvDo%3D&jwt=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc1NDQ5MDE1MywibmJmIjoxNzU0NDg5ODUzLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.mY6zK3_AEVhoigOXOjU64-5n386xwlvJrkIUUFj9ib4&response-content-disposition=attachment%3B%20filename%3Dfenics-install.tar.gz&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 75613788 (72M) [application/octet-stream]
# Saving to: ‘/tmp/fenics-install.tar.gz’
#
# /tmp/fenics-install 100%[===================>]  72.11M  24.8MB/s    in 2.9s
#
# 2025-08-06 14:17:37 (24.8 MB/s) - ‘/tmp/fenics-install.tar.gz’ saved [75613788/75613788]
#
# + [[ /tmp/fenics-install.tar.gz != skip ]]
# + tar -xzf /tmp/fenics-install.tar.gz --strip-components=2 --directory=/usr/local
# + [[ /tmp/fenics-install.tar.gz != skip ]]
# + ln -fs /usr/local/lib/libdolfin.so /usr/local/lib/libdolfin.so.2019.2 /usr/local/lib/libdolfin.so.2019.2.0.dev0 /usr/lib
# + ln -fs /usr/local/lib/libmshr.so /usr/local/lib/libmshr.so.2019.2 /usr/local/lib/libmshr.so.2019.2.0.dev0 /usr/lib
# + mkdir -p /usr/local/share/fem-on-colab
# + touch /usr/local/share/fem-on-colab/fenics.installed
# + set +x
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ################################################################################
# #     This installation is offered by FEM on Colab, an open-source project     #
# #       developed and maintained at Università Cattolica del Sacro Cuore       #
# #   by Prof. Francesco Ballarin. Please see https://fem-on-colab.github.io/    #
# #       for more details, including a list of further available packages       #
# #       and how to sponsor the development or contribute to the project.       #
# #                                                                              #
# #   We are conducting an informal survey on FEM on Colab usage by our users.   #
# #   The survey is anonymous, and its compilation will typically only require   #
# #   a couple of minutes of your time. If you wish, give us your feedback at    #
# #                     https://forms.gle/36sZZWNvPpUv8XWr7                      #
# ################################################################################
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Cloning into 'master'...
# Receiving objects: 100% (2278/2278), 1.07 MiB | 1.53 MiB/s, done.
# Resolving deltas: 100% (1623/1623), done.
# Processing ./master
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: cbc.block
#   Building wheel for cbc.block (setup.py) ... done
#   Created wheel for cbc.block: filename=cbc.block-0.0.1-py3-none-any.whl size=75552 sha256=a225da0c8683fa26ec568cff1474fa89040e47143f4a53bafbc10356ccfd76c2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-4zhq0m76/wheels/cd/f0/e6/745748b4ace7d5ce46d8033c122723f8b938ed1f8e9cfe4163
# Successfully built cbc.block
# Installing collected packages: cbc.block
# Successfully installed cbc.block-0.0.1
# Cloning into 'fenics_ii'...
# remote: Enumerating objects: 2967, done.
# remote: Counting objects: 100% (519/519), done.
# remote: Compressing objects: 100% (263/263), done.
# remote: Total 2967 (delta 356), reused 380 (delta 256), pack-reused 2448 (from 1)
# Receiving objects: 100% (2967/2967), 2.85 MiB | 47.08 MiB/s, done.
# Resolving deltas: 100% (2130/2130), done.
# Processing ./fenics_ii
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: FEniCS_ii
#   Building wheel for FEniCS_ii (setup.py) ... done
#   Created wheel for FEniCS_ii: filename=FEniCS_ii-0.5-py3-none-any.whl size=128124 sha256=000dae7fc70ce653cd56f3b8f0e8f5291f3475304626f7ee5ab9df8c656fbaf8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-64jcx7f_/wheels/f7/5b/ca/dfd803b5317a6fc874ed615e9dd278c8e9d3f805adba56a208
# Successfully built FEniCS_ii
# Installing collected packages: FEniCS_ii
# Successfully installed FEniCS_ii-0.5
# Collecting vtk
#   Downloading vtk-9.5.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.5 kB)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from vtk) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->vtk) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->vtk) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->vtk) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->vtk) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->vtk) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->vtk) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->vtk) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->vtk) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->vtk) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->vtk) (1.17.0)
# Downloading vtk-9.5.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (112.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.1/112.1 MB 11.2 MB/s eta 0:00:00
# Installing collected packages: vtk
# Successfully installed vtk-9.5.0
# Cloning into 'graphnics'...
# remote: Enumerating objects: 975, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 975 (delta 19), reused 28 (delta 12), pack-reused 928 (from 1)
# Receiving objects: 100% (975/975), 9.79 MiB | 19.46 MiB/s, done.
# Resolving deltas: 100% (562/562), done.
# Processing ./graphnics
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: graphnics
#   Building wheel for graphnics (setup.py) ... done
#   Created wheel for graphnics: filename=graphnics-1-py3-none-any.whl size=30775 sha256=9852290a5b6731ea69b082997f789cc9bcda3e235a487bdf2a90ddd7008edd53
#   Stored in directory: /tmp/pip-ephem-wheel-cache-693jre_f/wheels/9d/0b/e5/4dcabab25a1aabd76405750af472ad87f1ab14adbaf9684626
# Successfully built graphnics
# Installing collected packages: graphnics
# Successfully installed graphnics-1
# Collecting meshio
#   Downloading meshio-5.3.5-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.11/dist-packages (from meshio) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from meshio) (13.9.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->meshio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->meshio) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->meshio) (0.1.2)
# Downloading meshio-5.3.5-py3-none-any.whl (166 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.2/166.2 kB 11.3 MB/s eta 0:00:00
# Installing collected packages: meshio
# Successfully installed meshio-5.3.5
# Collecting pyvista
#   Downloading pyvista-0.46.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: matplotlib>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from pyvista) (3.10.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from pyvista) (2.0.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from pyvista) (11.3.0)
# Requirement already satisfied: pooch in /usr/local/lib/python3.11/dist-packages (from pyvista) (1.8.2)
# Requirement already satisfied: scooby>=0.5.1 in /usr/local/lib/python3.11/dist-packages (from pyvista) (0.10.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from pyvista) (4.14.1)
# Requirement already satisfied: vtk!=9.4.0 in /usr/local/lib/python3.11/dist-packages (from pyvista) (9.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.1->pyvista) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.1->pyvista) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.1->pyvista) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.1->pyvista) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.1->pyvista) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.1->pyvista) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.1->pyvista) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch->pyvista) (4.3.8)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from pooch->pyvista) (2.32.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0.1->pyvista) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch->pyvista) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch->pyvista) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch->pyvista) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch->pyvista) (2025.7.14)
# Downloading pyvista-0.46.0-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 42.7 MB/s eta 0:00:00
# Installing collected packages: pyvista
# Successfully installed pyvista-0.46.0

# %%
# @title Convergence test: 3D-FEM,1D-dG time-dependent advection-diffusion

from math import gamma
from argparse import RawDescriptionHelpFormatter
from petsc4py import PETSc
from ast import Constant
from dolfin import *
from xii import *
import numpy as np
import time

conv_study3d = open("conv_study3d.txt", "w")
conv_study1d = open("conv_study1d.txt", "w")

H1_error_3d   = np.ones(6)
H1_rates_3d   = np.ones(6)
L2_error_3d   = np.ones(6)
L2_rates_3d   = np.ones(6)
err_interface     = np.ones(6)
rates_interface   = np.ones(6)
h_out             = np.ones(6)

H1_error_1d = np.ones(6)
H1_rates_1d = np.ones(6)
L2_error_1d = np.ones(6)
L2_rates_1d = np.ones(6)

kappa     = 1.0
gamma_in  = 1.0
gamma_out = 1.0

mesh_vec = [0,1,2,3,4]

T    = 1.0
#dt   = 0.1
#tpts = int(T/dt)
#inv_dt = Constant(1.0/dt)

for i in mesh_vec:
  ncell   = 4*(2**i)
  mesh_3d = BoxMesh(Point(-0.5,-0.5,-0.5),Point(0.5,0.5,0.5),ncell,ncell,ncell)
  radius  = 0.05
  dt      = 0.1/ncell
  inv_dt  = Constant(1.0/dt)
  tpts    = int(T/dt)

  # === Perimeter and Area ===
  D_perimeter = 2*np.pi*radius
  D_area = np.pi*(radius**2)

  # === Create Meshes ===
  Omega = MeshFunction("size_t",mesh_3d,1,0)
  CompiledSubDomain("near(x[0],0.0) && near(x[1],0.0)").mark(Omega,1)
  Lambda = EmbeddedMesh(Omega,1)
  Lambda_boundaries = MeshFunction("size_t", Lambda, Lambda.topology().dim() - 1, 0)
  CompiledSubDomain("near(x[2], -0.5)").mark(Lambda_boundaries, 1)
  CompiledSubDomain("near(x[2],  0.5)").mark(Lambda_boundaries, 2)

  # === Function Spaces ===
  V3 = FunctionSpace(mesh_3d, "CG", 1)
  V1 = FunctionSpace(Lambda, "DG", 1)
  W = [V3, V1]
  u3, u1 = map(TrialFunction, W)
  v3, v1 = map(TestFunction, W)

  # === Velocity terms ===
  q1 = Constant(1.0)
  q3 = as_vector((0,0,q1))

  # === Initial concentration ===
  cinlet = Expression("(sin(pi*x[2])+2)*t", degree=4, t=0.0)#Constant(1.0)


  # === Mesh Measures ===
  dxOmega = Measure("dx", domain=mesh_3d)
  dxLambda = Measure("dx", domain=Lambda)
  dsLambda = Measure("ds", domain=Lambda, subdomain_data=Lambda_boundaries)
  #dsLambda = Measure("ds", domain=Lambda)
  #N = FacetNormal(mesh_3d)
  n = FacetNormal(Lambda)
  h = CellDiameter(Lambda)
  alpha = Constant(50.0)
  epsilon = Constant(-1.0)
  perf1 = 1.0
  perf3 = 1.0

  # === Upwind ===
  #u1_up = u1('+')
  #v1_up = v1('-')
  #q3_con = Constant((0,0,q1))
  #q1_up = (dot(q3_con, n) + abs(dot(q3_con, n))) / 2.0
  q1_up = (q1 + abs(q1))/2.0 # works best, gets okay convergence - rates are off
#%BR this is silly: q1=1, so q1_up = q1 = 1

  # === Cylinder ===
  cylinder = Circle(radius=radius, degree=20)

  # === Averages ===
  u3_avg = Average(u3, Lambda, cylinder)
  v3_avg = Average(v3, Lambda, cylinder)

  # === Initialize time step ===
  uh3d_prev = interpolate(Expression('0.0',degree=1), V3)
  uh1d_prev = interpolate(Expression('0.0',degree=1), V1)

  r = Expression('sqrt(pow(x[0] - 0.0, 2)+ pow(x[1] - 0.0,2))', degree  = 7)

  # === Begin time-stepping ===
  t = 0.0
  for step in range(tpts):
    t += dt
    print(f"[INFO] Time step {step+1}/{tpts}, t = {t:.3}")

    cinlet.t = t
    # === Exact solutions ===

    u3_exact_expr = Expression('(r > radius ? (kappa/(1+kappa))*(1-radius*std::log(r/radius))*((sin(pi*x[2])+2)*t) : (kappa/(1+kappa))*((sin(pi*x[2])+2)*t))',
                              degree = 7,
                              radius = radius,
                              kappa = kappa ,
                              r = r,
                              t = t)
    u3_exact = interpolate(u3_exact_expr, V3)

    u1_exact_expr = Expression('(sin(pi*x[2])+2)*t', degree = 7, t=t)
    u1_exact = interpolate(u1_exact_expr, V1)

    vtkfile = File('u3_exact.pvd')
    vtkfile << u3_exact
    vtkfile = File('u1_exact.pvd')
    vtkfile << u1_exact

    # === Forcing terms ===
    f3 = Expression('(r > radius ? (kappa/(1+kappa))*(1-radius*std::log(r/radius))*(sin(pi*x[2])+2) + (kappa/(1+kappa))*(1-radius*std::log(r/radius))*pow(pi,2)*sin(pi*x[2])*t + (kappa/(1+kappa))*(1-radius*std::log(r/radius))*pi*t*q*cos(pi*x[2]) :(kappa/(1+kappa))*pow(pi,2)*sin(pi*x[2]))*t + (kappa/(1+kappa))*(sin(pi*x[2])+2 + (kappa/(1+kappa))*pi*t*q*cos(pi*x[2]))',
                    degree = 4,
                    kappa = kappa,
                    radius = radius,
                    area = D_area,
                    r = r,
                    t = t,
                    q = q1)

    f1 = Expression(
        'area * (sin(pi*x[2])+2)'                             # time derivative
        ' + area * pow(pi,2) * t * sin(pi*x[2])'               # diffusion
        ' + (kappa / (1 + kappa)) * perimeter * t * (sin(pi*x[2]) + 2)'  # coupling
        ' + area * pi * t * q * cos(pi*x[2])',                # advection
        degree=4,
        area=D_area,
        perimeter=D_perimeter,
        kappa=kappa,
        t=t,
        q=q1
    )

    # === Checks for force terms ===
    #f3_func = interpolate(f3, V3)
    #f1_func = interpolate(f1, V1)
    #File(f"f3_step{step:03d}.pvd") << f3_func
    #File(f"f1_step{step:03d}.pvd") << f1_func

    # === Variational Forms ===
    a00 = inv_dt * (inner(u3, v3) * dxOmega) + inner(grad(u3), grad(v3)) * dxOmega \
          + D_perimeter * kappa * inner(u3_avg, v3_avg) * dxLambda - inner(dot(q3,grad(u3)),v3) *dxOmega
    a01 = -kappa * D_perimeter * inner(u1, v3_avg) * dxLambda
    a10 = -kappa * D_perimeter * inner(u3_avg, v1) * dxLambda
    a11 = D_area * inv_dt * u1 * v1 * dxLambda \
        + D_area * inner(grad(u1), grad(v1)) * dxLambda \
        - D_area * inner(avg(grad(u1)), jump(v1, n)) * dS \
        - D_area * inner(avg(grad(v1)), jump(u1, n)) * dS \
        + (alpha/avg(h)) * jump(u1) * jump(v1) * dS \
        + kappa * D_perimeter * u1 * v1 * dxLambda \
        - D_area * q1 * u1 * v1.dx(2) * dxLambda \ #%BR: what is this term? we cannot write grad(u1)?
        + D_area * jump(v1) * (q1_up * u1('+') - q1_up * u1('-')) * dS + D_area * q1_up * u1 * v1 * dsLambda(2)
        #%BR: + D_area * jump(v1) * (q1_up * u1('+') - q1_up * u1('-')) * dS + D_area * q1 * u1 * v1 * dsLambda(2)

    #% BR: question: dS is only on interior nodes? are we sure?
    #% BR: what does this term (q1_up * u1('+') - q1_up * u1('-')) do?



    L0 = inner(f3, v3) * dxOmega + inv_dt * (inner(uh3d_prev, v3) * dxOmega)
    L1 = inner(f1, v1) * dxLambda \
        + D_area * inv_dt * uh1d_prev * v1 * dxLambda \
        + D_area * q1_up * cinlet * v1 * dsLambda(1)
        #%BR:   + D_area * q1 * cinlet * v1 * dsLambda(1)  #%BR: use q1 instead of q1_up


    a = [[a00, a01], [a10, a11]]
    L = [L0, L1]

    bc3d = DirichletBC(V3, u3_exact, "on_boundary")
    W_bcs = [bc3d, []]  # No Dirichlet BCs on 1D

    A, b = map(ii_assemble, (a, L))
    A, b = apply_bc(A, b, W_bcs)
    A, b = map(ii_convert, (A, b))

    solver = PETScKrylovSolver()
    solver.set_operators(A, A)
    ksp = solver.ksp()

    opts = PETSc.Options()
    opts.setValue('ksp_type', 'gmres')
    opts.setValue('ksp_norm_type', 'unpreconditioned')
    opts.setValue('ksp_atol', 1E-14)
    opts.setValue('ksp_rtol', 1E-30)
    opts.setValue('ksp_monitor_true_residual', None)
    opts.setValue('pc_type', 'hypre')
    ksp.setFromOptions()

    x = b.copy()
    solver.solve(A,x,b)

    wh = ii_Function(W)
    wh.vector()[:] = x
    uh3d, uh1d = wh

    uh3d_prev.assign(uh3d)
    uh1d_prev.assign(uh1d)

    avg_uh3d = Average(uh3d, Lambda, cylinder)
    avg_u3d_exact = Average(u3_exact, Lambda, cylinder)

    # === Store Model Predictions ===
    vtkfile = File('3d_Prediction.pvd')
    vtkfile << uh3d

    vtkfile = File('1d_Prediction.pvd')
    vtkfile << uh1d


  # === Computer Errors ===
  h_out[i] =uh3d.function_space().mesh().hmax()
  H1_error_3d[i] = errornorm(u3_exact_expr, uh3d, 'H1')
  L2_error_3d[i] = errornorm(u3_exact_expr, uh3d, 'L2')
  err_interface[i] = 1.0
  H1_rates_3d[i] = ln(H1_error_3d[i]/H1_error_3d[i-1])/ln(h_out[i]/h_out[i-1])
  L2_rates_3d[i] = ln(L2_error_3d[i]/L2_error_3d[i-1])/ln(h_out[i]/h_out[i-1])
  rates_interface[i] = ln(err_interface[i]/err_interface[i-1])/ln(h_out[i]/h_out[i-1])

  H1_error_1d[i] = errornorm(u1_exact_expr, uh1d, 'H1')
  L2_error_1d[i] = errornorm(u1_exact_expr, uh1d, 'L2')
  H1_rates_1d[i] = ln(H1_error_1d[i]/H1_error_1d[i-1])/ln(h_out[i]/h_out[i-1])
  L2_rates_1d[i] = ln(L2_error_1d[i]/L2_error_1d[i-1])/ln(h_out[i]/h_out[i-1])

  print(i,"{:.3e}".format(h_out[i]),"{:.3e}".format(H1_error_3d[i]), "{:.3e}".format(H1_rates_3d[i]), "{:.3e}".format(err_interface[i]),"{:.3e}".format(rates_interface[i]), "{:.3e}".format(L2_error_3d[i]),"{:.3e}".format(L2_rates_3d[i]),  file= conv_study3d,flush = True)
  print(i,"{:.3e}".format(ncell),"{:.3e}".format(H1_error_1d[i]), "{:.3e}".format(H1_rates_1d[i]), "{:.3e}".format(L2_error_1d[i]),"{:.3e}".format(L2_rates_1d[i]),  file= conv_study1d,flush = True)
