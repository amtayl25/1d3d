# %% [markdown]
# <a href="https://colab.research.google.com/github/amtayl25/1d3d/blob/main/AdvDiff_DG_Bif.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Install required libraries (try-catch safe)
"""
NOTE: You can save the Docker image state after running this block so that you don't have to run it every time you start a new environment.
"""
import os, re

def replace_in_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()

    # Replace 'ufl' with 'ufl_legacy'
    content = re.sub(r'\bufl\b', 'ufl_legacy', content)

    with open(file_path, 'w', encoding='utf-8') as file:
        file.write(content)

def process_directory(directory):
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith('.py'):
                file_path = os.path.join(root, file)
                replace_in_file(file_path)

# ipywidgets
try:
    import ipywidgets
except ImportError:
    # !pip install ipywidgets

# dolfin
try:
    import dolfin
except ImportError:
    # !wget "https://fem-on-colab.github.io/releases/fenics-install-release-real.sh" -O "/tmp/fenics-install.sh" && bash "/tmp/fenics-install.sh"
    import dolfin

# block
try:
    import block
except ImportError:
    # !git clone "https://bitbucket.org/fenics-apps/cbc.block/src/master/"
    # !pip install master/

# fenics_ii
try:
    import xii
except ImportError:
    # !git clone "https://github.com/MiroK/fenics_ii"
    process_directory("fenics_ii/")
    # !pip install fenics_ii/

# vtk
try:
    import vtk
except ImportError:
    # !pip install vtk

# graphnics
try:
    import graphnics
except ImportError:
    # !git clone "https://github.com/IngeborgGjerde/graphnics"
    # !pip install graphnics/

# meshio
try:
    import meshio
except ImportError:
    # !pip install meshio

# pyvista
try:
    import pyvista
except ImportError:
    # !pip install pyvista
# Out:
# --2026-01-09 16:26:01--  https://fem-on-colab.github.io/releases/fenics-install-release-real.sh
# Resolving fem-on-colab.github.io (fem-on-colab.github.io)... 185.199.109.153, 185.199.111.153, 185.199.110.153, ...
# Connecting to fem-on-colab.github.io (fem-on-colab.github.io)|185.199.109.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4180 (4.1K) [application/x-sh]
# Saving to: ‘/tmp/fenics-install.sh’
#
# /tmp/fenics-install 100%[===================>]   4.08K  --.-KB/s    in 0s
#
# 2026-01-09 16:26:01 (49.2 MB/s) - ‘/tmp/fenics-install.sh’ saved [4180/4180]
#
# + INSTALL_PREFIX=/usr/local
# ++ echo /usr/local
# ++ awk -F/ '{print NF-1}'
# + INSTALL_PREFIX_DEPTH=2
# + PROJECT_NAME=fem-on-colab
# + SHARE_PREFIX=/usr/local/share/fem-on-colab
# + FENICS_INSTALLED=/usr/local/share/fem-on-colab/fenics.installed
# + [[ ! -f /usr/local/share/fem-on-colab/fenics.installed ]]
# + PYBIND11_INSTALL_SCRIPT_PATH=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/f34c0f89/releases/pybind11-install.sh
# + [[ https://github.com/fem-on-colab/fem-on-colab.github.io/raw/f34c0f89/releases/pybind11-install.sh == http* ]]
# + PYBIND11_INSTALL_SCRIPT_DOWNLOAD=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/f34c0f89/releases/pybind11-install.sh
# + PYBIND11_INSTALL_SCRIPT_PATH=/tmp/pybind11-install.sh
# + [[ ! -f /tmp/pybind11-install.sh ]]
# + wget https://github.com/fem-on-colab/fem-on-colab.github.io/raw/f34c0f89/releases/pybind11-install.sh -O /tmp/pybind11-install.sh
# --2026-01-09 16:26:01--  https://github.com/fem-on-colab/fem-on-colab.github.io/raw/f34c0f89/releases/pybind11-install.sh
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/f34c0f8965f5d749007818d4290584726e68b710/releases/pybind11-install.sh [following]
# --2026-01-09 16:26:01--  https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/f34c0f8965f5d749007818d4290584726e68b710/releases/pybind11-install.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1800 (1.8K) [text/plain]
# Saving to: ‘/tmp/pybind11-install.sh’
#
# /tmp/pybind11-insta 100%[===================>]   1.76K  --.-KB/s    in 0s
#
# 2026-01-09 16:26:01 (24.5 MB/s) - ‘/tmp/pybind11-install.sh’ saved [1800/1800]
#
# + source /tmp/pybind11-install.sh
# ++ set -e
# ++ set -x
# ++ INSTALL_PREFIX=/usr/local
# +++ awk -F/ '{print NF-1}'
# +++ echo /usr/local
# ++ INSTALL_PREFIX_DEPTH=2
# ++ PROJECT_NAME=fem-on-colab
# ++ SHARE_PREFIX=/usr/local/share/fem-on-colab
# ++ PYBIND11_INSTALLED=/usr/local/share/fem-on-colab/pybind11.installed
# ++ [[ ! -f /usr/local/share/fem-on-colab/pybind11.installed ]]
# ++ MPI4PY_INSTALL_SCRIPT_PATH=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/81c13b0b/releases/mpi4py-install.sh
# ++ [[ https://github.com/fem-on-colab/fem-on-colab.github.io/raw/81c13b0b/releases/mpi4py-install.sh == http* ]]
# ++ MPI4PY_INSTALL_SCRIPT_DOWNLOAD=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/81c13b0b/releases/mpi4py-install.sh
# ++ MPI4PY_INSTALL_SCRIPT_PATH=/tmp/mpi4py-install.sh
# ++ [[ ! -f /tmp/mpi4py-install.sh ]]
# ++ wget https://github.com/fem-on-colab/fem-on-colab.github.io/raw/81c13b0b/releases/mpi4py-install.sh -O /tmp/mpi4py-install.sh
# --2026-01-09 16:26:01--  https://github.com/fem-on-colab/fem-on-colab.github.io/raw/81c13b0b/releases/mpi4py-install.sh
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/81c13b0bbfba7d36f4abbd737b5ac138d26ad605/releases/mpi4py-install.sh [following]
# --2026-01-09 16:26:02--  https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/81c13b0bbfba7d36f4abbd737b5ac138d26ad605/releases/mpi4py-install.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2583 (2.5K) [text/plain]
# Saving to: ‘/tmp/mpi4py-install.sh’
#
# /tmp/mpi4py-install 100%[===================>]   2.52K  --.-KB/s    in 0s
#
# 2026-01-09 16:26:02 (28.9 MB/s) - ‘/tmp/mpi4py-install.sh’ saved [2583/2583]
#
# ++ source /tmp/mpi4py-install.sh
# +++ set -e
# +++ set -x
# +++ INSTALL_PREFIX=/usr/local
# ++++ echo /usr/local
# ++++ awk -F/ '{print NF-1}'
# +++ INSTALL_PREFIX_DEPTH=2
# +++ PROJECT_NAME=fem-on-colab
# +++ SHARE_PREFIX=/usr/local/share/fem-on-colab
# +++ MPI4PY_INSTALLED=/usr/local/share/fem-on-colab/mpi4py.installed
# +++ [[ ! -f /usr/local/share/fem-on-colab/mpi4py.installed ]]
# +++ GCC_INSTALL_SCRIPT_PATH=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/4643fa9f/releases/gcc-install.sh
# +++ [[ https://github.com/fem-on-colab/fem-on-colab.github.io/raw/4643fa9f/releases/gcc-install.sh == http* ]]
# +++ GCC_INSTALL_SCRIPT_DOWNLOAD=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/4643fa9f/releases/gcc-install.sh
# +++ GCC_INSTALL_SCRIPT_PATH=/tmp/gcc-install.sh
# +++ [[ ! -f /tmp/gcc-install.sh ]]
# +++ wget https://github.com/fem-on-colab/fem-on-colab.github.io/raw/4643fa9f/releases/gcc-install.sh -O /tmp/gcc-install.sh
# --2026-01-09 16:26:02--  https://github.com/fem-on-colab/fem-on-colab.github.io/raw/4643fa9f/releases/gcc-install.sh
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/4643fa9fcf45e485f1f8492721f22a0a5d836b50/releases/gcc-install.sh [following]
# --2026-01-09 16:26:02--  https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/4643fa9fcf45e485f1f8492721f22a0a5d836b50/releases/gcc-install.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8358 (8.2K) [text/plain]
# Saving to: ‘/tmp/gcc-install.sh’
#
# /tmp/gcc-install.sh 100%[===================>]   8.16K  --.-KB/s    in 0s
#
# 2026-01-09 16:26:02 (21.7 MB/s) - ‘/tmp/gcc-install.sh’ saved [8358/8358]
#
# +++ source /tmp/gcc-install.sh
# ++++ set -e
# ++++ set -x
# ++++ INSTALL_PREFIX=/usr/local
# +++++ echo /usr/local
# +++++ awk -F/ '{print NF-1}'
# ++++ INSTALL_PREFIX_DEPTH=2
# ++++ PROJECT_NAME=fem-on-colab
# ++++ SHARE_PREFIX=/usr/local/share/fem-on-colab
# ++++ GCC_INSTALLED=/usr/local/share/fem-on-colab/gcc.installed
# ++++ [[ ! -L /usr/local/lib64 ]]
# ++++ [[ -e /usr/local/lib64 ]]
# ++++ ln -s /usr/local/lib /usr/local/lib64
# ++++ [[ ! -L /usr/local/lib64 ]]
# ++++ [[ ! -d /usr/local/lib64 ]]
# ++++ [[ ! -f /usr/local/share/fem-on-colab/gcc.installed ]]
# ++++ GCC_ARCHIVE_PATH=https://github.com/fem-on-colab/fem-on-colab/releases/download/gcc-20260105-080727-a62e748/gcc-install.tar.gz
# ++++ [[ https://github.com/fem-on-colab/fem-on-colab/releases/download/gcc-20260105-080727-a62e748/gcc-install.tar.gz == http* ]]
# ++++ GCC_ARCHIVE_DOWNLOAD=https://github.com/fem-on-colab/fem-on-colab/releases/download/gcc-20260105-080727-a62e748/gcc-install.tar.gz
# ++++ GCC_ARCHIVE_PATH=/tmp/gcc-install.tar.gz
# ++++ wget https://github.com/fem-on-colab/fem-on-colab/releases/download/gcc-20260105-080727-a62e748/gcc-install.tar.gz -O /tmp/gcc-install.tar.gz
# --2026-01-09 16:26:02--  https://github.com/fem-on-colab/fem-on-colab/releases/download/gcc-20260105-080727-a62e748/gcc-install.tar.gz
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/370599515/6e9d8a5e-1bb8-41c8-ba08-2a04da0accde?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-01-09T17%3A00%3A37Z&rscd=attachment%3B+filename%3Dgcc-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-01-09T16%3A00%3A20Z&ske=2026-01-09T17%3A00%3A37Z&sks=b&skv=2018-11-09&sig=gVotqaRbyoboDvIFNzfI7Ck9h%2BEE5ercjgmhj6PD9Lw%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2Nzk3OTU2MiwibmJmIjoxNzY3OTc1OTYyLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.mNpxJ_Rul8WZnBoZfCZd-eO_nYiZ8Fa6WiZ0z8NhB2g&response-content-disposition=attachment%3B%20filename%3Dgcc-install.tar.gz&response-content-type=application%2Foctet-stream [following]
# --2026-01-09 16:26:02--  https://release-assets.githubusercontent.com/github-production-release-asset/370599515/6e9d8a5e-1bb8-41c8-ba08-2a04da0accde?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-01-09T17%3A00%3A37Z&rscd=attachment%3B+filename%3Dgcc-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-01-09T16%3A00%3A20Z&ske=2026-01-09T17%3A00%3A37Z&sks=b&skv=2018-11-09&sig=gVotqaRbyoboDvIFNzfI7Ck9h%2BEE5ercjgmhj6PD9Lw%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2Nzk3OTU2MiwibmJmIjoxNzY3OTc1OTYyLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.mNpxJ_Rul8WZnBoZfCZd-eO_nYiZ8Fa6WiZ0z8NhB2g&response-content-disposition=attachment%3B%20filename%3Dgcc-install.tar.gz&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 688003816 (656M) [application/octet-stream]
# Saving to: ‘/tmp/gcc-install.tar.gz’
#
# /tmp/gcc-install.ta 100%[===================>] 656.13M   143MB/s    in 4.2s
#
# 2026-01-09 16:26:06 (156 MB/s) - ‘/tmp/gcc-install.tar.gz’ saved [688003816/688003816]
#
# ++++ [[ /tmp/gcc-install.tar.gz != skip ]]
# ++++ tar -xzf /tmp/gcc-install.tar.gz --strip-components=2 --directory=/usr/local
# ++++ apt install -y -qq zlib1g-dev
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-2ubuntu9.2).
# zlib1g-dev set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 1 not upgraded.
# ++++ [[ /tmp/gcc-install.tar.gz != skip ]]
# ++++ for LEGACY_GPP in /usr/bin/g++-*
# +++++ /usr/bin/g++-11 -dumpversion
# ++++ LEGACY_GCC_VERSION=11
# ++++ update-alternatives --install /usr/bin/g++ g++ /usr/bin/g++-11 11
# update-alternatives: using /usr/bin/g++-11 to provide /usr/bin/g++ (g++) in auto mode
# ++++ update-alternatives --install /usr/bin/gcc gcc /usr/bin/gcc-11 11
# update-alternatives: using /usr/bin/gcc-11 to provide /usr/bin/gcc (gcc) in auto mode
# ++++ update-alternatives --install /usr/bin/gcc-ar gcc-ar /usr/bin/gcc-ar-11 11
# update-alternatives: using /usr/bin/gcc-ar-11 to provide /usr/bin/gcc-ar (gcc-ar) in auto mode
# ++++ update-alternatives --install /usr/bin/gcc-nm gcc-nm /usr/bin/gcc-nm-11 11
# update-alternatives: using /usr/bin/gcc-nm-11 to provide /usr/bin/gcc-nm (gcc-nm) in auto mode
# ++++ update-alternatives --install /usr/bin/gcc-ranlib gcc-ranlib /usr/bin/gcc-ranlib-11 11
# update-alternatives: using /usr/bin/gcc-ranlib-11 to provide /usr/bin/gcc-ranlib (gcc-ranlib) in auto mode
# ++++ update-alternatives --install /usr/bin/x86_64-linux-gnu-g++ x86_64-linux-gnu-g++ /usr/bin/x86_64-linux-gnu-g++-11 11
# update-alternatives: using /usr/bin/x86_64-linux-gnu-g++-11 to provide /usr/bin/x86_64-linux-gnu-g++ (x86_64-linux-gnu-g++) in auto mode
# ++++ update-alternatives --install /usr/bin/x86_64-linux-gnu-gcc x86_64-linux-gnu-gcc /usr/bin/x86_64-linux-gnu-gcc-11 11
# update-alternatives: using /usr/bin/x86_64-linux-gnu-gcc-11 to provide /usr/bin/x86_64-linux-gnu-gcc (x86_64-linux-gnu-gcc) in auto mode
# ++++ update-alternatives --install /usr/bin/x86_64-linux-gnu-gcc-ar x86_64-linux-gnu-gcc-ar /usr/bin/x86_64-linux-gnu-gcc-ar-11 11
# update-alternatives: using /usr/bin/x86_64-linux-gnu-gcc-ar-11 to provide /usr/bin/x86_64-linux-gnu-gcc-ar (x86_64-linux-gnu-gcc-ar) in auto mode
# ++++ update-alternatives --install /usr/bin/x86_64-linux-gnu-gcc-nm x86_64-linux-gnu-gcc-nm /usr/bin/x86_64-linux-gnu-gcc-nm-11 11
# update-alternatives: using /usr/bin/x86_64-linux-gnu-gcc-nm-11 to provide /usr/bin/x86_64-linux-gnu-gcc-nm (x86_64-linux-gnu-gcc-nm) in auto mode
# ++++ update-alternatives --install /usr/bin/x86_64-linux-gnu-gcc-ranlib x86_64-linux-gnu-gcc-ranlib /usr/bin/x86_64-linux-gnu-gcc-ranlib-11 11
# update-alternatives: using /usr/bin/x86_64-linux-gnu-gcc-ranlib-11 to provide /usr/bin/x86_64-linux-gnu-gcc-ranlib (x86_64-linux-gnu-gcc-ranlib) in auto mode
# +++++ /usr/local/bin/g++ -dumpversion
# ++++ GCC_VERSION=12
# ++++ update-alternatives --install /usr/bin/g++ g++ /usr/local/bin/g++-12 12
# update-alternatives: using /usr/local/bin/g++-12 to provide /usr/bin/g++ (g++) in auto mode
# ++++ update-alternatives --install /usr/bin/gcc gcc /usr/local/bin/gcc-12 12
# update-alternatives: using /usr/local/bin/gcc-12 to provide /usr/bin/gcc (gcc) in auto mode
# ++++ update-alternatives --install /usr/bin/gcc-ar gcc-ar /usr/local/bin/gcc-ar-12 12
# update-alternatives: using /usr/local/bin/gcc-ar-12 to provide /usr/bin/gcc-ar (gcc-ar) in auto mode
# ++++ update-alternatives --install /usr/bin/gcc-nm gcc-nm /usr/local/bin/gcc-nm-12 12
# update-alternatives: using /usr/local/bin/gcc-nm-12 to provide /usr/bin/gcc-nm (gcc-nm) in auto mode
# ++++ update-alternatives --install /usr/bin/gcc-ranlib gcc-ranlib /usr/local/bin/gcc-ranlib-12 12
# update-alternatives: using /usr/local/bin/gcc-ranlib-12 to provide /usr/bin/gcc-ranlib (gcc-ranlib) in auto mode
# ++++ update-alternatives --install /usr/bin/gfortran gfortran /usr/local/bin/gfortran-12 12
# update-alternatives: using /usr/local/bin/gfortran-12 to provide /usr/bin/gfortran (gfortran) in auto mode
# ++++ update-alternatives --install /usr/bin/x86_64-linux-gnu-g++ x86_64-linux-gnu-g++ /usr/local/bin/x86_64-linux-gnu-g++-12 12
# update-alternatives: using /usr/local/bin/x86_64-linux-gnu-g++-12 to provide /usr/bin/x86_64-linux-gnu-g++ (x86_64-linux-gnu-g++) in auto mode
# ++++ update-alternatives --install /usr/bin/x86_64-linux-gnu-gcc x86_64-linux-gnu-gcc /usr/local/bin/x86_64-linux-gnu-gcc-12 12
# update-alternatives: using /usr/local/bin/x86_64-linux-gnu-gcc-12 to provide /usr/bin/x86_64-linux-gnu-gcc (x86_64-linux-gnu-gcc) in auto mode
# ++++ update-alternatives --install /usr/bin/x86_64-linux-gnu-gcc-ar x86_64-linux-gnu-gcc-ar /usr/local/bin/x86_64-linux-gnu-gcc-ar-12 12
# update-alternatives: using /usr/local/bin/x86_64-linux-gnu-gcc-ar-12 to provide /usr/bin/x86_64-linux-gnu-gcc-ar (x86_64-linux-gnu-gcc-ar) in auto mode
# ++++ update-alternatives --install /usr/bin/x86_64-linux-gnu-gcc-nm x86_64-linux-gnu-gcc-nm /usr/local/bin/x86_64-linux-gnu-gcc-nm-12 12
# update-alternatives: using /usr/local/bin/x86_64-linux-gnu-gcc-nm-12 to provide /usr/bin/x86_64-linux-gnu-gcc-nm (x86_64-linux-gnu-gcc-nm) in auto mode
# ++++ update-alternatives --install /usr/bin/x86_64-linux-gnu-gcc-ranlib x86_64-linux-gnu-gcc-ranlib /usr/local/bin/x86_64-linux-gnu-gcc-ranlib-12 12
# update-alternatives: using /usr/local/bin/x86_64-linux-gnu-gcc-ranlib-12 to provide /usr/bin/x86_64-linux-gnu-gcc-ranlib (x86_64-linux-gnu-gcc-ranlib) in auto mode
# ++++ update-alternatives --set g++ /usr/local/bin/g++-12
# ++++ update-alternatives --set gcc /usr/local/bin/gcc-12
# ++++ update-alternatives --set gcc-ar /usr/local/bin/gcc-ar-12
# ++++ update-alternatives --set gcc-nm /usr/local/bin/gcc-nm-12
# ++++ update-alternatives --set gcc-ranlib /usr/local/bin/gcc-ranlib-12
# ++++ update-alternatives --set gfortran /usr/local/bin/gfortran-12
# ++++ update-alternatives --set x86_64-linux-gnu-g++ /usr/local/bin/x86_64-linux-gnu-g++-12
# ++++ update-alternatives --set x86_64-linux-gnu-gcc /usr/local/bin/x86_64-linux-gnu-gcc-12
# ++++ update-alternatives --set x86_64-linux-gnu-gcc-ar /usr/local/bin/x86_64-linux-gnu-gcc-ar-12
# ++++ update-alternatives --set x86_64-linux-gnu-gcc-nm /usr/local/bin/x86_64-linux-gnu-gcc-nm-12
# ++++ update-alternatives --set x86_64-linux-gnu-gcc-ranlib /usr/local/bin/x86_64-linux-gnu-gcc-ranlib-12
# ++++ [[ /tmp/gcc-install.tar.gz != skip ]]
# +++++ which python3
# ++++ PYTHON_EXEC=/usr/bin/python3
# +++++ dirname /usr/bin/python3
# ++++ PYTHON_EXEC_DIR=/usr/bin
# +++++ objdump -x /usr/bin/python3
# +++++ grep 'R.*PATH'
# +++++ sed 's|R.*PATH||g'
# +++++ sed 's| ||g'
# +++++ sed 's|$ORIGIN|/usr/bin|g'
# ++++ PYTHON_RPATH=
# ++++ [[ -z '' ]]
# ++++ PYTHON_RPATH=/usr/lib/x86_64-linux-gnu
# ++++ INSTALL_PREFIX_RPATH=/usr/local/lib
# ++++ [[ -L /usr/lib/x86_64-linux-gnu/libstdc++.so ]]
# +++++ basename /usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.30
# ++++ LIBSTDCXX_SYSTEM_VERSION=libstdc++.so.6.0.30
# +++++ basename /usr/local/lib/libstdc++.so.6.0.30 /usr/local/lib/libstdc++.so.6.0.30-gdb.py
# ++++ LIBSTDCXX_INSTALL_PREFIX_VERSION=libstdc++.so.6.0.30
# ++++ [[ libstdc++.so.6.0.30 != \l\i\b\s\t\d\c\+\+\.\s\o\.\6\.\0\.\3\0 ]]
# ++++ mkdir -p /usr/local/share/fem-on-colab
# ++++ touch /usr/local/share/fem-on-colab/gcc.installed
# +++ MPI4PY_ARCHIVE_PATH=https://github.com/fem-on-colab/fem-on-colab/releases/download/mpi4py-20260105-083057-a62e748/mpi4py-install.tar.gz
# +++ [[ https://github.com/fem-on-colab/fem-on-colab/releases/download/mpi4py-20260105-083057-a62e748/mpi4py-install.tar.gz == http* ]]
# +++ MPI4PY_ARCHIVE_DOWNLOAD=https://github.com/fem-on-colab/fem-on-colab/releases/download/mpi4py-20260105-083057-a62e748/mpi4py-install.tar.gz
# +++ MPI4PY_ARCHIVE_PATH=/tmp/mpi4py-install.tar.gz
# +++ wget https://github.com/fem-on-colab/fem-on-colab/releases/download/mpi4py-20260105-083057-a62e748/mpi4py-install.tar.gz -O /tmp/mpi4py-install.tar.gz
# --2026-01-09 16:26:34--  https://github.com/fem-on-colab/fem-on-colab/releases/download/mpi4py-20260105-083057-a62e748/mpi4py-install.tar.gz
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/370599515/b948d149-ddee-4902-81ed-74888dab1559?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-01-09T17%3A02%3A51Z&rscd=attachment%3B+filename%3Dmpi4py-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-01-09T16%3A02%3A12Z&ske=2026-01-09T17%3A02%3A51Z&sks=b&skv=2018-11-09&sig=ybW4oSgJ7z%2Bq2eacAR7QSXeYr%2FOHog9FjThKh5CTNjI%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2Nzk3Nzc5NCwibmJmIjoxNzY3OTc1OTk0LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.PqkKtqEgxFznMdkFtPikqlqZmLTEJ4aHz4F7-haTHBw&response-content-disposition=attachment%3B%20filename%3Dmpi4py-install.tar.gz&response-content-type=application%2Foctet-stream [following]
# --2026-01-09 16:26:34--  https://release-assets.githubusercontent.com/github-production-release-asset/370599515/b948d149-ddee-4902-81ed-74888dab1559?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-01-09T17%3A02%3A51Z&rscd=attachment%3B+filename%3Dmpi4py-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-01-09T16%3A02%3A12Z&ske=2026-01-09T17%3A02%3A51Z&sks=b&skv=2018-11-09&sig=ybW4oSgJ7z%2Bq2eacAR7QSXeYr%2FOHog9FjThKh5CTNjI%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2Nzk3Nzc5NCwibmJmIjoxNzY3OTc1OTk0LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.PqkKtqEgxFznMdkFtPikqlqZmLTEJ4aHz4F7-haTHBw&response-content-disposition=attachment%3B%20filename%3Dmpi4py-install.tar.gz&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14175702 (14M) [application/octet-stream]
# Saving to: ‘/tmp/mpi4py-install.tar.gz’
#
# /tmp/mpi4py-install 100%[===================>]  13.52M  --.-KB/s    in 0.04s
#
# 2026-01-09 16:26:34 (322 MB/s) - ‘/tmp/mpi4py-install.tar.gz’ saved [14175702/14175702]
#
# +++ [[ /tmp/mpi4py-install.tar.gz != skip ]]
# +++ tar -xzf /tmp/mpi4py-install.tar.gz --strip-components=2 --directory=/usr/local
# +++ [[ /tmp/mpi4py-install.tar.gz != skip ]]
# +++ command -v mpicc
# /usr/local/bin/mpicc
# +++ [[ /tmp/mpi4py-install.tar.gz != skip ]]
# +++ MPI_LIBS=('libhwloc*.so*' 'libmpi*.so*' 'libopen-pal*.so*' 'libpmix*.so*' 'libprrte*.so*')
# +++ for MPI_LIB in "${MPI_LIBS[@]}"
# +++ rm -f '/usr/lib/libhwloc*.so*'
# +++ rm -f /usr/lib/x86_64-linux-gnu/libhwloc.so /usr/lib/x86_64-linux-gnu/libhwloc.so.15 /usr/lib/x86_64-linux-gnu/libhwloc.so.15.5.2
# +++ ln -fs /usr/local/lib/libhwloc.so /usr/local/lib/libhwloc.so.15 /usr/local/lib/libhwloc.so.15.5.3 /usr/local/lib/libhwloc.so.15.8.1 /usr/lib
# +++ for MPI_LIB in "${MPI_LIBS[@]}"
# +++ rm -f '/usr/lib/libmpi*.so*'
# +++ rm -f /usr/lib/x86_64-linux-gnu/libmpi_cxx.so /usr/lib/x86_64-linux-gnu/libmpi_cxx.so.40 /usr/lib/x86_64-linux-gnu/libmpi_cxx.so.40.30.1 /usr/lib/x86_64-linux-gnu/libmpi_java.so /usr/lib/x86_64-linux-gnu/libmpi_java.so.40 /usr/lib/x86_64-linux-gnu/libmpi_java.so.40.30.0 /usr/lib/x86_64-linux-gnu/libmpi_mpifh-gfortran.so /usr/lib/x86_64-linux-gnu/libmpi_mpifh-gfortran.so.40 /usr/lib/x86_64-linux-gnu/libmpi_mpifh-gfortran.so.40.30.0 /usr/lib/x86_64-linux-gnu/libmpi_mpifh.so /usr/lib/x86_64-linux-gnu/libmpi_mpifh.so.40 /usr/lib/x86_64-linux-gnu/libmpi_mpifh.so.40.30.0 /usr/lib/x86_64-linux-gnu/libmpiseq_seq-5.4.0.so /usr/lib/x86_64-linux-gnu/libmpiseq_seq-5.4.so /usr/lib/x86_64-linux-gnu/libmpiseq_seq.so /usr/lib/x86_64-linux-gnu/libmpi++.so /usr/lib/x86_64-linux-gnu/libmpi.so /usr/lib/x86_64-linux-gnu/libmpi.so.40 /usr/lib/x86_64-linux-gnu/libmpi.so.40.30.2 /usr/lib/x86_64-linux-gnu/libmpi_usempif08-gfortran.so /usr/lib/x86_64-linux-gnu/libmpi_usempif08-gfortran.so.40 /usr/lib/x86_64-linux-gnu/libmpi_usempif08-gfortran.so.40.30.0 /usr/lib/x86_64-linux-gnu/libmpi_usempif08.so /usr/lib/x86_64-linux-gnu/libmpi_usempif08.so.40 /usr/lib/x86_64-linux-gnu/libmpi_usempif08.so.40.30.0 /usr/lib/x86_64-linux-gnu/libmpi_usempi_ignore_tkr-gfortran.so /usr/lib/x86_64-linux-gnu/libmpi_usempi_ignore_tkr-gfortran.so.40 /usr/lib/x86_64-linux-gnu/libmpi_usempi_ignore_tkr-gfortran.so.40.30.0 /usr/lib/x86_64-linux-gnu/libmpi_usempi_ignore_tkr.so /usr/lib/x86_64-linux-gnu/libmpi_usempi_ignore_tkr.so.40 /usr/lib/x86_64-linux-gnu/libmpi_usempi_ignore_tkr.so.40.30.0
# +++ ln -fs /usr/local/lib/libmpi_mpifh.so /usr/local/lib/libmpi_mpifh.so.40 /usr/local/lib/libmpi_mpifh.so.40.40.1 /usr/local/lib/libmpi.so /usr/local/lib/libmpi.so.40 /usr/local/lib/libmpi.so.40.40.7 /usr/local/lib/libmpi_usempif08.so /usr/local/lib/libmpi_usempif08.so.40 /usr/local/lib/libmpi_usempif08.so.40.40.3 /usr/local/lib/libmpi_usempi_ignore_tkr.so /usr/local/lib/libmpi_usempi_ignore_tkr.so.40 /usr/local/lib/libmpi_usempi_ignore_tkr.so.40.40.1 /usr/lib
# +++ for MPI_LIB in "${MPI_LIBS[@]}"
# +++ rm -f '/usr/lib/libopen-pal*.so*'
# +++ rm -f /usr/lib/x86_64-linux-gnu/libopen-pal.so /usr/lib/x86_64-linux-gnu/libopen-pal.so.40 /usr/lib/x86_64-linux-gnu/libopen-pal.so.40.30.2
# +++ ln -fs /usr/local/lib/libopen-pal.so /usr/local/lib/libopen-pal.so.80 /usr/local/lib/libopen-pal.so.80.0.5 /usr/lib
# +++ for MPI_LIB in "${MPI_LIBS[@]}"
# +++ rm -f '/usr/lib/libpmix*.so*'
# +++ rm -f /usr/lib/x86_64-linux-gnu/libpmix.so /usr/lib/x86_64-linux-gnu/libpmix.so.2 /usr/lib/x86_64-linux-gnu/libpmix.so.2.5.2
# +++ ln -fs /usr/local/lib/libpmix.so /usr/local/lib/libpmix.so.2 /usr/local/lib/libpmix.so.2.13.9 /usr/lib
# +++ for MPI_LIB in "${MPI_LIBS[@]}"
# +++ rm -f '/usr/lib/libprrte*.so*'
# +++ rm -f '/usr/lib/x86_64-linux-gnu/libprrte*.so*'
# +++ ln -fs /usr/local/lib/libprrte.so /usr/local/lib/libprrte.so.3 /usr/local/lib/libprrte.so.3.0.12 /usr/lib
# +++ mkdir -p /usr/local/share/fem-on-colab
# +++ touch /usr/local/share/fem-on-colab/mpi4py.installed
# ++ PYBIND11_ARCHIVE_PATH=https://github.com/fem-on-colab/fem-on-colab/releases/download/pybind11-20260105-084828-a62e748/pybind11-install.tar.gz
# ++ [[ https://github.com/fem-on-colab/fem-on-colab/releases/download/pybind11-20260105-084828-a62e748/pybind11-install.tar.gz == http* ]]
# ++ PYBIND11_ARCHIVE_DOWNLOAD=https://github.com/fem-on-colab/fem-on-colab/releases/download/pybind11-20260105-084828-a62e748/pybind11-install.tar.gz
# ++ PYBIND11_ARCHIVE_PATH=/tmp/pybind11-install.tar.gz
# ++ wget https://github.com/fem-on-colab/fem-on-colab/releases/download/pybind11-20260105-084828-a62e748/pybind11-install.tar.gz -O /tmp/pybind11-install.tar.gz
# --2026-01-09 16:26:35--  https://github.com/fem-on-colab/fem-on-colab/releases/download/pybind11-20260105-084828-a62e748/pybind11-install.tar.gz
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/370599515/cf99df33-5a9e-42e6-b39c-8793fdacc5fc?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-01-09T17%3A03%3A28Z&rscd=attachment%3B+filename%3Dpybind11-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-01-09T16%3A03%3A07Z&ske=2026-01-09T17%3A03%3A28Z&sks=b&skv=2018-11-09&sig=UmM%2FfYpQoX4G977SKIp5ZiOmfLAmTEKCpLhE8QohW28%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2Nzk3NjI5NSwibmJmIjoxNzY3OTc1OTk1LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.WOoYs0u4tdO0upqJ-MVI2IyTwHn7x7j4Tu3cxXFZrBM&response-content-disposition=attachment%3B%20filename%3Dpybind11-install.tar.gz&response-content-type=application%2Foctet-stream [following]
# --2026-01-09 16:26:35--  https://release-assets.githubusercontent.com/github-production-release-asset/370599515/cf99df33-5a9e-42e6-b39c-8793fdacc5fc?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-01-09T17%3A03%3A28Z&rscd=attachment%3B+filename%3Dpybind11-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-01-09T16%3A03%3A07Z&ske=2026-01-09T17%3A03%3A28Z&sks=b&skv=2018-11-09&sig=UmM%2FfYpQoX4G977SKIp5ZiOmfLAmTEKCpLhE8QohW28%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2Nzk3NjI5NSwibmJmIjoxNzY3OTc1OTk1LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.WOoYs0u4tdO0upqJ-MVI2IyTwHn7x7j4Tu3cxXFZrBM&response-content-disposition=attachment%3B%20filename%3Dpybind11-install.tar.gz&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 746131 (729K) [application/octet-stream]
# Saving to: ‘/tmp/pybind11-install.tar.gz’
#
# /tmp/pybind11-insta 100%[===================>] 728.64K  --.-KB/s    in 0.006s
#
# 2026-01-09 16:26:35 (115 MB/s) - ‘/tmp/pybind11-install.tar.gz’ saved [746131/746131]
#
# ++ [[ /tmp/pybind11-install.tar.gz != skip ]]
# ++ rm -rf '/usr/lib/python*/*-packages/pybind11*'
# ++ rm -rf '/usr/local/lib/python*/*-packages/pybind11*'
# ++ tar -xzf /tmp/pybind11-install.tar.gz --strip-components=2 --directory=/usr/local
# ++ mkdir -p /usr/local/share/fem-on-colab
# ++ touch /usr/local/share/fem-on-colab/pybind11.installed
# + BOOST_INSTALL_SCRIPT_PATH=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/c5ffe772/releases/boost-install.sh
# + [[ https://github.com/fem-on-colab/fem-on-colab.github.io/raw/c5ffe772/releases/boost-install.sh == http* ]]
# + BOOST_INSTALL_SCRIPT_DOWNLOAD=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/c5ffe772/releases/boost-install.sh
# + BOOST_INSTALL_SCRIPT_PATH=/tmp/boost-install.sh
# + [[ ! -f /tmp/boost-install.sh ]]
# + wget https://github.com/fem-on-colab/fem-on-colab.github.io/raw/c5ffe772/releases/boost-install.sh -O /tmp/boost-install.sh
# --2026-01-09 16:26:35--  https://github.com/fem-on-colab/fem-on-colab.github.io/raw/c5ffe772/releases/boost-install.sh
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/c5ffe772d3423594b60fe00c3b7405fc0020faa7/releases/boost-install.sh [following]
# --2026-01-09 16:26:35--  https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/c5ffe772d3423594b60fe00c3b7405fc0020faa7/releases/boost-install.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1856 (1.8K) [text/plain]
# Saving to: ‘/tmp/boost-install.sh’
#
# /tmp/boost-install. 100%[===================>]   1.81K  --.-KB/s    in 0s
#
# 2026-01-09 16:26:35 (28.0 MB/s) - ‘/tmp/boost-install.sh’ saved [1856/1856]
#
# + source /tmp/boost-install.sh
# ++ set -e
# ++ set -x
# ++ INSTALL_PREFIX=/usr/local
# +++ echo /usr/local
# +++ awk -F/ '{print NF-1}'
# ++ INSTALL_PREFIX_DEPTH=2
# ++ PROJECT_NAME=fem-on-colab
# ++ SHARE_PREFIX=/usr/local/share/fem-on-colab
# ++ BOOST_INSTALLED=/usr/local/share/fem-on-colab/boost.installed
# ++ [[ ! -f /usr/local/share/fem-on-colab/boost.installed ]]
# ++ GCC_INSTALL_SCRIPT_PATH=/tmp/gcc-install.sh
# ++ [[ /tmp/gcc-install.sh == http* ]]
# ++ source /tmp/gcc-install.sh
# +++ set -e
# +++ set -x
# +++ INSTALL_PREFIX=/usr/local
# ++++ echo /usr/local
# ++++ awk -F/ '{print NF-1}'
# +++ INSTALL_PREFIX_DEPTH=2
# +++ PROJECT_NAME=fem-on-colab
# +++ SHARE_PREFIX=/usr/local/share/fem-on-colab
# +++ GCC_INSTALLED=/usr/local/share/fem-on-colab/gcc.installed
# +++ [[ ! -L /usr/local/lib64 ]]
# +++ [[ ! -L /usr/local/lib64 ]]
# +++ [[ ! -d /usr/local/lib64 ]]
# +++ [[ ! -f /usr/local/share/fem-on-colab/gcc.installed ]]
# ++ BOOST_ARCHIVE_PATH=https://github.com/fem-on-colab/fem-on-colab/releases/download/boost-20260105-083056-a62e748/boost-install.tar.gz
# ++ [[ https://github.com/fem-on-colab/fem-on-colab/releases/download/boost-20260105-083056-a62e748/boost-install.tar.gz == http* ]]
# ++ BOOST_ARCHIVE_DOWNLOAD=https://github.com/fem-on-colab/fem-on-colab/releases/download/boost-20260105-083056-a62e748/boost-install.tar.gz
# ++ BOOST_ARCHIVE_PATH=/tmp/boost-install.tar.gz
# ++ wget https://github.com/fem-on-colab/fem-on-colab/releases/download/boost-20260105-083056-a62e748/boost-install.tar.gz -O /tmp/boost-install.tar.gz
# --2026-01-09 16:26:35--  https://github.com/fem-on-colab/fem-on-colab/releases/download/boost-20260105-083056-a62e748/boost-install.tar.gz
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/370599515/2981f7d2-3898-4d90-91dd-e3f9f9a058bc?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-01-09T17%3A02%3A15Z&rscd=attachment%3B+filename%3Dboost-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-01-09T16%3A02%3A15Z&ske=2026-01-09T17%3A02%3A15Z&sks=b&skv=2018-11-09&sig=07tKB%2BD6VeCUhnF20d%2B04Ldnjb4QBdowaBdjTKS3Rjw%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2Nzk3Nzc5NSwibmJmIjoxNzY3OTc1OTk1LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.Os8hTXUGN_wq430yyIb9tjc7l2-VG8eklZDzp7f9UTs&response-content-disposition=attachment%3B%20filename%3Dboost-install.tar.gz&response-content-type=application%2Foctet-stream [following]
# --2026-01-09 16:26:35--  https://release-assets.githubusercontent.com/github-production-release-asset/370599515/2981f7d2-3898-4d90-91dd-e3f9f9a058bc?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-01-09T17%3A02%3A15Z&rscd=attachment%3B+filename%3Dboost-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-01-09T16%3A02%3A15Z&ske=2026-01-09T17%3A02%3A15Z&sks=b&skv=2018-11-09&sig=07tKB%2BD6VeCUhnF20d%2B04Ldnjb4QBdowaBdjTKS3Rjw%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2Nzk3Nzc5NSwibmJmIjoxNzY3OTc1OTk1LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.Os8hTXUGN_wq430yyIb9tjc7l2-VG8eklZDzp7f9UTs&response-content-disposition=attachment%3B%20filename%3Dboost-install.tar.gz&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 26972164 (26M) [application/octet-stream]
# Saving to: ‘/tmp/boost-install.tar.gz’
#
# /tmp/boost-install. 100%[===================>]  25.72M  --.-KB/s    in 0.08s
#
# 2026-01-09 16:26:35 (313 MB/s) - ‘/tmp/boost-install.tar.gz’ saved [26972164/26972164]
#
# ++ [[ /tmp/boost-install.tar.gz != skip ]]
# ++ tar -xzf /tmp/boost-install.tar.gz --strip-components=2 --directory=/usr/local
# ++ [[ /tmp/boost-install.tar.gz != skip ]]
# ++ ln -fs /usr/local/lib/libboost_atomic.so /usr/local/lib/libboost_atomic.so.1.90.0 /usr/local/lib/libboost_charconv.so /usr/local/lib/libboost_charconv.so.1.90.0 /usr/local/lib/libboost_chrono.so /usr/local/lib/libboost_chrono.so.1.90.0 /usr/local/lib/libboost_container.so /usr/local/lib/libboost_container.so.1.90.0 /usr/local/lib/libboost_context.so /usr/local/lib/libboost_context.so.1.90.0 /usr/local/lib/libboost_contract.so /usr/local/lib/libboost_contract.so.1.90.0 /usr/local/lib/libboost_coroutine.so /usr/local/lib/libboost_coroutine.so.1.90.0 /usr/local/lib/libboost_date_time.so /usr/local/lib/libboost_date_time.so.1.90.0 /usr/local/lib/libboost_fiber.so /usr/local/lib/libboost_fiber.so.1.90.0 /usr/local/lib/libboost_filesystem.so /usr/local/lib/libboost_filesystem.so.1.90.0 /usr/local/lib/libboost_graph.so /usr/local/lib/libboost_graph.so.1.90.0 /usr/local/lib/libboost_iostreams.so /usr/local/lib/libboost_iostreams.so.1.90.0 /usr/local/lib/libboost_json.a /usr/local/lib/libboost_json.so /usr/local/lib/libboost_json.so.1.90.0 /usr/local/lib/libboost_log_setup.so /usr/local/lib/libboost_log_setup.so.1.90.0 /usr/local/lib/libboost_log.so /usr/local/lib/libboost_log.so.1.90.0 /usr/local/lib/libboost_math_c99f.so /usr/local/lib/libboost_math_c99f.so.1.90.0 /usr/local/lib/libboost_math_c99l.so /usr/local/lib/libboost_math_c99l.so.1.90.0 /usr/local/lib/libboost_math_c99.so /usr/local/lib/libboost_math_c99.so.1.90.0 /usr/local/lib/libboost_math_tr1f.so /usr/local/lib/libboost_math_tr1f.so.1.90.0 /usr/local/lib/libboost_math_tr1l.so /usr/local/lib/libboost_math_tr1l.so.1.90.0 /usr/local/lib/libboost_math_tr1.so /usr/local/lib/libboost_math_tr1.so.1.90.0 /usr/local/lib/libboost_nowide.so /usr/local/lib/libboost_nowide.so.1.90.0 /usr/local/lib/libboost_numpy312.so /usr/local/lib/libboost_numpy312.so.1.90.0 /usr/local/lib/libboost_prg_exec_monitor.so /usr/local/lib/libboost_prg_exec_monitor.so.1.90.0 /usr/local/lib/libboost_process.so /usr/local/lib/libboost_process.so.1.90.0 /usr/local/lib/libboost_program_options.so /usr/local/lib/libboost_program_options.so.1.90.0 /usr/local/lib/libboost_python312.so /usr/local/lib/libboost_python312.so.1.90.0 /usr/local/lib/libboost_random.so /usr/local/lib/libboost_random.so.1.90.0 /usr/local/lib/libboost_regex.so /usr/local/lib/libboost_regex.so.1.90.0 /usr/local/lib/libboost_serialization.so /usr/local/lib/libboost_serialization.so.1.90.0 /usr/local/lib/libboost_stacktrace_addr2line.so /usr/local/lib/libboost_stacktrace_addr2line.so.1.90.0 /usr/local/lib/libboost_stacktrace_basic.so /usr/local/lib/libboost_stacktrace_basic.so.1.90.0 /usr/local/lib/libboost_stacktrace_from_exception.so /usr/local/lib/libboost_stacktrace_from_exception.so.1.90.0 /usr/local/lib/libboost_stacktrace_noop.so /usr/local/lib/libboost_stacktrace_noop.so.1.90.0 /usr/local/lib/libboost_thread.so /usr/local/lib/libboost_thread.so.1.90.0 /usr/local/lib/libboost_timer.so /usr/local/lib/libboost_timer.so.1.90.0 /usr/local/lib/libboost_type_erasure.so /usr/local/lib/libboost_type_erasure.so.1.90.0 /usr/local/lib/libboost_unit_test_framework.so /usr/local/lib/libboost_unit_test_framework.so.1.90.0 /usr/local/lib/libboost_url.so /usr/local/lib/libboost_url.so.1.90.0 /usr/local/lib/libboost_wave.so /usr/local/lib/libboost_wave.so.1.90.0 /usr/local/lib/libboost_wserialization.so /usr/local/lib/libboost_wserialization.so.1.90.0 /usr/lib
# ++ mkdir -p /usr/local/share/fem-on-colab
# ++ touch /usr/local/share/fem-on-colab/boost.installed
# + SLEPC4PY_INSTALL_SCRIPT_PATH=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/f6cc66bd/releases/slepc4py-install-release-real.sh
# + [[ https://github.com/fem-on-colab/fem-on-colab.github.io/raw/f6cc66bd/releases/slepc4py-install-release-real.sh == http* ]]
# + SLEPC4PY_INSTALL_SCRIPT_DOWNLOAD=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/f6cc66bd/releases/slepc4py-install-release-real.sh
# + SLEPC4PY_INSTALL_SCRIPT_PATH=/tmp/slepc4py-install.sh
# + [[ ! -f /tmp/slepc4py-install.sh ]]
# + wget https://github.com/fem-on-colab/fem-on-colab.github.io/raw/f6cc66bd/releases/slepc4py-install-release-real.sh -O /tmp/slepc4py-install.sh
# --2026-01-09 16:26:37--  https://github.com/fem-on-colab/fem-on-colab.github.io/raw/f6cc66bd/releases/slepc4py-install-release-real.sh
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/f6cc66bd8666662ac74f2f01eb7987912c9dd01b/releases/slepc4py-install-release-real.sh [following]
# --2026-01-09 16:26:37--  https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/f6cc66bd8666662ac74f2f01eb7987912c9dd01b/releases/slepc4py-install-release-real.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1758 (1.7K) [text/plain]
# Saving to: ‘/tmp/slepc4py-install.sh’
#
# /tmp/slepc4py-insta 100%[===================>]   1.72K  --.-KB/s    in 0s
#
# 2026-01-09 16:26:38 (25.6 MB/s) - ‘/tmp/slepc4py-install.sh’ saved [1758/1758]
#
# + source /tmp/slepc4py-install.sh
# ++ set -e
# ++ set -x
# ++ INSTALL_PREFIX=/usr/local
# +++ echo /usr/local
# +++ awk -F/ '{print NF-1}'
# ++ INSTALL_PREFIX_DEPTH=2
# ++ PROJECT_NAME=fem-on-colab
# ++ SHARE_PREFIX=/usr/local/share/fem-on-colab
# ++ SLEPC4PY_INSTALLED=/usr/local/share/fem-on-colab/slepc4py.installed
# ++ [[ ! -f /usr/local/share/fem-on-colab/slepc4py.installed ]]
# ++ PETSC4PY_INSTALL_SCRIPT_PATH=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/ef7c0aaf/releases/petsc4py-install-release-real.sh
# ++ [[ https://github.com/fem-on-colab/fem-on-colab.github.io/raw/ef7c0aaf/releases/petsc4py-install-release-real.sh == http* ]]
# ++ PETSC4PY_INSTALL_SCRIPT_DOWNLOAD=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/ef7c0aaf/releases/petsc4py-install-release-real.sh
# ++ PETSC4PY_INSTALL_SCRIPT_PATH=/tmp/petsc4py-install.sh
# ++ [[ ! -f /tmp/petsc4py-install.sh ]]
# ++ wget https://github.com/fem-on-colab/fem-on-colab.github.io/raw/ef7c0aaf/releases/petsc4py-install-release-real.sh -O /tmp/petsc4py-install.sh
# --2026-01-09 16:26:38--  https://github.com/fem-on-colab/fem-on-colab.github.io/raw/ef7c0aaf/releases/petsc4py-install-release-real.sh
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/ef7c0aaf8debaa6cd143cab701400e411b6db870/releases/petsc4py-install-release-real.sh [following]
# --2026-01-09 16:26:38--  https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/ef7c0aaf8debaa6cd143cab701400e411b6db870/releases/petsc4py-install-release-real.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1802 (1.8K) [text/plain]
# Saving to: ‘/tmp/petsc4py-install.sh’
#
# /tmp/petsc4py-insta 100%[===================>]   1.76K  --.-KB/s    in 0s
#
# 2026-01-09 16:26:38 (26.6 MB/s) - ‘/tmp/petsc4py-install.sh’ saved [1802/1802]
#
# ++ source /tmp/petsc4py-install.sh
# +++ set -e
# +++ set -x
# +++ INSTALL_PREFIX=/usr/local
# ++++ echo /usr/local
# ++++ awk -F/ '{print NF-1}'
# +++ INSTALL_PREFIX_DEPTH=2
# +++ PROJECT_NAME=fem-on-colab
# +++ SHARE_PREFIX=/usr/local/share/fem-on-colab
# +++ PETSC4PY_INSTALLED=/usr/local/share/fem-on-colab/petsc4py.installed
# +++ [[ ! -f /usr/local/share/fem-on-colab/petsc4py.installed ]]
# +++ H5PY_INSTALL_SCRIPT_PATH=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/e6cdd0d9/releases/h5py-install.sh
# +++ [[ https://github.com/fem-on-colab/fem-on-colab.github.io/raw/e6cdd0d9/releases/h5py-install.sh == http* ]]
# +++ H5PY_INSTALL_SCRIPT_DOWNLOAD=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/e6cdd0d9/releases/h5py-install.sh
# +++ H5PY_INSTALL_SCRIPT_PATH=/tmp/h5py-install.sh
# +++ [[ ! -f /tmp/h5py-install.sh ]]
# +++ wget https://github.com/fem-on-colab/fem-on-colab.github.io/raw/e6cdd0d9/releases/h5py-install.sh -O /tmp/h5py-install.sh
# --2026-01-09 16:26:38--  https://github.com/fem-on-colab/fem-on-colab.github.io/raw/e6cdd0d9/releases/h5py-install.sh
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/e6cdd0d97decebdfb514417b8fe95ee16f3e1d17/releases/h5py-install.sh [following]
# --2026-01-09 16:26:38--  https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/e6cdd0d97decebdfb514417b8fe95ee16f3e1d17/releases/h5py-install.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1724 (1.7K) [text/plain]
# Saving to: ‘/tmp/h5py-install.sh’
#
# /tmp/h5py-install.s 100%[===================>]   1.68K  --.-KB/s    in 0s
#
# 2026-01-09 16:26:38 (16.8 MB/s) - ‘/tmp/h5py-install.sh’ saved [1724/1724]
#
# +++ source /tmp/h5py-install.sh
# ++++ set -e
# ++++ set -x
# ++++ INSTALL_PREFIX=/usr/local
# +++++ echo /usr/local
# +++++ awk -F/ '{print NF-1}'
# ++++ INSTALL_PREFIX_DEPTH=2
# ++++ PROJECT_NAME=fem-on-colab
# ++++ SHARE_PREFIX=/usr/local/share/fem-on-colab
# ++++ H5PY_INSTALLED=/usr/local/share/fem-on-colab/h5py.installed
# ++++ [[ ! -f /usr/local/share/fem-on-colab/h5py.installed ]]
# ++++ MPI4PY_INSTALL_SCRIPT_PATH=/tmp/mpi4py-install.sh
# ++++ [[ /tmp/mpi4py-install.sh == http* ]]
# ++++ source /tmp/mpi4py-install.sh
# +++++ set -e
# +++++ set -x
# +++++ INSTALL_PREFIX=/usr/local
# ++++++ echo /usr/local
# ++++++ awk -F/ '{print NF-1}'
# +++++ INSTALL_PREFIX_DEPTH=2
# +++++ PROJECT_NAME=fem-on-colab
# +++++ SHARE_PREFIX=/usr/local/share/fem-on-colab
# +++++ MPI4PY_INSTALLED=/usr/local/share/fem-on-colab/mpi4py.installed
# +++++ [[ ! -f /usr/local/share/fem-on-colab/mpi4py.installed ]]
# ++++ H5PY_ARCHIVE_PATH=https://github.com/fem-on-colab/fem-on-colab/releases/download/h5py-20260105-084829-a62e748/h5py-install.tar.gz
# ++++ [[ https://github.com/fem-on-colab/fem-on-colab/releases/download/h5py-20260105-084829-a62e748/h5py-install.tar.gz == http* ]]
# ++++ H5PY_ARCHIVE_DOWNLOAD=https://github.com/fem-on-colab/fem-on-colab/releases/download/h5py-20260105-084829-a62e748/h5py-install.tar.gz
# ++++ H5PY_ARCHIVE_PATH=/tmp/h5py-install.tar.gz
# ++++ wget https://github.com/fem-on-colab/fem-on-colab/releases/download/h5py-20260105-084829-a62e748/h5py-install.tar.gz -O /tmp/h5py-install.tar.gz
# --2026-01-09 16:26:38--  https://github.com/fem-on-colab/fem-on-colab/releases/download/h5py-20260105-084829-a62e748/h5py-install.tar.gz
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/370599515/41f4a6b7-8de3-4644-b30b-c6fe1334703f?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-01-09T17%3A02%3A43Z&rscd=attachment%3B+filename%3Dh5py-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-01-09T16%3A01%3A48Z&ske=2026-01-09T17%3A02%3A43Z&sks=b&skv=2018-11-09&sig=U%2Fyz7XesbolH6HE1BrbqGN5FYGQfwLcOeD2uUxPw%2Fgg%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2Nzk3Nzc5OCwibmJmIjoxNzY3OTc1OTk4LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.zBcGfbXtsEkX0MFJyOXB8o3neJkd9l1rIOjaTPYfR0g&response-content-disposition=attachment%3B%20filename%3Dh5py-install.tar.gz&response-content-type=application%2Foctet-stream [following]
# --2026-01-09 16:26:38--  https://release-assets.githubusercontent.com/github-production-release-asset/370599515/41f4a6b7-8de3-4644-b30b-c6fe1334703f?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-01-09T17%3A02%3A43Z&rscd=attachment%3B+filename%3Dh5py-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-01-09T16%3A01%3A48Z&ske=2026-01-09T17%3A02%3A43Z&sks=b&skv=2018-11-09&sig=U%2Fyz7XesbolH6HE1BrbqGN5FYGQfwLcOeD2uUxPw%2Fgg%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2Nzk3Nzc5OCwibmJmIjoxNzY3OTc1OTk4LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.zBcGfbXtsEkX0MFJyOXB8o3neJkd9l1rIOjaTPYfR0g&response-content-disposition=attachment%3B%20filename%3Dh5py-install.tar.gz&response-content-type=application%2Foctet-stream
# ...
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/370599515/4e1454a4-4452-4a5f-a702-ac58c26bdf58?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-01-09T17%3A05%3A19Z&rscd=attachment%3B+filename%3Dslepc4py-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-01-09T16%3A04%3A58Z&ske=2026-01-09T17%3A05%3A19Z&sks=b&skv=2018-11-09&sig=iuR1jWzx6PW3jrxEwPe25jmapHKpC%2FJuhqYhEsk7FUg%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2Nzk3NzgxMiwibmJmIjoxNzY3OTc2MDEyLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.q4yeFARyoGjUNqhg2-aBAbrJQ82zxpV5egEi3IJlunk&response-content-disposition=attachment%3B%20filename%3Dslepc4py-install.tar.gz&response-content-type=application%2Foctet-stream [following]
# --2026-01-09 16:26:52--  https://release-assets.githubusercontent.com/github-production-release-asset/370599515/4e1454a4-4452-4a5f-a702-ac58c26bdf58?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-01-09T17%3A05%3A19Z&rscd=attachment%3B+filename%3Dslepc4py-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-01-09T16%3A04%3A58Z&ske=2026-01-09T17%3A05%3A19Z&sks=b&skv=2018-11-09&sig=iuR1jWzx6PW3jrxEwPe25jmapHKpC%2FJuhqYhEsk7FUg%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2Nzk3NzgxMiwibmJmIjoxNzY3OTc2MDEyLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.q4yeFARyoGjUNqhg2-aBAbrJQ82zxpV5egEi3IJlunk&response-content-disposition=attachment%3B%20filename%3Dslepc4py-install.tar.gz&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23882275 (23M) [application/octet-stream]
# Saving to: ‘/tmp/slepc4py-install.tar.gz’
#
# /tmp/slepc4py-insta 100%[===================>]  22.78M  --.-KB/s    in 0.06s
#
# 2026-01-09 16:26:52 (403 MB/s) - ‘/tmp/slepc4py-install.tar.gz’ saved [23882275/23882275]
#
# ++ [[ /tmp/slepc4py-install.tar.gz != skip ]]
# ++ tar -xzf /tmp/slepc4py-install.tar.gz --strip-components=2 --directory=/usr/local
# ++ mkdir -p /usr/local/share/fem-on-colab
# ++ touch /usr/local/share/fem-on-colab/slepc4py.installed
# + FENICS_ARCHIVE_PATH=https://github.com/fem-on-colab/fem-on-colab/releases/download/fenics-20260105-125309-a62e748-release-real/fenics-install.tar.gz
# + [[ https://github.com/fem-on-colab/fem-on-colab/releases/download/fenics-20260105-125309-a62e748-release-real/fenics-install.tar.gz == http* ]]
# + FENICS_ARCHIVE_DOWNLOAD=https://github.com/fem-on-colab/fem-on-colab/releases/download/fenics-20260105-125309-a62e748-release-real/fenics-install.tar.gz
# + FENICS_ARCHIVE_PATH=/tmp/fenics-install.tar.gz
# + wget https://github.com/fem-on-colab/fem-on-colab/releases/download/fenics-20260105-125309-a62e748-release-real/fenics-install.tar.gz -O /tmp/fenics-install.tar.gz
# --2026-01-09 16:26:53--  https://github.com/fem-on-colab/fem-on-colab/releases/download/fenics-20260105-125309-a62e748-release-real/fenics-install.tar.gz
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/370599515/40fdd9fe-ecc2-4617-a56e-aeaceecec06f?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-01-09T17%3A02%3A17Z&rscd=attachment%3B+filename%3Dfenics-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-01-09T16%3A01%3A30Z&ske=2026-01-09T17%3A02%3A17Z&sks=b&skv=2018-11-09&sig=hliXor6bsCRpk11bz2Tm9RNWwhUYwa2KRMHfRPVrFbo%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2Nzk3NzgxMywibmJmIjoxNzY3OTc2MDEzLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.NAI-JwkcKKIrASAGRjlqCb9rQvZY3jt81LN-BGGa9VI&response-content-disposition=attachment%3B%20filename%3Dfenics-install.tar.gz&response-content-type=application%2Foctet-stream [following]
# --2026-01-09 16:26:53--  https://release-assets.githubusercontent.com/github-production-release-asset/370599515/40fdd9fe-ecc2-4617-a56e-aeaceecec06f?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-01-09T17%3A02%3A17Z&rscd=attachment%3B+filename%3Dfenics-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-01-09T16%3A01%3A30Z&ske=2026-01-09T17%3A02%3A17Z&sks=b&skv=2018-11-09&sig=hliXor6bsCRpk11bz2Tm9RNWwhUYwa2KRMHfRPVrFbo%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2Nzk3NzgxMywibmJmIjoxNzY3OTc2MDEzLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.NAI-JwkcKKIrASAGRjlqCb9rQvZY3jt81LN-BGGa9VI&response-content-disposition=attachment%3B%20filename%3Dfenics-install.tar.gz&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 75827698 (72M) [application/octet-stream]
# Saving to: ‘/tmp/fenics-install.tar.gz’
#
# /tmp/fenics-install 100%[===================>]  72.31M   269MB/s    in 0.3s
#
# 2026-01-09 16:26:53 (269 MB/s) - ‘/tmp/fenics-install.tar.gz’ saved [75827698/75827698]
#
# + [[ /tmp/fenics-install.tar.gz != skip ]]
# + tar -xzf /tmp/fenics-install.tar.gz --strip-components=2 --directory=/usr/local
# + [[ /tmp/fenics-install.tar.gz != skip ]]
# + ln -fs /usr/local/lib/libdolfin.so /usr/local/lib/libdolfin.so.2019.2 /usr/local/lib/libdolfin.so.2019.2.0.dev0 /usr/lib
# + ln -fs /usr/local/lib/libmshr.so /usr/local/lib/libmshr.so.2019.2 /usr/local/lib/libmshr.so.2019.2.0.dev0 /usr/lib
# + mkdir -p /usr/local/share/fem-on-colab
# + touch /usr/local/share/fem-on-colab/fenics.installed
# + set +x
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ################################################################################
# #     This installation is offered by FEM on Colab, an open-source project     #
# #       developed and maintained at Università Cattolica del Sacro Cuore       #
# #   by Prof. Francesco Ballarin. Please see https://fem-on-colab.github.io/    #
# #       for more details, including a list of further available packages       #
# #       and how to sponsor the development or contribute to the project.       #
# #                                                                              #
# #   We are conducting an informal survey on FEM on Colab usage by our users.   #
# #   The survey is anonymous, and its compilation will typically only require   #
# #   a couple of minutes of your time. If you wish, give us your feedback at    #
# #                     https://forms.gle/36sZZWNvPpUv8XWr7                      #
# ################################################################################
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Cloning into 'master'...
# Receiving objects: 100% (2278/2278), 1.07 MiB | 16.79 MiB/s, done.
# Resolving deltas: 100% (1623/1623), done.
# Processing ./master
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: cbc.block
#   Building wheel for cbc.block (setup.py) ... done
#   Created wheel for cbc.block: filename=cbc.block-0.0.1-py3-none-any.whl size=75552 sha256=d105b30afc3365d9e55a6d8afb06bf3d4b365643ce97ab26f8544894e335e78a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-634ew1xp/wheels/df/36/80/3c2c31b34cc23342b6c56da9214958f605aa726cdbef429578
# Successfully built cbc.block
# Installing collected packages: cbc.block
# Successfully installed cbc.block-0.0.1
# Cloning into 'fenics_ii'...
# remote: Enumerating objects: 3028, done.
# remote: Counting objects: 100% (129/129), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 3028 (delta 56), reused 63 (delta 44), pack-reused 2899 (from 2)
# Receiving objects: 100% (3028/3028), 2.89 MiB | 29.88 MiB/s, done.
# Resolving deltas: 100% (2167/2167), done.
# Processing ./fenics_ii
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: FEniCS_ii
#   Building wheel for FEniCS_ii (setup.py) ... done
#   Created wheel for FEniCS_ii: filename=FEniCS_ii-0.5-py3-none-any.whl size=143219 sha256=82546a08b8e0d650d207dd1336e72a10522c274f89d9986e7baacb783fb0fb3b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-x9hcbb1y/wheels/ec/bd/ae/e290a9cdff40b90be7c0935ace358342a55ec36074a0acfdfa
# Successfully built FEniCS_ii
# Installing collected packages: FEniCS_ii
# Successfully installed FEniCS_ii-0.5
# Collecting vtk
#   Downloading vtk-9.5.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from vtk) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->vtk) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->vtk) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->vtk) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->vtk) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->vtk) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->vtk) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->vtk) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->vtk) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->vtk) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->vtk) (1.17.0)
# Downloading vtk-9.5.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (112.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.3/112.3 MB 7.8 MB/s eta 0:00:00
# Installing collected packages: vtk
# Successfully installed vtk-9.5.2
# Cloning into 'graphnics'...
# remote: Enumerating objects: 975, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 975 (delta 19), reused 28 (delta 12), pack-reused 928 (from 1)
# Receiving objects: 100% (975/975), 9.79 MiB | 29.91 MiB/s, done.
# Resolving deltas: 100% (562/562), done.
# Processing ./graphnics
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: graphnics
#   Building wheel for graphnics (setup.py) ... done
#   Created wheel for graphnics: filename=graphnics-1-py3-none-any.whl size=30775 sha256=c3ac984b81698b70cc393a06a7cf7fb9ed6da06da3a4b7fcdd26ef34533caabd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2tkfjeuo/wheels/44/c6/93/e0fc34eca3b572d55a23d08e91365a7f6a1158552a1b2a0854
# Successfully built graphnics
# Installing collected packages: graphnics
# Successfully installed graphnics-1
# Collecting meshio
#   Downloading meshio-5.3.5-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.12/dist-packages (from meshio) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from meshio) (13.9.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->meshio) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->meshio) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->meshio) (0.1.2)
# Downloading meshio-5.3.5-py3-none-any.whl (166 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.2/166.2 kB 8.5 MB/s eta 0:00:00
# Installing collected packages: meshio
# Successfully installed meshio-5.3.5
# Collecting pyvista
#   Downloading pyvista-0.46.4-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: matplotlib>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from pyvista) (3.10.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from pyvista) (2.0.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from pyvista) (11.3.0)
# Requirement already satisfied: pooch in /usr/local/lib/python3.12/dist-packages (from pyvista) (1.8.2)
# Requirement already satisfied: scooby>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from pyvista) (0.11.0)
# Requirement already satisfied: typing-extensions>=4.10 in /usr/local/lib/python3.12/dist-packages (from pyvista) (4.15.0)
# Requirement already satisfied: vtk!=9.4.0 in /usr/local/lib/python3.12/dist-packages (from pyvista) (9.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.1->pyvista) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.1->pyvista) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.1->pyvista) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.1->pyvista) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.1->pyvista) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.1->pyvista) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.1->pyvista) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch->pyvista) (4.5.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from pooch->pyvista) (2.32.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0.1->pyvista) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch->pyvista) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch->pyvista) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch->pyvista) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch->pyvista) (2025.11.12)
# Downloading pyvista-0.46.4-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 77.3 MB/s eta 0:00:00
# Installing collected packages: pyvista
# Successfully installed pyvista-0.46.4

# %%
#@title Define functions
from math import gamma
from argparse import RawDescriptionHelpFormatter
from petsc4py import PETSc
from dolfin import *
from xii import *
import numpy as np
import time
import networkx as nx
from graphnics import FenicsGraph
from scipy.spatial import cKDTree
from itertools import combinations
from collections import deque

def bif_tangents(G):
    pos   = nx.get_node_attributes(G,"pos")
    nodes = list(G.nodes)
    T     = np.zeros((len(nodes),3))
    for k, n in enumerate(nodes):
        p0 = np.array(pos[n])
        neighbor = list(G.neighbors(n))
        vec = np.zeros(3)
        for m in neighbor:
            vec += np.array(pos[m]) - p0

        norm = np.linalg.norm(vec)
        if norm > 0:
          T[k,:] = vec/norm
        else:
          T[k,:] = np.array([0,0,1.0]) #use unit normal if needed
    P = np.array([pos[n] for n in nodes])
    return nodes, P, T

class TangentExpression(UserExpression):
    def __init__(self, nodes, P, T_array, **kwargs):
        self.nodes  = nodes
        self.P      = np.asarray(P)
        self.T_array = np.asarray(T_array)
        self.kdtree = cKDTree(self.P)
        super().__init__(**kwargs)
    def eval(self,values,x):
      _, idx = self.kdtree.query((x[0],x[1],x[2]))
      tx, ty, tz = self.T_array[idx]
      values[0] = tx
      values[1] = ty
      values[2] = tz
    def value_shape(self):
      return (3,)

def make_Y_bifurcation(
    parent_len=0.45, parent_pts=4,          # parent vessel
    daughter_len=0.45, daughter_pts=4,      # identical daughter vessels
    angle_deg=35.0,                         # opening half-angle of the Y (each daughter)
    r_parent=0.05, r_daughter=0.05/np.sqrt(2),        # radii
    damage_default=0.0,                     # damage field included in vtk file from Pierce's example, just made zero
    origin=(0.0, 0.0, -0.45),               # parent begins at z = -0.45
    bifurcation_z= 0.0                      # split occors at origin
):
    G = FenicsGraph()

    # === Parent: from (0,0,-0.45) to (0,0,bifurcation_z) ===
    z0 = origin[2]
    parent_zs = np.linspace(z0, bifurcation_z, parent_pts)
    parent_ids = []
    for z in parent_zs:
        i = len(G)  # next node id
        G.add_node(i, pos=(origin[0], origin[1], z), radius=r_parent, damage=damage_default)
        parent_ids.append(i)

    # Use the last parent node as the bifurcation node:
    bif_id = parent_ids[-1]
    bif_pt = G.nodes[bif_id]["pos"]

    # Connect parent and daughter paths
    for a, b in zip(parent_ids[:-1], parent_ids[1:]):
        G.add_edge(a, b)

    # === Daughters: symmetric about the z-axis in x–z plane ===
    angle = np.deg2rad(angle_deg)
    # Unit directions for the two daughters (right and left in +x/-x):
    d1 = np.array([ np.sin(angle), 0.0, np.cos(angle)])
    d2 = np.array([-np.sin(angle), 0.0, np.cos(angle)])

    def add_branch(bif_id, dir_vec):
        # start at the bifurcation point (re-use the node id at the bifurcation)
        # then create additional points along the ray
        ids = [bif_id]
        for k in range(1, daughter_pts):
            p = np.array(bif_pt) + (k / (daughter_pts - 1)) * daughter_len * dir_vec
            i = len(G)
            G.add_node(i, pos=tuple(p), radius=r_daughter, damage=damage_default)
            ids.append(i)
        # connect the line
        for a, b in zip(ids[:-1], ids[1:]):
            G.add_edge(a, b)

    add_branch(bif_id, d1)
    add_branch(bif_id, d2)

    return G

def build_bifurcation_pairs(G):
    """
    For every bifurcation node (degree > 2), return ordered pairs:
      (parent, daughter) for each daughter, and (daughter_i, daughter_j) for all daughter pairs.

    """
    pos = nx.get_node_attributes(G, 'pos')
    bif_nodes = [n for n in G.nodes if G.degree[n] > 2]
    results = []

    for b in bif_nodes:
        neighbor = list(G.neighbors(b))
        # Sort neighbors by z so smallest-z branch is treated as "parent" (upstream)
        neighbor_sorted = sorted(neighbor, key=lambda n: pos[n][2])
        parent_vessel   = neighbor_sorted[0]
        daughter_vessel = neighbor_sorted[1:]


        # Assign local vessel IDs per neighbor by walking to next junction/terminal
        vessel_id = {}
        for k, n in enumerate(neighbor_sorted, start = 1):
            vessel_id[n] = k

        parent_id = vessel_id[parent_vessel]
        daughter_id = [vessel_id[n] for n in daughter_vessel]

        results.append({
            "bif_node": b,
            "parent_id": parent_id,
            "daughter_id": daughter_id,
            "pairs": [(parent_id,d) for d in daughter_id] + list(combinations(daughter_id, 2)),
            "pos": np.array(pos[b]),
            "neighbor_sorted": neighbor_sorted,
            "vessel_id": vessel_id
        })

    return results

def bifurcation_vertices_from_graph(Lambda, bif_info):
    """Return mesh vertex indices of bifurcation points (nearest vertex to each bif node position)."""
    coords = Lambda.coordinates()

    def nearest_vertex(point):
        diff = coords - point
        return int(np.argmin(np.linalg.norm(diff, axis=1)))

    bif_vertices = []
    for bif in bif_info:
        vtx = nearest_vertex(bif["pos"])
        bif_vertices.append(vtx)
    return sorted(set(bif_vertices))


def add_kirchhoff_junction_terms_P1DG(
    A_petsc, V3, V1, Lambda, bif_vertices, D_area_expr,
    eta_gamma=10.0, epsilon=1.0
):
    """
    Assemble Kirchhoff/SIPG junction terms by writing directly into the PETSc Mat.

    """
    dm = V1.dofmap()
    coords = Lambda.coordinates()

    Lambda.init(0, 1)
    v2c = Lambda.topology()(0, 1)

    N = A_petsc.mat().getSize()[0]
    off1 = N - V1.dim()   # assumes V1 block is last in ii_convert ordering

    # get petsc4py Mat
    M = A_petsc.mat()

    M.setOption(PETSc.Mat.Option.NEW_NONZERO_ALLOCATION_ERR, False)
    M.setOption(PETSc.Mat.Option.NEW_NONZERO_LOCATION_ERR, False)

    def add_entry(I, J, val):
        # addv=True means accumulate into existing entry
        M.setValue(I, J, val, addv=True)

    for vtx in bif_vertices:
        incident_cells = list(v2c(vtx))
        m = len(incident_cells)
        if m < 3:
            continue

        branches = []
        h_gamma = 0.0

        for c in incident_cells:
            cell = Cell(Lambda, c)
            vids = cell.entities(0)
            x0 = coords[vids[0]]
            x1 = coords[vids[1]]
            hK = float(np.linalg.norm(x1 - x0))
            h_gamma = max(h_gamma, hK)

            if vids[0] == vtx:
                loc_g, loc_o = 0, 1
                x_mid = 0.5*(x0 + x1)
            else:
                loc_g, loc_o = 1, 0
                x_mid = 0.5*(x0 + x1)

            cdofs = dm.cell_dofs(c)  # DG1: 2 dofs per cell
            dof_g = int(cdofs[loc_g])
            dof_o = int(cdofs[loc_o])

            Da = float(D_area_expr(Point(*x_mid)))
            branches.append(dict(hK=hK, Da=Da, dof_g=dof_g, dof_o=dof_o))

        for a in range(m):
            for b in range(a + 1, m):
                Ia = branches[a]
                Ib = branches[b]

                ha, Da = Ia["hK"], Ia["Da"]
                hb, Db = Ib["hK"], Ib["Da"]
                ga, oa = Ia["dof_g"], Ia["dof_o"]
                gb, ob = Ib["dof_g"], Ib["dof_o"]

                # GLOBAL indices
                Gga, Goa = off1 + ga, off1 + oa
                Ggb, Gob = off1 + gb, off1 + ob

                # === penalty ===
                pen = eta_gamma / h_gamma
                for (I, sI) in [(Gga, +1.0), (Ggb, -1.0)]:
                    for (J, sJ) in [(Gga, +1.0), (Ggb, -1.0)]:
                        add_entry(I, J, pen * sI * sJ)

                # === New jump: -(1/m) {sigma(u)}^{ab} (v_ga - v_gb) ===
                w = -1.0 / m
                for (Row, srow) in [(Gga, +1.0), (Ggb, -1.0)]:
                    # flux_a(u) = Da*(u_oa - u_ga)/ha
                    add_entry(Row, Goa, w * srow * ( Da/ha))
                    add_entry(Row, Gga, w * srow * (-Da/ha))
                    # -flux_b(u) = -Db*(u_ob - u_gb)/hb
                    add_entry(Row, Gob, w * srow * (-Db/hb))
                    add_entry(Row, Ggb, w * srow * ( Db/hb))

                # === New average: -(eta/m) {sigma(v)}^{ab} (u_ga - u_gb) ===
                ws = -epsilon / m
                for (Col, scol) in [(Gga, +1.0), (Ggb, -1.0)]:
                    # flux_a(v) rows
                    add_entry(Goa, Col, ws * scol * ( Da/ha))
                    add_entry(Gga, Col, ws * scol * (-Da/ha))
                    # -flux_b(v) rows
                    add_entry(Gob, Col, ws * scol * (-Db/hb))
                    add_entry(Ggb, Col, ws * scol * ( Db/hb))

    # finalize PETSc assembly
    M.assemblyBegin()
    M.assemblyEnd()

def advection_junction_terms_P1DG(
    A_petsc, V3, V1, Lambda, bif_vertices, D_area_expr,
    q1_value=1.0
):
    dm = V1.dofmap()
    coords = Lambda.coordinates()

    Lambda.init(0, 1)
    v2c = Lambda.topology()(0, 1)

    # Use the same safe offset as for diffusion:
    N = A_petsc.mat().getSize()[0]
    off1 = N - V1.dim()   # V1 block last

    M = A_petsc.mat()
    M.setOption(PETSc.Mat.Option.NEW_NONZERO_ALLOCATION_ERR, False)
    M.setOption(PETSc.Mat.Option.NEW_NONZERO_LOCATION_ERR, False)

    def add_entry(I, J, val):
        M.setValue(I, J, float(val), addv=True)

    for vtx in bif_vertices:
        cells = list(v2c(vtx))
        if len(cells) != 3:
            continue  # expecting a Y junction

        xg = coords[vtx]
        branches = []

        # 1) collect branch data
        for c in cells:
            cell = Cell(Lambda, c)
            vids = cell.entities(0)
            x0, x1 = coords[vids[0]], coords[vids[1]]

            if vids[0] == vtx:
                loc_g = 0
                other = x1
                x_mid = 0.5*(x0 + x1)
            else:
                loc_g = 1
                other = x0
                x_mid = 0.5*(x0 + x1)

            dof_g = int(dm.cell_dofs(c)[loc_g])
            A_here = float(D_area_expr(Point(*x_mid)))
            Q_here = A_here * float(q1_value)

            branches.append({
                "dof_g": dof_g,
                "Q": Q_here,
                "z_other": other[2],
            })

        # 2) classify: inflow = smallest z_other (parent), outflows = other two
        inflow = min(branches, key=lambda b: b["z_other"])
        outflows = [b for b in branches if b is not inflow]

        Gin = off1 + inflow["dof_g"]

        # 3) assemble: sum_out Q_out * u_in * (v_out - v_in)
        Qsum = 0.0
        for b in outflows:
            Gout = off1 + b["dof_g"]
            Q = b["Q"]
            Qsum += Q
            add_entry(Gout, Gin, +Q)   # v_out * u_in
        add_entry(Gin, Gin, -Qsum)     # -v_in * u_in

    M.assemblyBegin()
    M.assemblyEnd()


def kirchhoff_residual_at_vertex(Lambda, V1, uh1d, vtx, D_area_expr):
  coords = Lambda.coordinates()
  dm = V1.dofmap()

  Lambda.init(0, 1)
  v2c = Lambda.topology()(0, 1)
  cells = list(v2c(vtx))

  res = 0.0
  fluxes = []
  for c in cells:
      cell = Cell(Lambda, c)
      vids = cell.entities(0)
      x0 = coords[vids[0]]
      x1 = coords[vids[1]]
      hK = float(np.linalg.norm(x1 - x0))
      x_mid = 0.5*(x0 + x1)
      Da = float(D_area_expr(Point(*x_mid)))

      cdofs = dm.cell_dofs(c)
      # local dof at junction vs other endpoint
      if vids[0] == vtx:
          dof_g, dof_o = int(cdofs[0]), int(cdofs[1])
      else:
          dof_g, dof_o = int(cdofs[1]), int(cdofs[0])

      ug = uh1d.vector()[dof_g]
      uo = uh1d.vector()[dof_o]
      F = Da * (uo - ug) / hK  # outgoing flux from junction into cell
      fluxes.append(F)
      res += F

  return res, fluxes

def advection_junction_terms_P1DG_flow_based(
    A_petsc, V1, Lambda, bif_vertices, D_area_expr, t_vec, q1_value=1.0
):
    dm = V1.dofmap()
    coords = Lambda.coordinates()
    Lambda.init(0, 1)
    v2c = Lambda.topology()(0, 1)

    N = A_petsc.mat().getSize()[0]
    off1 = N - V1.dim()

    M = A_petsc.mat()
    M.setOption(PETSc.Mat.Option.NEW_NONZERO_ALLOCATION_ERR, False)
    M.setOption(PETSc.Mat.Option.NEW_NONZERO_LOCATION_ERR, False)

    def add_entry(I, J, val):
        M.setValue(I, J, float(val), addv=True)

    for vtx in bif_vertices:
        cells = list(v2c(vtx))
        if len(cells) < 3:
            continue

        xg = coords[vtx]
        branches = []

        for c in cells:
            cell = Cell(Lambda, c)
            vids = cell.entities(0)
            x0, x1 = coords[vids[0]], coords[vids[1]]

            # vector from junction -> other endpoint (points into the branch)
            if vids[0] == vtx:
                loc_g = 0
                xother = x1
            else:
                loc_g = 1
                xother = x0

            d = xother - xg
            d_hat = d / np.linalg.norm(d)

            x_mid = 0.5*(xg + xother)
            tmid = np.array(t_vec(Point(*x_mid)))
            tmid /= np.linalg.norm(tmid)

            # signed velocity along this branch away from junction
            s = float(q1_value) * float(np.dot(tmid, d_hat))

            A = float(D_area_expr(Point(*x_mid)))
            Q = A * abs(s)

            dof_g = int(dm.cell_dofs(c)[loc_g])

            branches.append(dict(cell=c, dof_g=dof_g, s=s, Q=Q))

        inflows  = [b for b in branches if b["s"] < 0.0 and b["Q"] > 0.0]
        outflows = [b for b in branches if b["s"] > 0.0 and b["Q"] > 0.0]

        if len(outflows) == 0 or len(inflows) == 0:
            continue

        # Build node value as weighted inflow average:
        Q_in_sum = sum(b["Q"] for b in inflows)


        for bout in outflows:
            Gout = off1 + bout["dof_g"]
            Qout = bout["Q"]

            # outflow receives weighted mix of inflow dofs
            for bin_ in inflows:
                Gin = off1 + bin_["dof_g"]
                add_entry(Gout, Gin, Qout * (bin_["Q"]/Q_in_sum))

            # diagonal damping so it behaves like a node balance
            add_entry(Gout, Gout, -Qout)

    M.assemblyBegin()
    M.assemblyEnd()


def build_cell_tangent_expression(Lambda, degree=0):
    coords = Lambda.coordinates()
    cell_mids = []
    cell_tans = []

    for c in range(Lambda.num_cells()):
        cell = Cell(Lambda, c)
        vids = cell.entities(0)
        x0, x1 = coords[vids[0]], coords[vids[1]]

        t = x1 - x0
        t /= np.linalg.norm(t)

        # === ORIENT tangent consistently (toward +z) ===
        # this is specific to this network need to come back and revise for general
        if t[2] < 0.0:
            t = -t

        cell_mids.append(0.5*(x0 + x1))
        cell_tans.append(t)

    cell_mids = np.array(cell_mids)
    cell_tans = np.array(cell_tans)
    kdt = cKDTree(cell_mids)

    class CellTangent(UserExpression):
        def eval(self, values, x):
            _, idx = kdt.query((x[0], x[1], x[2]))
            values[:] = cell_tans[idx]
        def value_shape(self): return (3,)

    return CellTangent(degree=degree)

def build_bfs_tangent_expression(Lambda, inlet_v, degree=0):
    coords = Lambda.coordinates()
    conn   = Lambda.cells()  # (v0,v1) per cell

    # === BFS distances on the vertex graph ===
    adj = {v: [] for v in range(Lambda.num_vertices())}
    for a, b in conn:
        a = int(a); b = int(b)
        adj[a].append(b); adj[b].append(a)

    dist = {int(inlet_v): 0}
    q = deque([int(inlet_v)])
    while q:
        v = q.popleft()
        for nb in adj[v]:
            if nb not in dist:
                dist[nb] = dist[v] + 1
                q.append(nb)

    # === per-cell downstream tangent (from smaller dist -> larger dist) ===
    cell_mids = []
    cell_tans = []

    for c, (a, b) in enumerate(conn):
        a = int(a); b = int(b)
        da = dist.get(a, None)
        db = dist.get(b, None)
        if da is None or db is None:

            up, dn = a, b
        else:
            up, dn = (a, b) if da <= db else (b, a)

        x_up = coords[up]
        x_dn = coords[dn]
        t = x_dn - x_up
        t /= np.linalg.norm(t)

        cell_mids.append(0.5*(x_up + x_dn))
        cell_tans.append(t)

    cell_mids = np.array(cell_mids)
    cell_tans = np.array(cell_tans)
    kdt = cKDTree(cell_mids)

    class BFSTangent(UserExpression):
        def eval(self, values, x):
            _, idx = kdt.query((x[0], x[1], x[2]))
            values[:] = cell_tans[idx]
        def value_shape(self):
            return (3,)

    return BFSTangent(degree=degree)

def outlet_bn_geometric(Lambda, endpoints, Lambda_boundaries, t_vec, q1_value=1.0):
    coords = Lambda.coordinates()
    Lambda.init(0, 1)
    v2e = Lambda.topology()(0, 1)
    e2v = Lambda.topology()(1, 0)

    for v in endpoints:
        if Lambda_boundaries.array()[v] != 2:
            continue  # only outlets

        # endpoint has exactly one incident edge
        e = int(v2e(v)[0])
        vids = e2v(e)

        # other vertex on that edge
        v_other = int(vids[0] if vids[1] == v else vids[1])

        x_end   = coords[v]
        x_other = coords[v_other]

        # outward direction from interior -> endpoint
        d = x_end - x_other
        d_hat = d / np.linalg.norm(d)

        # evaluate your tangent (UserExpression) at edge midpoint
        x_mid = 0.5 * (x_end + x_other)
        tmid = np.array(t_vec(Point(*x_mid)))
        tmid = tmid / np.linalg.norm(tmid)

        bn = float(q1_value) * float(np.dot(tmid, d_hat))
        print(f"outlet vertex {v}: other={v_other}, bn≈{bn:+.6e}, tmid={tmid}, dout={d_hat}")

def branch_cells_from_outlet(Lambda, bif_vtx, outlet_vtx):
    """Return ordered list of cell indices from bif_vtx -> outlet_vtx."""
    coords = Lambda.coordinates()
    Lambda.init(0, 1)
    v2c = Lambda.topology()(0, 1)

    # In 1D, outlet vertex touches exactly 1 cell
    current_cell = int(v2c(outlet_vtx)[0])
    cells = [current_cell]

    # Walk toward the bifurcation: each interior vertex has 2 incident cells
    while True:
        cell = Cell(Lambda, current_cell)
        vids = cell.entities(0)

        # pick the vertext closest to bifurcation
        # Step by finding which vertex of this cell has degree 2 (interior) until we reach bif_vtx.
        if bif_vtx in vids:
            break  # reached bifurcation cell

        # choose the vertex that is not the endpoint and keep moving
        # Candidate next vertices are vids[0], vids[1]; one of them leads to another cell.
        next_vertex = None
        for v in vids:
            if v == outlet_vtx:
                continue
            # if this vertex is not the outlet and has 2 incident cells, it is interior
            if len(v2c(v)) == 2:
                next_vertex = v
                break

        if next_vertex is None:
            # fallback: choose vertex that is not outlet_vtx
            next_vertex = vids[0] if vids[1] == outlet_vtx else vids[1]

        # Move to the other incident cell across next_vertex
        inc = list(v2c(next_vertex))
        next_cell = inc[0] if inc[1] == current_cell else inc[1]

        current_cell = int(next_cell)
        cells.append(current_cell)

    return list(reversed(cells))  # bif -> outlet order

def rel_diff(a, b):
    return abs(a-b) / max(1e-16, 0.5*(abs(a)+abs(b)))

def classify_branch_cells(Lambda, bif_vtx):
    coords = Lambda.coordinates()
    bif_x = coords[bif_vtx]              # numpy array shape (3,)

    left = []
    right = []

    for c in range(Lambda.num_cells()):
        cell = Cell(Lambda, c)
        mpP = cell.midpoint()            # dolfin Point
        mp  = np.array(mpP.array())      # numpy array (3,)

        d = mp - bif_x                   # numpy - numpy works

        # ignore parent branch (z <= 0 relative to bif)
        if d[2] <= 0.0:
            continue

        # classify by x sign
        if mp[0] > 0.0:
            right.append((np.linalg.norm(d), c))
        else:
            left.append((np.linalg.norm(d), c))

    left.sort()
    right.sort()

    return [c for _, c in left], [c for _, c in right]

# May switch back to this function for general network
class radius_function(UserExpression):
    def __init__(self, G, node_list, kdtree, **kwargs):
        self.G = G
        self.node_list = node_list
        self.kdtree = kdtree
        super().__init__(**kwargs)
    def eval(self, value, x):
        _, idx = self.kdtree.query((x[0], x[1], x[2]))
        node = self.node_list[idx]
        value[0] = float(self.G.nodes[node]['radius'])
    def value_shape(self):
        return ()

# Currently using this function due to how mesh was created
class edge_radius_function(UserExpression):
    def __init__(self, edge_midpoints, edge_radii, kdtree, **kwargs):
        super().__init__(**kwargs)
        self.edge_midpoints = edge_midpoints
        self.edge_radii = edge_radii
        self.kdtree = kdtree

    def eval(self, value, x):
        _, idx = self.kdtree.query((x[0], x[1], x[2]))
        value[0] = float(self.edge_radii[idx])

    def value_shape(self):
        return ()

# %%
#@title dG Y bifurcation


# === Parameters ===
kappa     = Constant(0.1)
gamma_in  = 1.0
gamma_out = 1.0

mesh_vec = [2]

T    = 1.0

vtu3 = File("3d_Prediction_dGY_series.pvd") #1d prediction to be written
vtu1 = File("1d_Prediction_dGY_series.pvd") #3d prediction to be written

for i in mesh_vec:
  ncell   = 4*(2**i)
  G       = make_Y_bifurcation()
  mesh_3d = BoxMesh(Point(-0.5,-0.5,-0.5),Point(0.5,0.5,0.5),ncell,ncell,ncell)
  radius  = 0.05
  dt      = 0.1#/ncell
  inv_dt  = Constant(1.0/dt)
  tpts    = int(T/dt)

  # === Create Meshes ===
  G.make_mesh()
  Lambda, mf_Lambda = G.get_mesh()
  nodes, P_nodes, T_nodes = bif_tangents(G)

  Omega_boundaries = MeshFunction("size_t", mesh_3d, mesh_3d.topology().dim() - 1, 0)
  CompiledSubDomain("near(x[2], -0.5)").mark(Omega_boundaries, 1)
  CompiledSubDomain("near(x[2],  0.5)").mark(Omega_boundaries, 2)

  Lambda_boundaries = MeshFunction("size_t", Lambda, 0, 0)  # vertices
  coords = Lambda.coordinates()

  Lambda.init(0,1); v2e = Lambda.topology()(0,1)
  endpoints = [v for v in range(Lambda.num_vertices()) if v2e.size(v)==1]
  inlet_v = min(endpoints, key=lambda v: coords[v,2])
  t_vec = build_bfs_tangent_expression(Lambda, inlet_v, degree=0)

  Lambda_boundaries.array()[inlet_v] = 1
  for v in endpoints:
      if v != inlet_v:
          Lambda_boundaries.array()[v] = 2

  outlet_bn_geometric(Lambda, endpoints, Lambda_boundaries, t_vec, q1_value=1.0)


  # === Bifurcations ===
  bif_info = build_bifurcation_pairs(G) # constructing network tree
  bif_vertices = bifurcation_vertices_from_graph(Lambda, bif_info)
  left_cells, right_cells = classify_branch_cells(Lambda, bif_vertices[0])
  outlet_vs = [v for v in endpoints if Lambda_boundaries.array()[v] == 2]

  # === Split dS measure for junction and non-junction ==
  facet_tags = MeshFunction("size_t", Lambda, 0, 0)
  for vtx in bif_vertices:
      facet_tags.array()[vtx] = 1

  # === Build edge-midpoint KDTree for radius mapping ===
  pos = nx.get_node_attributes(G, "pos")
  edge_midpoints, edge_radii = [], []
  for (a, b) in G.edges():
      pa = np.array(pos[a]); pb = np.array(pos[b])
      pmid = 0.5*(pa + pb)
      r_edge = 0.5*(float(G.nodes[a]["radius"]) + float(G.nodes[b]["radius"]))
      edge_midpoints.append(pmid); edge_radii.append(r_edge)

  edge_kdtree = cKDTree(np.array(edge_midpoints))
  radius_map_G = edge_radius_function(np.array(edge_midpoints),
                                      np.array(edge_radii),
                                      edge_kdtree, degree=0)

  # === Perimeter and Area dependent on position ===
  D_area       = np.pi * radius_map_G**2
  D_perimeter  = 2.0  * np.pi * radius_map_G
  cylinder = Circle(radius=radius_map_G, degree=10)

  # === Function Spaces ===
  V3 = FunctionSpace(mesh_3d, "DG", 1)
  V1 = FunctionSpace(Lambda, "DG", 1)
  W = [V3, V1]
  u3, u1 = map(TrialFunction, W)
  v3, v1 = map(TestFunction, W)


  # === Initial concentration ===
  cinlet = Constant(5.0) # Amount of drug administered
  tau = 0.10  # Duration of administration
  pulse = Constant(0.0) # needed for conditional to stop drug administration


  # === Mesh Measures ===
  dxOmega = Measure("dx", domain=mesh_3d)
  dsOmega = Measure("ds", domain=mesh_3d, subdomain_data = Omega_boundaries)
  dSOmega = Measure("dS", domain=mesh_3d)
  dxLambda = Measure("dx", domain=Lambda)
  dsLambda = Measure("ds", domain=Lambda, subdomain_data=Lambda_boundaries)
  dSLambda = Measure("dS", domain=Lambda)
  dS_tag = Measure("dS", domain=Lambda, subdomain_data=facet_tags)
  dS_jun = dS_tag(1)
  dS_reg = dS_tag(0)
  n3d      = FacetNormal(mesh_3d)
  n1d      = FacetNormal(Lambda)
  h3d        = CellDiameter(mesh_3d)
  h1d        = CellDiameter(Lambda)
  alpha3d    = Constant(50.0)
  alpha1d    = Constant(50.0)
  alpha_bif  = Constant(50.0)
  alpha_boundary = Constant(50.0)
  epsilon  = Constant(1.0)
  perf1    = 1.0
  perf3    = 1.0
  g = Constant(0.0)

  # === Velocity terms ===
  q1     = Constant(1.0)
  q_t    = q1 * t_vec
  q3     = as_vector((0,0,q1))
  q3_pos = dot(q3,n3d('+'))

  # === Upwind ===
  q_norm_1d = dot(q_t('+'),n1d('+'))
  u1_up   = conditional(ge(q_norm_1d, 0.0), u1('-'), u1('+'))
  u3_up   = conditional(ge(q3_pos, 0.0), u3('-'), u3('+'))

  # === Averages ===
  u3_avg = Average(u3, Lambda, cylinder)
  v3_avg = Average(v3, Lambda, cylinder)


  # === Initialize time step ===
  uh3d_prev = interpolate(Expression('0.0',degree=1), V3)
  uh1d_prev = interpolate(Expression('0.0',degree=1), V1)

  vtu3 = File("3d_Prediction_dGY_series.pvd") #1d prediction to be written
  vtu1 = File("1d_Prediction_dGY_series.pvd") #3d prediction to be written


  # === Begin time-stepping ===
  t = 0.0
  for step in range(tpts):
    t += dt
    print(f"[INFO] Time step {step+1}/{tpts}, t = {t:.3}")
    pulse.assign(1.0 if t <= tau else 0.0) # injecting concentration only at the start of time period

    #cinlet.t = t #include if time dependent concentration

    # === Variational Forms ===
    a00 = inv_dt * (inner(u3, v3) * dxOmega) \
          + inner(grad(u3), grad(v3)) * dxOmega \
          + D_perimeter * kappa * inner(u3_avg, v3_avg) * dxLambda \
          - epsilon * dot(avg(grad(v3)),jump(u3,n3d))* dSOmega \
          - dot(jump(v3,n3d),avg(grad(u3))) * dSOmega \
          + (alpha3d/avg(h3d)) * dot(jump(v3,n3d),jump(u3,n3d)) * dSOmega \
          - inner(q3, grad(v3)) * u3 * dxOmega \
          + q3_pos * u3_up * jump(v3) * dSOmega \
          + dot(q3,n3d) * u3 * v3 * dsOmega(2)
          #- epsilon * dot(grad(v3),u3*n3d) * dsOmega - dot(v3*n3d,grad(u3)) * dsOmega \
          #+ (alpha_boundary/h3d)*v3*u3*dsOmega \
    a01 = -kappa * D_perimeter * inner(u1, v3_avg) * dxLambda
    a10 = -kappa * D_perimeter * inner(u3_avg, v1) * dxLambda
    a11 = D_area * inv_dt * u1 * v1 * dxLambda \
          + D_area * inner(grad(u1), grad(v1)) * dxLambda \
          - avg(D_area) * inner(avg(grad(u1)), jump(v1, n1d)) * dS_reg \
          - epsilon * avg(D_area) * inner(avg(grad(v1)), jump(u1, n1d)) * dS_reg \
          + (alpha1d/avg(h1d)) * jump(u1) * jump(v1) * dS_reg \
          + kappa * D_perimeter * u1 * v1 * dxLambda \
          - D_area * u1 * dot(q_t, grad(v1)) * dxLambda \
          + avg(D_area) * q_norm_1d * u1_up * jump(v1) * dS_reg \
          + D_area * dot(q_t,n1d) * u1 * v1 * dsLambda(2)


    f3 = Constant(0.0)
    f1 = Constant(0.0)

    L0  = inner(f3, v3) * dxOmega + inv_dt * inner(uh3d_prev, v3) * dxOmega \
        #+ (alpha_boundary/h3d)*v3*g*dsOmega - epsilon*dot(grad(v3), g*n3d)*dsOmega
    L1  = inner(f1, v1) * dxLambda + D_area * inv_dt * uh1d_prev * v1 * dxLambda \
        + pulse * D_area * q1 * cinlet * v1 * dsLambda(1) \



    a = [[a00, a01], [a10, a11]]
    L = [L0, L1]

   # bc3d = DirichletBC(V3, u3_exact, "on_boundary")
    W_bcs = [[], []]  # Boundaries now included in variational form for dG

    A, b = map(ii_assemble, (a, L))
    A, b = apply_bc(A, b, W_bcs)
    A, b = map(ii_convert, (A, b))

    # === Kirchhoff junction terms (diffusion, DG1) ===
    add_kirchhoff_junction_terms_P1DG(
        A, V3, V1, Lambda, bif_vertices,
        D_area_expr=D_area,
        eta_gamma=10.0,             # paper uses 10
        epsilon=1.0      # same epsilon as in variational form for SIPG
    )
    A.apply("insert")

    advection_junction_terms_P1DG(A, V3, V1, Lambda, bif_vertices, D_area_expr=D_area, q1_value=1.0)
    A.apply("insert")

    solver = PETScKrylovSolver()
    solver.set_operators(A, A)
    ksp = solver.ksp()

    opts = PETSc.Options()
    opts.setValue('ksp_type', 'gmres')
    opts.setValue('ksp_norm_type', 'unpreconditioned')
    opts.setValue('ksp_atol', 1E-14)
    opts.setValue('ksp_rtol', 1E-30)
    opts.setValue('ksp_monitor_true_residual', None)
    opts.setValue('pc_type', 'hypre')
    ksp.setFromOptions()

    x = b.copy()
    solver.solve(A,x,b)

    wh = ii_Function(W)
    wh.vector()[:] = x
    uh3d, uh1d = wh

    uh3d_prev.assign(uh3d)
    uh1d_prev.assign(uh1d)

    #avg_uh3d = Average(uh3d, Lambda, cylinder)
    #avg_u3d_exact = Average(u3_exact, Lambda, cylinder)


    # === Store Model Predictions ===
    vtkfile = File('3d_Prediction_dGY_series.pvd')
    uh3d.rename("u3","u3")
    vtu3 << (uh3d, t)

    vtkfile = File('1d_Prediction_dGY_series.pvd')
    uh1d.rename("u1","u1")
    vtu1 << (uh1d, t)


  # === Final time-step only ===
  File("3d_Prediction_final_dGY.pvd") << uh3d
  File("1d_Prediction_final_dGY.pvd") << uh1d
# Out:
# outlet vertex 6: other=16, bn≈+1.000000e+00, tmid=[0.57357644 0.         0.81915204], dout=[0.57357644 0.         0.81915204]
# outlet vertex 9: other=18, bn≈+1.000000e+00, tmid=[-0.57357644  0.          0.81915204], dout=[-0.57357644  0.          0.81915204]
# [INFO] Time step 1/10, t = 0.1
# Averaging over 18 cells: 100%|██████████| 18/18 [00:00<00:00, 614.82it/s]
#   0 KSP unpreconditioned resid norm 3.926990816987e-02 true resid norm 3.926990816987e-02 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 2.331929670791e-03 true resid norm 2.331929670787e-03 ||r(i)||/||b|| 5.938210144774e-02
#   2 KSP unpreconditioned resid norm 3.420219032723e-04 true resid norm 3.420219032715e-04 ||r(i)||/||b|| 8.709516248218e-03
#   3 KSP unpreconditioned resid norm 1.533904255165e-04 true resid norm 1.533904255097e-04 ||r(i)||/||b|| 3.906055110855e-03
#   4 KSP unpreconditioned resid norm 9.396728513582e-05 true resid norm 9.396728513056e-05 ||r(i)||/||b|| 2.392857266793e-03
#   5 KSP unpreconditioned resid norm 4.599025519144e-05 true resid norm 4.599025517310e-05 ||r(i)||/||b|| 1.171132231177e-03
#   6 KSP unpreconditioned resid norm 2.735466183854e-05 true resid norm 2.735466183233e-05 ||r(i)||/||b|| 6.965807435557e-04
#   7 KSP unpreconditioned resid norm 1.630284402229e-05 true resid norm 1.630284400896e-05 ||r(i)||/||b|| 4.151485136772e-04
#   8 KSP unpreconditioned resid norm 9.305238881448e-06 true resid norm 9.305238901909e-06 ||r(i)||/||b|| 2.369559628624e-04
#   9 KSP unpreconditioned resid norm 5.266988168182e-06 true resid norm 5.266988194879e-06 ||r(i)||/||b|| 1.341227530275e-04
#  10 KSP unpreconditioned resid norm 2.967203592444e-06 true resid norm 2.967203598306e-06 ||r(i)||/||b|| 7.555921917288e-05
#  11 KSP unpreconditioned resid norm 1.813373527999e-06 true resid norm 1.813373526792e-06 ||r(i)||/||b|| 4.617717767376e-05
#  12 KSP unpreconditioned resid norm 9.185849528776e-07 true resid norm 9.185849588386e-07 ||r(i)||/||b|| 2.339157389584e-05
#  13 KSP unpreconditioned resid norm 5.901353011158e-07 true resid norm 5.901353009458e-07 ||r(i)||/||b|| 1.502767203817e-05
#  14 KSP unpreconditioned resid norm 3.014392144962e-07 true resid norm 3.014392267417e-07 ||r(i)||/||b|| 7.676086876438e-06
#  15 KSP unpreconditioned resid norm 1.919182671262e-07 true resid norm 1.919182568294e-07 ||r(i)||/||b|| 4.887158279036e-06
#  16 KSP unpreconditioned resid norm 1.024493468079e-07 true resid norm 1.024493611507e-07 ||r(i)||/||b|| 2.608851558999e-06
#  17 KSP unpreconditioned resid norm 6.102556596334e-08 true resid norm 6.102555343384e-08 ||r(i)||/||b|| 1.554002957426e-06
#  18 KSP unpreconditioned resid norm 3.456636534367e-08 true resid norm 3.456636428414e-08 ||r(i)||/||b|| 8.802252384857e-07
#  19 KSP unpreconditioned resid norm 2.121228146838e-08 true resid norm 2.121227534429e-08 ||r(i)||/||b|| 5.401661560431e-07
#  20 KSP unpreconditioned resid norm 1.117663415159e-08 true resid norm 1.117663424360e-08 ||r(i)||/||b|| 2.846106539198e-07
#  21 KSP unpreconditioned resid norm 7.113999089089e-09 true resid norm 7.113985916120e-09 ||r(i)||/||b|| 1.811561637819e-07
#  22 KSP unpreconditioned resid norm 3.803548442165e-09 true resid norm 3.803566623616e-09 ||r(i)||/||b|| 9.685702872446e-08
#  23 KSP unpreconditioned resid norm 2.301146795905e-09 true resid norm 2.301147614668e-09 ||r(i)||/||b|| 5.859824282536e-08
#  24 KSP unpreconditioned resid norm 1.264439586836e-09 true resid norm 1.264451460891e-09 ||r(i)||/||b|| 3.219899204809e-08
#  25 KSP unpreconditioned resid norm 7.615875564176e-10 true resid norm 7.615809347221e-10 ||r(i)||/||b|| 1.939349925209e-08
#  26 KSP unpreconditioned resid norm 4.243040735271e-10 true resid norm 4.243146347854e-10 ||r(i)||/||b|| 1.080508344837e-08
#  27 KSP unpreconditioned resid norm 2.603501596563e-10 true resid norm 2.603460859580e-10 ||r(i)||/||b|| 6.629658639175e-09
#  28 KSP unpreconditioned resid norm 1.377469719835e-10 true resid norm 1.377495274474e-10 ||r(i)||/||b|| 3.507762912291e-09
#  29 KSP unpreconditioned resid norm 8.590951550249e-11 true resid norm 8.591038818390e-11 ||r(i)||/||b|| 2.187690070786e-09
#  30 KSP unpreconditioned resid norm 4.525848163569e-11 true resid norm 4.525848163569e-11 ||r(i)||/||b|| 1.152497771065e-09
#  31 KSP unpreconditioned resid norm 3.123690834727e-11 true resid norm 3.123644770887e-11 ||r(i)||/||b|| 7.954296091998e-10
#  32 KSP unpreconditioned resid norm 2.058460126347e-11 true resid norm 2.059065939829e-11 ||r(i)||/||b|| 5.243368359615e-10
#  33 KSP unpreconditioned resid norm 1.260176005034e-11 true resid norm 1.260722081386e-11 ||r(i)||/||b|| 3.210402417882e-10
#  34 KSP unpreconditioned resid norm 7.637862651061e-12 true resid norm 7.641204064970e-12 ||r(i)||/||b|| 1.945816636982e-10
#  35 KSP unpreconditioned resid norm 4.312905806920e-12 true resid norm 4.325876979084e-12 ||r(i)||/||b|| 1.101575527086e-10
#  36 KSP unpreconditioned resid norm 2.388589428185e-12 true resid norm 2.395332560943e-12 ||r(i)||/||b|| 6.099664278768e-11
#  37 KSP unpreconditioned resid norm 1.352704763545e-12 true resid norm 1.367769928123e-12 ||r(i)||/||b|| 3.482997521173e-11
#  38 KSP unpreconditioned resid norm 7.412575445434e-13 true resid norm 7.640700636666e-13 ||r(i)||/||b|| 1.945688440017e-11
#  39 KSP unpreconditioned resid norm 4.230056448953e-13 true resid norm 4.490247830576e-13 ||r(i)||/||b|| 1.143432220710e-11
#  40 KSP unpreconditioned resid norm 2.352079427677e-13 true resid norm 3.109528957193e-13 ||r(i)||/||b|| 7.918350467594e-12
#  41 KSP unpreconditioned resid norm 1.437436853326e-13 true resid norm 2.687167926382e-13 ||r(i)||/||b|| 6.842816934427e-12
#  42 KSP unpreconditioned resid norm 7.713112856442e-14 true resid norm 2.376847571065e-13 ||r(i)||/||b|| 6.052592638576e-12
#  43 KSP unpreconditioned resid norm 4.622092762194e-14 true resid norm 2.291349345958e-13 ||r(i)||/||b|| 5.834873196154e-12
#  44 KSP unpreconditioned resid norm 2.633107469537e-14 true resid norm 2.250928272028e-13 ||r(i)||/||b|| 5.731941776617e-12
#  45 KSP unpreconditioned resid norm 1.498835430513e-14 true resid norm 2.256802860383e-13 ||r(i)||/||b|| 5.746901293022e-12
#  46 KSP unpreconditioned resid norm 8.834384360515e-15 true resid norm 1.355901983818e-13 ||r(i)||/||b|| 3.452776049165e-12
# [INFO] Time step 2/10, t = 0.2
#   0 KSP unpreconditioned resid norm 6.768826911365e-03 true resid norm 6.768826911365e-03 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 1.237996251653e-03 true resid norm 1.237996251661e-03 ||r(i)||/||b|| 1.828967216731e-01
#   2 KSP unpreconditioned resid norm 2.350227190392e-04 true resid norm 2.350227190402e-04 ||r(i)||/||b|| 3.472133681622e-02
#   3 KSP unpreconditioned resid norm 1.007778476335e-04 true resid norm 1.007778476351e-04 ||r(i)||/||b|| 1.488852484407e-02
#   4 KSP unpreconditioned resid norm 6.406839901453e-05 true resid norm 6.406839901289e-05 ||r(i)||/||b|| 9.465214556648e-03
#   5 KSP unpreconditioned resid norm 3.035005176529e-05 true resid norm 3.035005176699e-05 ||r(i)||/||b|| 4.483797881732e-03
#   6 KSP unpreconditioned resid norm 1.872242866236e-05 true resid norm 1.872242866212e-05 ||r(i)||/||b|| 2.765978345625e-03
#   7 KSP unpreconditioned resid norm 1.117569072899e-05 true resid norm 1.117569073645e-05 ||r(i)||/||b|| 1.651052816506e-03
#   8 KSP unpreconditioned resid norm 5.742970894627e-06 true resid norm 5.742970894739e-06 ||r(i)||/||b|| 8.484440465003e-04
#   9 KSP unpreconditioned resid norm 3.490300644137e-06 true resid norm 3.490300651887e-06 ||r(i)||/||b|| 5.156433600077e-04
#  10 KSP unpreconditioned resid norm 2.018497376583e-06 true resid norm 2.018497377515e-06 ||r(i)||/||b|| 2.982049037368e-04
#  11 KSP unpreconditioned resid norm 1.179370762851e-06 true resid norm 1.179370758547e-06 ||r(i)||/||b|| 1.742356207347e-04
#  12 KSP unpreconditioned resid norm 6.821258644152e-07 true resid norm 6.821258645792e-07 ||r(i)||/||b|| 1.007746059267e-04
#  13 KSP unpreconditioned resid norm 3.931498995699e-07 true resid norm 3.931498962634e-07 ||r(i)||/||b|| 5.808242719330e-05
#  14 KSP unpreconditioned resid norm 2.319042649200e-07 true resid norm 2.319042660436e-07 ||r(i)||/||b|| 3.426062877368e-05
#  15 KSP unpreconditioned resid norm 1.333077172392e-07 true resid norm 1.333077174749e-07 ||r(i)||/||b|| 1.969436051779e-05
#  16 KSP unpreconditioned resid norm 7.972801219987e-08 true resid norm 7.972800865967e-08 ||r(i)||/||b|| 1.177870400642e-05
#  17 KSP unpreconditioned resid norm 4.354753270434e-08 true resid norm 4.354753143476e-08 ||r(i)||/||b|| 6.433541883254e-06
#  18 KSP unpreconditioned resid norm 2.521552146056e-08 true resid norm 2.521551962240e-08 ||r(i)||/||b|| 3.725242195226e-06
#  19 KSP unpreconditioned resid norm 1.534221478897e-08 true resid norm 1.534221444178e-08 ||r(i)||/||b|| 2.266598724222e-06
#  20 KSP unpreconditioned resid norm 7.805790958996e-09 true resid norm 7.805784019132e-09 ||r(i)||/||b|| 1.153195985264e-06
#  21 KSP unpreconditioned resid norm 5.006901981368e-09 true resid norm 5.006899807895e-09 ||r(i)||/||b|| 7.396997845355e-07
#  22 KSP unpreconditioned resid norm 2.609259410674e-09 true resid norm 2.609256345731e-09 ||r(i)||/||b|| 3.854813219333e-07
#  23 KSP unpreconditioned resid norm 1.602787991095e-09 true resid norm 1.602788034253e-09 ||r(i)||/||b|| 2.367896321239e-07
#  24 KSP unpreconditioned resid norm 8.834472557138e-10 true resid norm 8.834500010347e-10 ||r(i)||/||b|| 1.305174460218e-07
#  25 KSP unpreconditioned resid norm 5.222114821068e-10 true resid norm 5.222118661112e-10 ||r(i)||/||b|| 7.714953757118e-08
#  26 KSP unpreconditioned resid norm 3.042834872797e-10 true resid norm 3.042841688295e-10 ||r(i)||/||b|| 4.495375237305e-08
#  27 KSP unpreconditioned resid norm 1.770548588983e-10 true resid norm 1.770614454107e-10 ||r(i)||/||b|| 2.615836506520e-08
#  28 KSP unpreconditioned resid norm 1.014741344986e-10 true resid norm 1.014760379138e-10 ||r(i)||/||b|| 1.499167274368e-08
#  29 KSP unpreconditioned resid norm 5.984183475743e-11 true resid norm 5.984335644870e-11 ||r(i)||/||b|| 8.841023301722e-09
#  30 KSP unpreconditioned resid norm 3.353012386009e-11 true resid norm 3.353012386009e-11 ||r(i)||/||b|| 4.953609288456e-09
#  31 KSP unpreconditioned resid norm 2.350824714288e-11 true resid norm 2.350756882659e-11 ||r(i)||/||b|| 3.472916228235e-09
#  32 KSP unpreconditioned resid norm 1.503431820735e-11 true resid norm 1.503270735431e-11 ||r(i)||/||b|| 2.220873358288e-09
#  33 KSP unpreconditioned resid norm 9.507625048945e-12 true resid norm 9.510635925199e-12 ||r(i)||/||b|| 1.405064134412e-09
#  34 KSP unpreconditioned resid norm 5.562274334787e-12 true resid norm 5.563280624139e-12 ||r(i)||/||b|| 8.218973090888e-10
#  35 KSP unpreconditioned resid norm 3.200883112844e-12 true resid norm 3.200984708074e-12 ||r(i)||/||b|| 4.729009546247e-10
#  36 KSP unpreconditioned resid norm 1.800424803349e-12 true resid norm 1.804300995367e-12 ||r(i)||/||b|| 2.665603684351e-10
#  37 KSP unpreconditioned resid norm 9.928881272148e-13 true resid norm 1.001123696894e-12 ||r(i)||/||b|| 1.479020973654e-10
#  38 KSP unpreconditioned resid norm 5.699935622281e-13 true resid norm 5.852719211287e-13 ||r(i)||/||b|| 8.646578333182e-11
#  39 KSP unpreconditioned resid norm 3.085763108371e-13 true resid norm 3.256859785186e-13 ||r(i)||/||b|| 4.811557198659e-11
#  40 KSP unpreconditioned resid norm 1.833912611206e-13 true resid norm 2.176551724149e-13 ||r(i)||/||b|| 3.215552344076e-11
#  41 KSP unpreconditioned resid norm 1.054412041702e-13 true resid norm 1.529534260516e-13 ||r(i)||/||b|| 2.259674062499e-11
#  42 KSP unpreconditioned resid norm 5.863644350782e-14 true resid norm 1.263223432665e-13 ||r(i)||/||b|| 1.866236866752e-11
#  43 KSP unpreconditioned resid norm 3.471865739478e-14 true resid norm 1.315199103418e-13 ||r(i)||/||b|| 1.943023688801e-11
#  44 KSP unpreconditioned resid norm 1.975678699180e-14 true resid norm 1.401899349004e-13 ||r(i)||/||b|| 2.071111238862e-11
#  45 KSP unpreconditioned resid norm 1.144198194259e-14 true resid norm 1.274929293962e-13 ||r(i)||/||b|| 1.883530648157e-11
#  46 KSP unpreconditioned resid norm 6.570103537648e-15 true resid norm 1.574476723735e-13 ||r(i)||/||b|| 2.326070298964e-11
# [INFO] Time step 3/10, t = 0.3
#   0 KSP unpreconditioned resid norm 3.562540839749e-03 true resid norm 3.562540839749e-03 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 5.273339380895e-04 true resid norm 5.273339380946e-04 ||r(i)||/||b|| 1.480218646790e-01
#   2 KSP unpreconditioned resid norm 1.617877199450e-04 true resid norm 1.617877199459e-04 ||r(i)||/||b|| 4.541357621527e-02
#   3 KSP unpreconditioned resid norm 6.879810825874e-05 true resid norm 6.879810825892e-05 ||r(i)||/||b|| 1.931152830343e-02
#   4 KSP unpreconditioned resid norm 4.492525362495e-05 true resid norm 4.492525362578e-05 ||r(i)||/||b|| 1.261045294542e-02
#   5 KSP unpreconditioned resid norm 2.130843759594e-05 true resid norm 2.130843759638e-05 ||r(i)||/||b|| 5.981247248772e-03
#   6 KSP unpreconditioned resid norm 1.298184094909e-05 true resid norm 1.298184094714e-05 ||r(i)||/||b|| 3.643983755161e-03
#   7 KSP unpreconditioned resid norm 7.601319203632e-06 true resid norm 7.601319203768e-06 ||r(i)||/||b|| 2.133679176097e-03
#   8 KSP unpreconditioned resid norm 4.128827655130e-06 true resid norm 4.128827658035e-06 ||r(i)||/||b|| 1.158955881142e-03
#   9 KSP unpreconditioned resid norm 2.424291966591e-06 true resid norm 2.424291970014e-06 ||r(i)||/||b|| 6.804952080732e-04
#  10 KSP unpreconditioned resid norm 1.430023311162e-06 true resid norm 1.430023310396e-06 ||r(i)||/||b|| 4.014054504137e-04
#  11 KSP unpreconditioned resid norm 8.003074251632e-07 true resid norm 8.003074236820e-07 ||r(i)||/||b|| 2.246451225913e-04
#  12 KSP unpreconditioned resid norm 5.049188430367e-07 true resid norm 5.049188472301e-07 ||r(i)||/||b|| 1.417299814774e-04
#  13 KSP unpreconditioned resid norm 2.667665030141e-07 true resid norm 2.667665017759e-07 ||r(i)||/||b|| 7.488096664031e-05
#  14 KSP unpreconditioned resid norm 1.682514309348e-07 true resid norm 1.682514318323e-07 ||r(i)||/||b|| 4.722793068225e-05
#  15 KSP unpreconditioned resid norm 8.918236900336e-08 true resid norm 8.918236922086e-08 ||r(i)||/||b|| 2.503336052343e-05
#  16 KSP unpreconditioned resid norm 5.435924801593e-08 true resid norm 5.435924909761e-08 ||r(i)||/||b|| 1.525856166787e-05
#  17 KSP unpreconditioned resid norm 2.979372959767e-08 true resid norm 2.979373058156e-08 ||r(i)||/||b|| 8.363056571630e-06
#  18 KSP unpreconditioned resid norm 1.699358931045e-08 true resid norm 1.699358736919e-08 ||r(i)||/||b|| 4.770075104709e-06
#  19 KSP unpreconditioned resid norm 1.015817817258e-08 true resid norm 1.015817078955e-08 ||r(i)||/||b|| 2.851383674319e-06
#  20 KSP unpreconditioned resid norm 5.275637757063e-09 true resid norm 5.275641172354e-09 ||r(i)||/||b|| 1.480864756269e-06
#  21 KSP unpreconditioned resid norm 3.326423603361e-09 true resid norm 3.326424133407e-09 ||r(i)||/||b|| 9.337223860828e-07
#  22 KSP unpreconditioned resid norm 1.848385873432e-09 true resid norm 1.848386778661e-09 ||r(i)||/||b|| 5.188394636878e-07
#  23 KSP unpreconditioned resid norm 1.088454763194e-09 true resid norm 1.088452531692e-09 ||r(i)||/||b|| 3.055270327144e-07
#  24 KSP unpreconditioned resid norm 6.210992176344e-10 true resid norm 6.211014997511e-10 ||r(i)||/||b|| 1.743422820087e-07
#  25 KSP unpreconditioned resid norm 3.582748720934e-10 true resid norm 3.582736807948e-10 ||r(i)||/||b|| 1.005668978717e-07
#  26 KSP unpreconditioned resid norm 2.130871718658e-10 true resid norm 2.130863792312e-10 ||r(i)||/||b|| 5.981303480194e-08
#  27 KSP unpreconditioned resid norm 1.212355330534e-10 true resid norm 1.212354548925e-10 ||r(i)||/||b|| 3.403061476231e-08
#  28 KSP unpreconditioned resid norm 7.063019706994e-11 true resid norm 7.063058879759e-11 ||r(i)||/||b|| 1.982590290883e-08
#  29 KSP unpreconditioned resid norm 4.041884727879e-11 true resid norm 4.041975965422e-11 ||r(i)||/||b|| 1.134576738131e-08
#  30 KSP unpreconditioned resid norm 2.366663719346e-11 true resid norm 2.366663719346e-11 ||r(i)||/||b|| 6.643190424487e-09
#  31 KSP unpreconditioned resid norm 1.636869289604e-11 true resid norm 1.637068759338e-11 ||r(i)||/||b|| 4.595228049242e-09
#  32 KSP unpreconditioned resid norm 1.046140738414e-11 true resid norm 1.045921556938e-11 ||r(i)||/||b|| 2.935886503441e-09
#  33 KSP unpreconditioned resid norm 6.566705864433e-12 true resid norm 6.568018384040e-12 ||r(i)||/||b|| 1.843633148218e-09
#  34 KSP unpreconditioned resid norm 3.854324533963e-12 true resid norm 3.855636841315e-12 ||r(i)||/||b|| 1.082271618699e-09
#  35 KSP unpreconditioned resid norm 2.261524604593e-12 true resid norm 2.264921455216e-12 ||r(i)||/||b|| 6.357601378053e-10
#  36 KSP unpreconditioned resid norm 1.251455333448e-12 true resid norm 1.252619910295e-12 ||r(i)||/||b|| 3.516085756320e-10
#  37 KSP unpreconditioned resid norm 7.106809362444e-13 true resid norm 7.188048581902e-13 ||r(i)||/||b|| 2.017674717354e-10
#  38 KSP unpreconditioned resid norm 4.011136629789e-13 true resid norm 4.102382680703e-13 ||r(i)||/||b|| 1.151532814707e-10
#  39 KSP unpreconditioned resid norm 2.210966788335e-13 true resid norm 2.348704590804e-13 ||r(i)||/||b|| 6.592779413498e-11
#  40 KSP unpreconditioned resid norm 1.324534239211e-13 true resid norm 1.641167173414e-13 ||r(i)||/||b|| 4.606732237573e-11
#  41 KSP unpreconditioned resid norm 7.274797945771e-14 true resid norm 1.094750221671e-13 ||r(i)||/||b|| 3.072947850749e-11
#  42 KSP unpreconditioned resid norm 4.112731910865e-14 true resid norm 8.704767842881e-14 ||r(i)||/||b|| 2.443415594218e-11
#  43 KSP unpreconditioned resid norm 2.468354443464e-14 true resid norm 7.987297096282e-14 ||r(i)||/||b|| 2.242022605654e-11
#  44 KSP unpreconditioned resid norm 1.347525001285e-14 true resid norm 6.928746241451e-14 ||r(i)||/||b|| 1.944888929874e-11
#  45 KSP unpreconditioned resid norm 8.162889379101e-15 true resid norm 7.402459325788e-14 ||r(i)||/||b|| 2.077859499376e-11
# [INFO] Time step 4/10, t = 0.4
#   0 KSP unpreconditioned resid norm 2.142133203604e-03 true resid norm 2.142133203604e-03 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 2.424733905868e-04 true resid norm 2.424733905836e-04 ||r(i)||/||b|| 1.131924896993e-01
#   2 KSP unpreconditioned resid norm 1.178925911444e-04 true resid norm 1.178925911441e-04 ||r(i)||/||b|| 5.503513551153e-02
#   3 KSP unpreconditioned resid norm 5.122390067908e-05 true resid norm 5.122390067933e-05 ||r(i)||/||b|| 2.391256556462e-02
#   4 KSP unpreconditioned resid norm 3.380616296109e-05 true resid norm 3.380616296115e-05 ||r(i)||/||b|| 1.578154099113e-02
#   5 KSP unpreconditioned resid norm 1.581567708684e-05 true resid norm 1.581567708644e-05 ||r(i)||/||b|| 7.383143615826e-03
#   6 KSP unpreconditioned resid norm 9.472546661897e-06 true resid norm 9.472546662138e-06 ||r(i)||/||b|| 4.422015702012e-03
#   7 KSP unpreconditioned resid norm 5.393088415032e-06 true resid norm 5.393088411786e-06 ||r(i)||/||b|| 2.517625142411e-03
#   8 KSP unpreconditioned resid norm 3.213170135435e-06 true resid norm 3.213170134347e-06 ||r(i)||/||b|| 1.499986148826e-03
#   9 KSP unpreconditioned resid norm 1.745228165536e-06 true resid norm 1.745228167336e-06 ||r(i)||/||b|| 8.147150533867e-04
#  10 KSP unpreconditioned resid norm 1.021565055690e-06 true resid norm 1.021565055246e-06 ||r(i)||/||b|| 4.768914713276e-04
#  11 KSP unpreconditioned resid norm 6.038500106638e-07 true resid norm 6.038500100641e-07 ||r(i)||/||b|| 2.818919052504e-04
#  12 KSP unpreconditioned resid norm 3.739769027531e-07 true resid norm 3.739769018404e-07 ||r(i)||/||b|| 1.745815345242e-04
#  13 KSP unpreconditioned resid norm 1.905425081031e-07 true resid norm 1.905425073238e-07 ||r(i)||/||b|| 8.894988743148e-05
#  14 KSP unpreconditioned resid norm 1.249428903385e-07 true resid norm 1.249428900039e-07 ||r(i)||/||b|| 5.832638689025e-05
#  15 KSP unpreconditioned resid norm 6.157083775340e-08 true resid norm 6.157083713820e-08 ||r(i)||/||b|| 2.874276773947e-05
#  16 KSP unpreconditioned resid norm 3.913593689557e-08 true resid norm 3.913593697843e-08 ||r(i)||/||b|| 1.826960943072e-05
#  17 KSP unpreconditioned resid norm 2.082641635388e-08 true resid norm 2.082641873278e-08 ||r(i)||/||b|| 9.722279967342e-06
#  18 KSP unpreconditioned resid norm 1.192468859696e-08 true resid norm 1.192468683135e-08 ||r(i)||/||b|| 5.566734510855e-06
#  19 KSP unpreconditioned resid norm 7.115864837925e-09 true resid norm 7.115866371776e-09 ||r(i)||/||b|| 3.321859891721e-06
#  20 KSP unpreconditioned resid norm 3.773128428819e-09 true resid norm 3.773127777615e-09 ||r(i)||/||b|| 1.761388027256e-06
#  21 KSP unpreconditioned resid norm 2.301537190734e-09 true resid norm 2.301534755434e-09 ||r(i)||/||b|| 1.074412530258e-06
#  22 KSP unpreconditioned resid norm 1.342929070966e-09 true resid norm 1.342928326926e-09 ||r(i)||/||b|| 6.269116806867e-07
#  23 KSP unpreconditioned resid norm 7.721648169000e-10 true resid norm 7.721660087334e-10 ||r(i)||/||b|| 3.604659166079e-07
#  24 KSP unpreconditioned resid norm 4.453572892506e-10 true resid norm 4.453557155666e-10 ||r(i)||/||b|| 2.079029048321e-07
#  25 KSP unpreconditioned resid norm 2.595999854092e-10 true resid norm 2.596003727949e-10 ||r(i)||/||b|| 1.211877825142e-07
#  26 KSP unpreconditioned resid norm 1.507332103322e-10 true resid norm 1.507336760738e-10 ||r(i)||/||b|| 7.036615455109e-08
#  27 KSP unpreconditioned resid norm 8.717344132993e-11 true resid norm 8.717248778449e-11 ||r(i)||/||b|| 4.069424237383e-08
#  28 KSP unpreconditioned resid norm 5.129305095968e-11 true resid norm 5.129269657813e-11 ||r(i)||/||b|| 2.394468116727e-08
#  29 KSP unpreconditioned resid norm 2.836038873977e-11 true resid norm 2.836141618188e-11 ||r(i)||/||b|| 1.323980046346e-08
#  30 KSP unpreconditioned resid norm 1.692550715091e-11 true resid norm 1.692550715091e-11 ||r(i)||/||b|| 7.901239345171e-09
#  31 KSP unpreconditioned resid norm 1.177094446300e-11 true resid norm 1.177152415952e-11 ||r(i)||/||b|| 5.495234441869e-09
#  32 KSP unpreconditioned resid norm 7.247917411279e-12 true resid norm 7.247856923900e-12 ||r(i)||/||b|| 3.383476299096e-09
#  33 KSP unpreconditioned resid norm 4.403619255814e-12 true resid norm 4.406921741002e-12 ||r(i)||/||b|| 2.057258499886e-09
#  34 KSP unpreconditioned resid norm 2.563103574045e-12 true resid norm 2.560780401894e-12 ||r(i)||/||b|| 1.195434717872e-09
#  35 KSP unpreconditioned resid norm 1.499366317668e-12 true resid norm 1.500852608913e-12 ||r(i)||/||b|| 7.006345853693e-10
#  36 KSP unpreconditioned resid norm 8.724411784261e-13 true resid norm 8.734065233944e-13 ||r(i)||/||b|| 4.077274568757e-10
#  37 KSP unpreconditioned resid norm 5.099919396699e-13 true resid norm 5.138382172122e-13 ||r(i)||/||b|| 2.398722060550e-10
#  38 KSP unpreconditioned resid norm 2.801870373778e-13 true resid norm 2.858329917146e-13 ||r(i)||/||b|| 1.334338085203e-10
#  39 KSP unpreconditioned resid norm 1.619936019286e-13 true resid norm 1.713923464571e-13 ||r(i)||/||b|| 8.001012549952e-11
#  40 KSP unpreconditioned resid norm 9.406393705350e-14 true resid norm 1.227828108737e-13 ||r(i)||/||b|| 5.731800929426e-11
#  41 KSP unpreconditioned resid norm 5.243231274878e-14 true resid norm 9.022273791761e-14 ||r(i)||/||b|| 4.211817349445e-11
#  42 KSP unpreconditioned resid norm 2.991821612519e-14 true resid norm 7.544012057396e-14 ||r(i)||/||b|| 3.521728735031e-11
#  43 KSP unpreconditioned resid norm 1.765157950672e-14 true resid norm 7.439150274646e-14 ||r(i)||/||b|| 3.472776698540e-11
#  44 KSP unpreconditioned resid norm 9.778957288324e-15 true resid norm 6.231470605955e-14 ||r(i)||/||b|| 2.909002388587e-11
# [INFO] Time step 5/10, t = 0.5
#   0 KSP unpreconditioned resid norm 1.341617572659e-03 true resid norm 1.341617572659e-03 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 1.408231827221e-04 true resid norm 1.408231827245e-04 ||r(i)||/||b|| 1.049652192952e-01
#   2 KSP unpreconditioned resid norm 9.233889652963e-05 true resid norm 9.233889652935e-05 ||r(i)||/||b|| 6.882654074539e-02
#   3 KSP unpreconditioned resid norm 4.043256637520e-05 true resid norm 4.043256637536e-05 ||r(i)||/||b|| 3.013717709081e-02
#   4 KSP unpreconditioned resid norm 2.645971317053e-05 true resid norm 2.645971317025e-05 ||r(i)||/||b|| 1.972224701694e-02
#   5 KSP unpreconditioned resid norm 1.184566465509e-05 true resid norm 1.184566465486e-05 ||r(i)||/||b|| 8.829389906828e-03
#   6 KSP unpreconditioned resid norm 7.046168124370e-06 true resid norm 7.046168123113e-06 ||r(i)||/||b|| 5.251994507755e-03
#   7 KSP unpreconditioned resid norm 3.927652451861e-06 true resid norm 3.927652451651e-06 ||r(i)||/||b|| 2.927549945448e-03
#   8 KSP unpreconditioned resid norm 2.321681497040e-06 true resid norm 2.321681498057e-06 ||r(i)||/||b|| 1.730509159518e-03
#   9 KSP unpreconditioned resid norm 1.280292871983e-06 true resid norm 1.280292872946e-06 ||r(i)||/||b|| 9.542904766882e-04
#  10 KSP unpreconditioned resid norm 7.348537477209e-07 true resid norm 7.348537486979e-07 ||r(i)||/||b|| 5.477371224659e-04
#  11 KSP unpreconditioned resid norm 4.362039295247e-07 true resid norm 4.362039304317e-07 ||r(i)||/||b|| 3.251328391347e-04
#  12 KSP unpreconditioned resid norm 2.736192209436e-07 true resid norm 2.736192192424e-07 ||r(i)||/||b|| 2.039472535382e-04
#  13 KSP unpreconditioned resid norm 1.353483390548e-07 true resid norm 1.353483380023e-07 ||r(i)||/||b|| 1.008844403656e-04
#  14 KSP unpreconditioned resid norm 8.960744067916e-08 true resid norm 8.960744178692e-08 ||r(i)||/||b|| 6.679059935784e-05
#  15 KSP unpreconditioned resid norm 4.406412345603e-08 true resid norm 4.406412365775e-08 ||r(i)||/||b|| 3.284402690881e-05
#  16 KSP unpreconditioned resid norm 2.785698339096e-08 true resid norm 2.785698343402e-08 ||r(i)||/||b|| 2.076372880150e-05
#  17 KSP unpreconditioned resid norm 1.528220228885e-08 true resid norm 1.528220153703e-08 ||r(i)||/||b|| 1.139087758573e-05
#  18 KSP unpreconditioned resid norm 8.699750051389e-09 true resid norm 8.699749928851e-09 ||r(i)||/||b|| 6.484522941667e-06
#  19 KSP unpreconditioned resid norm 5.111519964979e-09 true resid norm 5.111519733817e-09 ||r(i)||/||b|| 3.809967786637e-06
#  20 KSP unpreconditioned resid norm 2.792413136294e-09 true resid norm 2.792413047886e-09 ||r(i)||/||b|| 2.081377811974e-06
#  21 KSP unpreconditioned resid norm 1.648176581403e-09 true resid norm 1.648176679000e-09 ||r(i)||/||b|| 1.228499620598e-06
#  22 KSP unpreconditioned resid norm 9.605898963083e-10 true resid norm 9.605910849310e-10 ||r(i)||/||b|| 7.159947100477e-07
#  23 KSP unpreconditioned resid norm 5.632204615350e-10 true resid norm 5.632186436062e-10 ||r(i)||/||b|| 4.198056548185e-07
#  24 KSP unpreconditioned resid norm 3.201076197597e-10 true resid norm 3.201068893666e-10 ||r(i)||/||b|| 2.385977165849e-07
#  25 KSP unpreconditioned resid norm 1.889101462535e-10 true resid norm 1.889091036183e-10 ||r(i)||/||b|| 1.408069687429e-07
#  26 KSP unpreconditioned resid norm 1.103341695196e-10 true resid norm 1.103345566095e-10 ||r(i)||/||b|| 8.223994591159e-08
#  27 KSP unpreconditioned resid norm 6.389577271755e-11 true resid norm 6.389517031698e-11 ||r(i)||/||b|| 4.762547213088e-08
#  28 KSP unpreconditioned resid norm 3.809645886371e-11 true resid norm 3.809693523910e-11 ||r(i)||/||b|| 2.839627030495e-08
#  29 KSP unpreconditioned resid norm 2.099830497923e-11 true resid norm 2.099793155592e-11 ||r(i)||/||b|| 1.565120492146e-08
#  30 KSP unpreconditioned resid norm 1.241183873048e-11 true resid norm 1.241183873048e-11 ||r(i)||/||b|| 9.251398448723e-09
#  31 KSP unpreconditioned resid norm 8.600098741968e-12 true resid norm 8.600894008204e-12 ||r(i)||/||b|| 6.410838813893e-09
#  32 KSP unpreconditioned resid norm 5.287905221497e-12 true resid norm 5.287067417780e-12 ||r(i)||/||b|| 3.940815568852e-09
#  33 KSP unpreconditioned resid norm 3.213207704846e-12 true resid norm 3.212663593429e-12 ||r(i)||/||b|| 2.394619494333e-09
#  34 KSP unpreconditioned resid norm 1.831965512064e-12 true resid norm 1.832155960585e-12 ||r(i)||/||b|| 1.365632053368e-09
#  35 KSP unpreconditioned resid norm 1.077636290444e-12 true resid norm 1.077937190810e-12 ||r(i)||/||b|| 8.034608466505e-10
#  36 KSP unpreconditioned resid norm 6.336272721960e-13 true resid norm 6.351686940732e-13 ||r(i)||/||b|| 4.734349840203e-10
#  37 KSP unpreconditioned resid norm 3.702565513251e-13 true resid norm 3.728066076289e-13 ||r(i)||/||b|| 2.778784470525e-10
#  38 KSP unpreconditioned resid norm 2.059738520233e-13 true resid norm 2.099463205019e-13 ||r(i)||/||b|| 1.564874557254e-10
#  39 KSP unpreconditioned resid norm 1.189114506634e-13 true resid norm 1.270048902202e-13 ||r(i)||/||b|| 9.466549395924e-11
#  40 KSP unpreconditioned resid norm 6.739112062552e-14 true resid norm 7.939766261405e-14 ||r(i)||/||b|| 5.918054759575e-11
#  41 KSP unpreconditioned resid norm 3.836719600443e-14 true resid norm 6.105529623224e-14 ||r(i)||/||b|| 4.550871833859e-11
#  42 KSP unpreconditioned resid norm 2.199854122653e-14 true resid norm 4.113836743506e-14 ||r(i)||/||b|| 3.066325924274e-11
#  43 KSP unpreconditioned resid norm 1.274880300652e-14 true resid norm 4.026036259955e-14 ||r(i)||/||b|| 3.000882175369e-11
#  44 KSP unpreconditioned resid norm 7.433692362132e-15 true resid norm 4.399815764896e-14 ||r(i)||/||b|| 3.279485789811e-11
# [INFO] Time step 6/10, t = 0.6
#   0 KSP unpreconditioned resid norm 8.537459873809e-04 true resid norm 8.537459873809e-04 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 1.034306909050e-04 true resid norm 1.034306909031e-04 ||r(i)||/||b|| 1.211492556708e-01
#   2 KSP unpreconditioned resid norm 7.560402233746e-05 true resid norm 7.560402233740e-05 ||r(i)||/||b|| 8.855564003216e-02
#   3 KSP unpreconditioned resid norm 3.327884814109e-05 true resid norm 3.327884814040e-05 ||r(i)||/||b|| 3.897980035314e-02
#   4 KSP unpreconditioned resid norm 2.145590930749e-05 true resid norm 2.145590930774e-05 ||r(i)||/||b|| 2.513149065984e-02
#   5 KSP unpreconditioned resid norm 9.229157650623e-06 true resid norm 9.229157650072e-06 ||r(i)||/||b|| 1.081019153997e-02
#   6 KSP unpreconditioned resid norm 5.483437592852e-06 true resid norm 5.483437593056e-06 ||r(i)||/||b|| 6.422797499615e-03
#   7 KSP unpreconditioned resid norm 3.000346191896e-06 true resid norm 3.000346191455e-06 ||r(i)||/||b|| 3.514331236460e-03
#   8 KSP unpreconditioned resid norm 1.728376208319e-06 true resid norm 1.728376208683e-06 ||r(i)||/||b|| 2.024461882375e-03
#   9 KSP unpreconditioned resid norm 9.717375106978e-07 true resid norm 9.717375105571e-07 ||r(i)||/||b|| 1.138204483441e-03
#  10 KSP unpreconditioned resid norm 5.473655654076e-07 true resid norm 5.473655657337e-07 ||r(i)||/||b|| 6.411339834380e-04
#  11 KSP unpreconditioned resid norm 3.148870140961e-07 true resid norm 3.148870146519e-07 ||r(i)||/||b|| 3.688298619334e-04
#  12 KSP unpreconditioned resid norm 1.987381154060e-07 true resid norm 1.987381171883e-07 ||r(i)||/||b|| 2.327836617985e-04
#  13 KSP unpreconditioned resid norm 9.849138044282e-08 true resid norm 9.849137948549e-08 ||r(i)||/||b|| 1.153637978289e-04
#  14 KSP unpreconditioned resid norm 6.549899428022e-08 true resid norm 6.549899510132e-08 ||r(i)||/||b|| 7.671953493129e-05
#  15 KSP unpreconditioned resid norm 3.300733182763e-08 true resid norm 3.300733115077e-08 ||r(i)||/||b|| 3.866177017362e-05
#  16 KSP unpreconditioned resid norm 2.063089173860e-08 true resid norm 2.063089220407e-08 ||r(i)||/||b|| 2.416514104782e-05
#  17 KSP unpreconditioned resid norm 1.166502708255e-08 true resid norm 1.166502646762e-08 ||r(i)||/||b|| 1.366334558526e-05
#  18 KSP unpreconditioned resid norm 6.646861540791e-09 true resid norm 6.646861913915e-09 ||r(i)||/||b|| 7.785526388599e-06
#  19 KSP unpreconditioned resid norm 3.827302632646e-09 true resid norm 3.827302223732e-09 ||r(i)||/||b|| 4.482951932194e-06
#  20 KSP unpreconditioned resid norm 2.121883595167e-09 true resid norm 2.121883884128e-09 ||r(i)||/||b|| 2.485380798845e-06
#  21 KSP unpreconditioned resid norm 1.240192484748e-09 true resid norm 1.240191825165e-09 ||r(i)||/||b|| 1.452647325429e-06
#  22 KSP unpreconditioned resid norm 7.084524050646e-10 true resid norm 7.084515570002e-10 ||r(i)||/||b|| 8.298153870960e-07
#  23 KSP unpreconditioned resid norm 4.207468707237e-10 true resid norm 4.207469179425e-10 ||r(i)||/||b|| 4.928244749159e-07
#  24 KSP unpreconditioned resid norm 2.363126372507e-10 true resid norm 2.363122140558e-10 ||r(i)||/||b|| 2.767945238382e-07
#  25 KSP unpreconditioned resid norm 1.391652370038e-10 true resid norm 1.391667857880e-10 ||r(i)||/||b|| 1.630072502184e-07
#  26 KSP unpreconditioned resid norm 8.211642451150e-11 true resid norm 8.211486651242e-11 ||r(i)||/||b|| 9.618184767618e-08
#  27 KSP unpreconditioned resid norm 4.808478675857e-11 true resid norm 4.808549760988e-11 ||r(i)||/||b|| 5.632295591502e-08
#  28 KSP unpreconditioned resid norm 2.888696166055e-11 true resid norm 2.888601682024e-11 ||r(i)||/||b|| 3.383443933816e-08
#  29 KSP unpreconditioned resid norm 1.609757788820e-11 true resid norm 1.609793280154e-11 ||r(i)||/||b|| 1.885564680769e-08
#  30 KSP unpreconditioned resid norm 9.499852749720e-12 true resid norm 9.499852749720e-12 ||r(i)||/||b|| 1.112725903271e-08
#  31 KSP unpreconditioned resid norm 6.564222311762e-12 true resid norm 6.563756363914e-12 ||r(i)||/||b|| 7.688184144853e-09
#  32 KSP unpreconditioned resid norm 4.060077248092e-12 true resid norm 4.059580340251e-12 ||r(i)||/||b|| 4.755021282975e-09
#  33 KSP unpreconditioned resid norm 2.473200887755e-12 true resid norm 2.473877297389e-12 ||r(i)||/||b|| 2.897673703836e-09
#  34 KSP unpreconditioned resid norm 1.415106605900e-12 true resid norm 1.414478681940e-12 ||r(i)||/||b|| 1.656791016118e-09
#  35 KSP unpreconditioned resid norm 8.435309490390e-13 true resid norm 8.439803855959e-13 ||r(i)||/||b|| 9.885614668421e-10
#  36 KSP unpreconditioned resid norm 4.918118234919e-13 true resid norm 4.924748051330e-13 ||r(i)||/||b|| 5.768399645939e-10
#  37 KSP unpreconditioned resid norm 2.850256635519e-13 true resid norm 2.857317821801e-13 ||r(i)||/||b|| 3.346800879928e-10
#  38 KSP unpreconditioned resid norm 1.607990221261e-13 true resid norm 1.620733285932e-13 ||r(i)||/||b|| 1.898378803400e-10
#  39 KSP unpreconditioned resid norm 9.111802225476e-14 true resid norm 9.337311246456e-14 ||r(i)||/||b|| 1.093687277536e-10
#  40 KSP unpreconditioned resid norm 5.117294772402e-14 true resid norm 5.568781127775e-14 ||r(i)||/||b|| 6.522761114062e-11
#  41 KSP unpreconditioned resid norm 2.936030475113e-14 true resid norm 3.450734839773e-14 ||r(i)||/||b|| 4.041875324485e-11
#  42 KSP unpreconditioned resid norm 1.690282428207e-14 true resid norm 2.636948007329e-14 ||r(i)||/||b|| 3.088679825504e-11
#  43 KSP unpreconditioned resid norm 9.766630052709e-15 true resid norm 2.357739802899e-14 ||r(i)||/||b|| 2.761640860102e-11
# [INFO] Time step 7/10, t = 0.7
#   0 KSP unpreconditioned resid norm 5.488844042881e-04 true resid norm 5.488844042881e-04 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 8.607816324895e-05 true resid norm 8.607816324818e-05 ||r(i)||/||b|| 1.568238459240e-01
#   2 KSP unpreconditioned resid norm 6.222116675533e-05 true resid norm 6.222116675424e-05 ||r(i)||/||b|| 1.133593271518e-01
#   3 KSP unpreconditioned resid norm 2.836274636925e-05 true resid norm 2.836274636971e-05 ||r(i)||/||b|| 5.167344189073e-02
#   4 KSP unpreconditioned resid norm 1.804123263737e-05 true resid norm 1.804123263748e-05 ||r(i)||/||b|| 3.286891100665e-02
#   5 KSP unpreconditioned resid norm 7.557788929298e-06 true resid norm 7.557788929324e-06 ||r(i)||/||b|| 1.376936358599e-02
#   6 KSP unpreconditioned resid norm 4.489259991809e-06 true resid norm 4.489259991706e-06 ||r(i)||/||b|| 8.178880574187e-03
#   7 KSP unpreconditioned resid norm 2.415182161578e-06 true resid norm 2.415182161475e-06 ||r(i)||/||b|| 4.400165394766e-03
#   8 KSP unpreconditioned resid norm 1.359891154446e-06 true resid norm 1.359891154831e-06 ||r(i)||/||b|| 2.477554735034e-03
#   9 KSP unpreconditioned resid norm 7.651823659628e-07 true resid norm 7.651823658266e-07 ||r(i)||/||b|| 1.394068331781e-03
#  10 KSP unpreconditioned resid norm 4.243778388164e-07 true resid norm 4.243778390203e-07 ||r(i)||/||b|| 7.731643233163e-04
#  11 KSP unpreconditioned resid norm 2.351370515788e-07 true resid norm 2.351370514075e-07 ||r(i)||/||b|| 4.283908407135e-04
#  12 KSP unpreconditioned resid norm 1.468881479620e-07 true resid norm 1.468881478828e-07 ||r(i)||/||b|| 2.676121724998e-04
#  13 KSP unpreconditioned resid norm 7.356605085997e-08 true resid norm 7.356605171864e-08 ||r(i)||/||b|| 1.340283147852e-04
#  14 KSP unpreconditioned resid norm 4.899183618150e-08 true resid norm 4.899183644981e-08 ||r(i)||/||b|| 8.925711145565e-05
#  15 KSP unpreconditioned resid norm 2.539561439680e-08 true resid norm 2.539561478690e-08 ||r(i)||/||b|| 4.626769241119e-05
#  16 KSP unpreconditioned resid norm 1.578456521462e-08 true resid norm 1.578456527176e-08 ||r(i)||/||b|| 2.875754010944e-05
#  17 KSP unpreconditioned resid norm 9.126789437747e-09 true resid norm 9.126790041295e-09 ||r(i)||/||b|| 1.662789099124e-05
#  18 KSP unpreconditioned resid norm 5.231877789989e-09 true resid norm 5.231877716706e-09 ||r(i)||/||b|| 9.531838900563e-06
#  19 KSP unpreconditioned resid norm 2.969286211526e-09 true resid norm 2.969286159042e-09 ||r(i)||/||b|| 5.409674852928e-06
#  20 KSP unpreconditioned resid norm 1.652728430868e-09 true resid norm 1.652728202544e-09 ||r(i)||/||b|| 3.011067885390e-06
#  21 KSP unpreconditioned resid norm 9.641239599323e-10 true resid norm 9.641239304645e-10 ||r(i)||/||b|| 1.756515439193e-06
#  22 KSP unpreconditioned resid norm 5.429433000040e-10 true resid norm 5.429433553864e-10 ||r(i)||/||b|| 9.891761382628e-07
#  23 KSP unpreconditioned resid norm 3.238502468226e-10 true resid norm 3.238503984639e-10 ||r(i)||/||b|| 5.900156680237e-07
#  24 KSP unpreconditioned resid norm 1.811225827554e-10 true resid norm 1.811224866000e-10 ||r(i)||/||b|| 3.299829348128e-07
#  25 KSP unpreconditioned resid norm 1.056449985744e-10 true resid norm 1.056449472460e-10 ||r(i)||/||b|| 1.924721242226e-07
#  26 KSP unpreconditioned resid norm 6.217200742028e-11 true resid norm 6.217167161065e-11 ||r(i)||/||b|| 1.132691530766e-07
#  27 KSP unpreconditioned resid norm 3.663618467426e-11 true resid norm 3.663574039293e-11 ||r(i)||/||b|| 6.674582135458e-08
#  28 KSP unpreconditioned resid norm 2.221241919864e-11 true resid norm 2.221262154427e-11 ||r(i)||/||b|| 4.046866948803e-08
#  29 KSP unpreconditioned resid norm 1.253555251151e-11 true resid norm 1.253596943610e-11 ||r(i)||/||b|| 2.283899731558e-08
#  30 KSP unpreconditioned resid norm 7.442641899906e-12 true resid norm 7.442641899906e-12 ||r(i)||/||b|| 1.355957983459e-08
#  31 KSP unpreconditioned resid norm 5.171567019451e-12 true resid norm 5.171219441052e-12 ||r(i)||/||b|| 9.421326969126e-09
#  32 KSP unpreconditioned resid norm 3.191277135282e-12 true resid norm 3.191652013250e-12 ||r(i)||/||b|| 5.814798140220e-09
#  33 KSP unpreconditioned resid norm 1.928870679614e-12 true resid norm 1.928199465157e-12 ||r(i)||/||b|| 3.512942707231e-09
#  34 KSP unpreconditioned resid norm 1.086484912528e-12 true resid norm 1.087409694530e-12 ||r(i)||/||b|| 1.981126965961e-09
#  35 KSP unpreconditioned resid norm 6.402895126603e-13 true resid norm 6.396030299247e-13 ||r(i)||/||b|| 1.165278198702e-09
#  36 KSP unpreconditioned resid norm 3.728015729316e-13 true resid norm 3.730504819727e-13 ||r(i)||/||b|| 6.796521800552e-10
#  37 KSP unpreconditioned resid norm 2.171169794294e-13 true resid norm 2.179653750967e-13 ||r(i)||/||b|| 3.971061545816e-10
#  38 KSP unpreconditioned resid norm 1.238947605907e-13 true resid norm 1.248741581802e-13 ||r(i)||/||b|| 2.275053858420e-10
#  39 KSP unpreconditioned resid norm 6.994273271463e-14 true resid norm 7.200148433528e-14 ||r(i)||/||b|| 1.311778650892e-10
#  40 KSP unpreconditioned resid norm 3.933428258300e-14 true resid norm 4.260466481868e-14 ||r(i)||/||b|| 7.762046887438e-11
#  41 KSP unpreconditioned resid norm 2.250147389528e-14 true resid norm 2.977485271717e-14 ||r(i)||/||b|| 5.424612629646e-11
#  42 KSP unpreconditioned resid norm 1.302471904836e-14 true resid norm 2.122437240250e-14 ||r(i)||/||b|| 3.866820087560e-11
#  43 KSP unpreconditioned resid norm 7.570124859973e-15 true resid norm 1.840675168753e-14 ||r(i)||/||b|| 3.353484184235e-11
# [INFO] Time step 8/10, t = 0.8
#   0 KSP unpreconditioned resid norm 3.569412650741e-04 true resid norm 3.569412650741e-04 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 7.490193724232e-05 true resid norm 7.490193724293e-05 ||r(i)||/||b|| 2.098438722891e-01
#   2 KSP unpreconditioned resid norm 5.090175757918e-05 true resid norm 5.090175757886e-05 ||r(i)||/||b|| 1.426054159591e-01
#   3 KSP unpreconditioned resid norm 2.468598756565e-05 true resid norm 2.468598756576e-05 ||r(i)||/||b|| 6.915980297384e-02
#   4 KSP unpreconditioned resid norm 1.556149506618e-05 true resid norm 1.556149506595e-05 ||r(i)||/||b|| 4.359679473516e-02
#   5 KSP unpreconditioned resid norm 6.443818016490e-06 true resid norm 6.443818016800e-06 ||r(i)||/||b|| 1.805288053614e-02
#   6 KSP unpreconditioned resid norm 3.828116219660e-06 true resid norm 3.828116219405e-06 ||r(i)||/||b|| 1.072477909947e-02
#   7 KSP unpreconditioned resid norm 2.031494268825e-06 true resid norm 2.031494268932e-06 ||r(i)||/||b|| 5.691396506116e-03
#   8 KSP unpreconditioned resid norm 1.125975095893e-06 true resid norm 1.125975095805e-06 ||r(i)||/||b|| 3.154510856489e-03
#   9 KSP unpreconditioned resid norm 6.268491391446e-07 true resid norm 6.268491392120e-07 ||r(i)||/||b|| 1.756168872999e-03
#  10 KSP unpreconditioned resid norm 3.425775362198e-07 true resid norm 3.425775364761e-07 ||r(i)||/||b|| 9.597588454924e-04
#  11 KSP unpreconditioned resid norm 1.842339368825e-07 true resid norm 1.842339368145e-07 ||r(i)||/||b|| 5.161463659187e-04
#  12 KSP unpreconditioned resid norm 1.131688526652e-07 true resid norm 1.131688526278e-07 ||r(i)||/||b|| 3.170517496885e-04
#  13 KSP unpreconditioned resid norm 5.668612646322e-08 true resid norm 5.668612643563e-08 ||r(i)||/||b|| 1.588107960111e-04
#  14 KSP unpreconditioned resid norm 3.751034343259e-08 true resid norm 3.751034402574e-08 ||r(i)||/||b|| 1.050882811713e-04
#  15 KSP unpreconditioned resid norm 1.977866676240e-08 true resid norm 1.977866725427e-08 ||r(i)||/||b|| 5.541154579076e-05
#  16 KSP unpreconditioned resid norm 1.226653234612e-08 true resid norm 1.226653251871e-08 ||r(i)||/||b|| 3.436568903335e-05
#  17 KSP unpreconditioned resid norm 7.234842458255e-09 true resid norm 7.234842461860e-09 ||r(i)||/||b|| 2.026899988814e-05
#  18 KSP unpreconditioned resid norm 4.190420683577e-09 true resid norm 4.190420609256e-09 ||r(i)||/||b|| 1.173980432995e-05
#  19 KSP unpreconditioned resid norm 2.364808077285e-09 true resid norm 2.364808605739e-09 ||r(i)||/||b|| 6.625203743949e-06
#  20 KSP unpreconditioned resid norm 1.317897809314e-09 true resid norm 1.317897628702e-09 ||r(i)||/||b|| 3.692197449986e-06
#  21 KSP unpreconditioned resid norm 7.666692817547e-10 true resid norm 7.666696558061e-10 ||r(i)||/||b|| 2.147887428053e-06
#  22 KSP unpreconditioned resid norm 4.285037184099e-10 true resid norm 4.285035902245e-10 ||r(i)||/||b|| 1.200487677253e-06
#  23 KSP unpreconditioned resid norm 2.548834760959e-10 true resid norm 2.548838339785e-10 ||r(i)||/||b|| 7.140778019196e-07
#  24 KSP unpreconditioned resid norm 1.426689168470e-10 true resid norm 1.426686785496e-10 ||r(i)||/||b|| 3.996979125401e-07
#  25 KSP unpreconditioned resid norm 8.277805072023e-11 true resid norm 8.277806256667e-11 ||r(i)||/||b|| 2.319094782988e-07
#  26 KSP unpreconditioned resid norm 4.840846543745e-11 true resid norm 4.840882957579e-11 ||r(i)||/||b|| 1.356212752979e-07
#  27 KSP unpreconditioned resid norm 2.832764110616e-11 true resid norm 2.832710636952e-11 ||r(i)||/||b|| 7.936069359656e-08
#  28 KSP unpreconditioned resid norm 1.728697486491e-11 true resid norm 1.728701083000e-11 ||r(i)||/||b|| 4.843096756104e-08
#  29 KSP unpreconditioned resid norm 9.854087895908e-12 true resid norm 9.853512268589e-12 ||r(i)||/||b|| 2.760541644447e-08
#  30 KSP unpreconditioned resid norm 5.908997878015e-12 true resid norm 5.908997878015e-12 ||r(i)||/||b|| 1.655453839664e-08
#  31 KSP unpreconditioned resid norm 4.156296067042e-12 true resid norm 4.156622325608e-12 ||r(i)||/||b|| 1.164511568800e-08
#  32 KSP unpreconditioned resid norm 2.555230835567e-12 true resid norm 2.554840751137e-12 ||r(i)||/||b|| 7.157594263039e-09
#  33 KSP unpreconditioned resid norm 1.542621481367e-12 true resid norm 1.542721958517e-12 ||r(i)||/||b|| 4.322061104919e-09
#  34 KSP unpreconditioned resid norm 8.659182536237e-13 true resid norm 8.663086697363e-13 ||r(i)||/||b|| 2.427034233647e-09
#  35 KSP unpreconditioned resid norm 5.033738626704e-13 true resid norm 5.032113468117e-13 ||r(i)||/||b|| 1.409787536633e-09
#  36 KSP unpreconditioned resid norm 2.915334638235e-13 true resid norm 2.917186561502e-13 ||r(i)||/||b|| 8.172735536463e-10
#  37 KSP unpreconditioned resid norm 1.688731209798e-13 true resid norm 1.691700820996e-13 ||r(i)||/||b|| 4.739437511224e-10
#  38 KSP unpreconditioned resid norm 9.653789643314e-14 true resid norm 9.682595621336e-14 ||r(i)||/||b|| 2.712657954895e-10
#  39 KSP unpreconditioned resid norm 5.491450664763e-14 true resid norm 5.560966433271e-14 ||r(i)||/||b|| 1.557949998333e-10
#  40 KSP unpreconditioned resid norm 3.154361281383e-14 true resid norm 3.277795180175e-14 ||r(i)||/||b|| 9.183009925999e-11
#  41 KSP unpreconditioned resid norm 1.822595981792e-14 true resid norm 2.105719798766e-14 ||r(i)||/||b|| 5.899345368009e-11
#  42 KSP unpreconditioned resid norm 1.091128361963e-14 true resid norm 1.512470840595e-14 ||r(i)||/||b|| 4.237310136391e-11
#  43 KSP unpreconditioned resid norm 6.379812340737e-15 true resid norm 1.186973491969e-14 ||r(i)||/||b|| 3.325402827052e-11
# [INFO] Time step 9/10, t = 0.9
#   0 KSP unpreconditioned resid norm 2.358609222051e-04 true resid norm 2.358609222051e-04 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 6.579984524278e-05 true resid norm 6.579984524290e-05 ||r(i)||/||b|| 2.789773084398e-01
#   2 KSP unpreconditioned resid norm 4.196259069651e-05 true resid norm 4.196259069644e-05 ||r(i)||/||b|| 1.779124337518e-01
#   3 KSP unpreconditioned resid norm 2.168515949641e-05 true resid norm 2.168515949650e-05 ||r(i)||/||b|| 9.194045072736e-02
#   4 KSP unpreconditioned resid norm 1.358546804151e-05 true resid norm 1.358546804155e-05 ||r(i)||/||b|| 5.759948665739e-02
#   5 KSP unpreconditioned resid norm 5.622238721348e-06 true resid norm 5.622238721404e-06 ||r(i)||/||b|| 2.383709293105e-02
#   6 KSP unpreconditioned resid norm 3.349389809331e-06 true resid norm 3.349389809414e-06 ||r(i)||/||b|| 1.420069835266e-02
#   7 KSP unpreconditioned resid norm 1.759182464908e-06 true resid norm 1.759182464969e-06 ||r(i)||/||b|| 7.458558410280e-03
#   8 KSP unpreconditioned resid norm 9.666277150251e-07 true resid norm 9.666277150918e-07 ||r(i)||/||b|| 4.098295326139e-03
#   9 KSP unpreconditioned resid norm 5.321338955655e-07 true resid norm 5.321338954729e-07 ||r(i)||/||b|| 2.256134210356e-03
#  10 KSP unpreconditioned resid norm 2.869789601993e-07 true resid norm 2.869789601940e-07 ||r(i)||/||b|| 1.216729577376e-03
#  11 KSP unpreconditioned resid norm 1.513268784378e-07 true resid norm 1.513268783043e-07 ||r(i)||/||b|| 6.415936853360e-04
#  12 KSP unpreconditioned resid norm 9.137681868915e-08 true resid norm 9.137681881537e-08 ||r(i)||/||b|| 3.874182207086e-04
#  13 KSP unpreconditioned resid norm 4.532261835994e-08 true resid norm 4.532261830389e-08 ||r(i)||/||b|| 1.921582340990e-04
#  14 KSP unpreconditioned resid norm 2.961976648374e-08 true resid norm 2.961976631228e-08 ||r(i)||/||b|| 1.255814911405e-04
#  15 KSP unpreconditioned resid norm 1.564019562752e-08 true resid norm 1.564019546664e-08 ||r(i)||/||b|| 6.631109265757e-05
#  16 KSP unpreconditioned resid norm 9.634579113379e-09 true resid norm 9.634578990545e-09 ||r(i)||/||b|| 4.084855982276e-05
#  17 KSP unpreconditioned resid norm 5.768338952959e-09 true resid norm 5.768338899609e-09 ||r(i)||/||b|| 2.445652652284e-05
#  18 KSP unpreconditioned resid norm 3.381105860270e-09 true resid norm 3.381105817568e-09 ||r(i)||/||b|| 1.433516746207e-05
#  19 KSP unpreconditioned resid norm 1.912782365318e-09 true resid norm 1.912782531832e-09 ||r(i)||/||b|| 8.109789930223e-06
#  20 KSP unpreconditioned resid norm 1.069401629042e-09 true resid norm 1.069401310394e-09 ||r(i)||/||b|| 4.534033448171e-06
#  21 KSP unpreconditioned resid norm 6.212357707424e-10 true resid norm 6.212357058105e-10 ||r(i)||/||b|| 2.633906880388e-06
#  22 KSP unpreconditioned resid norm 3.465807236136e-10 true resid norm 3.465807786398e-10 ||r(i)||/||b|| 1.469428574262e-06
#  23 KSP unpreconditioned resid norm 2.048929100658e-10 true resid norm 2.048929777588e-10 ||r(i)||/||b|| 8.687025211436e-07
#  24 KSP unpreconditioned resid norm 1.146599086944e-10 true resid norm 1.146597959176e-10 ||r(i)||/||b|| 4.861330772629e-07
#  25 KSP unpreconditioned resid norm 6.640229656606e-11 true resid norm 6.640224604874e-11 ||r(i)||/||b|| 2.815313593619e-07
#  26 KSP unpreconditioned resid norm 3.861562975124e-11 true resid norm 3.861587683589e-11 ||r(i)||/||b|| 1.637230808515e-07
#  27 KSP unpreconditioned resid norm 2.232793792363e-11 true resid norm 2.232746917780e-11 ||r(i)||/||b|| 9.466370676863e-08
#  28 KSP unpreconditioned resid norm 1.363582400229e-11 true resid norm 1.363607132657e-11 ||r(i)||/||b|| 5.781403379196e-08
#  29 KSP unpreconditioned resid norm 7.788418981099e-12 true resid norm 7.788091952020e-12 ||r(i)||/||b|| 3.301984864305e-08
#  30 KSP unpreconditioned resid norm 4.719463281194e-12 true resid norm 4.719463281194e-12 ||r(i)||/||b|| 2.000951763044e-08
#  31 KSP unpreconditioned resid norm 3.363883459400e-12 true resid norm 3.364202131739e-12 ||r(i)||/||b|| 1.426349943979e-08
#  32 KSP unpreconditioned resid norm 2.063825209098e-12 true resid norm 2.063769831012e-12 ||r(i)||/||b|| 8.749943872508e-09
#  33 KSP unpreconditioned resid norm 1.247198947022e-12 true resid norm 1.246955964070e-12 ||r(i)||/||b|| 5.286827306586e-09
#  34 KSP unpreconditioned resid norm 7.039743014098e-13 true resid norm 7.039270790097e-13 ||r(i)||/||b|| 2.984500664327e-09
#  35 KSP unpreconditioned resid norm 4.082235232814e-13 true resid norm 4.082653041925e-13 ||r(i)||/||b|| 1.730957805030e-09
#  36 KSP unpreconditioned resid norm 2.370492602116e-13 true resid norm 2.372947118813e-13 ||r(i)||/||b|| 1.006078962394e-09
#  37 KSP unpreconditioned resid norm 1.373504742644e-13 true resid norm 1.374386661155e-13 ||r(i)||/||b|| 5.827106280709e-10
#  38 KSP unpreconditioned resid norm 7.889540026988e-14 true resid norm 7.921782145936e-14 ||r(i)||/||b|| 3.358666654856e-10
#  39 KSP unpreconditioned resid norm 4.448550573632e-14 true resid norm 4.498539136411e-14 ||r(i)||/||b|| 1.907284638063e-10
#  40 KSP unpreconditioned resid norm 2.539148394380e-14 true resid norm 2.676088649072e-14 ||r(i)||/||b|| 1.134604505084e-10
#  41 KSP unpreconditioned resid norm 1.442154470046e-14 true resid norm 1.652942666436e-14 ||r(i)||/||b|| 7.008124325905e-11
#  42 KSP unpreconditioned resid norm 8.521326172666e-15 true resid norm 1.187999001448e-14 ||r(i)||/||b|| 5.036862360840e-11
# [INFO] Time step 10/10, t = 1.0
#   0 KSP unpreconditioned resid norm 1.594856480592e-04 true resid norm 1.594856480592e-04 ||r(i)||/||b|| 1.000000000000e+00
#   1 KSP unpreconditioned resid norm 5.752553731750e-05 true resid norm 5.752553731737e-05 ||r(i)||/||b|| 3.606941315247e-01
#   2 KSP unpreconditioned resid norm 3.519947528756e-05 true resid norm 3.519947528763e-05 ||r(i)||/||b|| 2.207062247668e-01
#   3 KSP unpreconditioned resid norm 1.913244618056e-05 true resid norm 1.913244618039e-05 ||r(i)||/||b|| 1.199634350376e-01
#   4 KSP unpreconditioned resid norm 1.189704123987e-05 true resid norm 1.189704124001e-05 ||r(i)||/||b|| 7.459631248820e-02
#   5 KSP unpreconditioned resid norm 4.947472399099e-06 true resid norm 4.947472399133e-06 ||r(i)||/||b|| 3.102142706469e-02
#   6 KSP unpreconditioned resid norm 2.968023800885e-06 true resid norm 2.968023801006e-06 ||r(i)||/||b|| 1.860997423357e-02
#   7 KSP unpreconditioned resid norm 1.546296842222e-06 true resid norm 1.546296842072e-06 ||r(i)||/||b|| 9.695523458625e-03
#   8 KSP unpreconditioned resid norm 8.472921805499e-07 true resid norm 8.472921805336e-07 ||r(i)||/||b|| 5.312654717490e-03
#   9 KSP unpreconditioned resid norm 4.631182027644e-07 true resid norm 4.631182027534e-07 ||r(i)||/||b|| 2.903823688144e-03
#  10 KSP unpreconditioned resid norm 2.473045685143e-07 true resid norm 2.473045685148e-07 ||r(i)||/||b|| 1.550638389875e-03
#  11 KSP unpreconditioned resid norm 1.289301522304e-07 true resid norm 1.289301522204e-07 ||r(i)||/||b|| 8.084122539513e-04
#  12 KSP unpreconditioned resid norm 7.681303224743e-08 true resid norm 7.681303227172e-08 ||r(i)||/||b|| 4.816297466666e-04
#  13 KSP unpreconditioned resid norm 3.763640726859e-08 true resid norm 3.763640716721e-08 ||r(i)||/||b|| 2.359861694467e-04
#  14 KSP unpreconditioned resid norm 2.425685795331e-08 true resid norm 2.425685796497e-08 ||r(i)||/||b|| 1.520942997703e-04
#  15 KSP unpreconditioned resid norm 1.268698183881e-08 true resid norm 1.268698162605e-08 ||r(i)||/||b|| 7.954936246891e-05
#  16 KSP unpreconditioned resid norm 7.713622203604e-09 true resid norm 7.713622314214e-09 ||r(i)||/||b|| 4.836562040586e-05
#  17 KSP unpreconditioned resid norm 4.640731120550e-09 true resid norm 4.640730910597e-09 ||r(i)||/||b|| 2.909810987428e-05
#  18 KSP unpreconditioned resid norm 2.742442527104e-09 true resid norm 2.742442610276e-09 ||r(i)||/||b|| 1.719554482582e-05
#  19 KSP unpreconditioned resid norm 1.560695943362e-09 true resid norm 1.560695802605e-09 ||r(i)||/||b|| 9.785807197054e-06
#  20 KSP unpreconditioned resid norm 8.764225233795e-10 true resid norm 8.764226049613e-10 ||r(i)||/||b|| 5.495307042524e-06
#  21 KSP unpreconditioned resid norm 5.098833565812e-10 true resid norm 5.098832682000e-10 ||r(i)||/||b|| 3.197047975193e-06
#  22 KSP unpreconditioned resid norm 2.851044261416e-10 true resid norm 2.851044210771e-10 ||r(i)||/||b|| 1.787649387557e-06
#  23 KSP unpreconditioned resid norm 1.677220942934e-10 true resid norm 1.677220991793e-10 ||r(i)||/||b|| 1.051643838931e-06
#  24 KSP unpreconditioned resid norm 9.381037761030e-11 true resid norm 9.381037792096e-11 ||r(i)||/||b|| 5.882057668671e-07
#  25 KSP unpreconditioned resid norm 5.430289293693e-11 true resid norm 5.430289350425e-11 ||r(i)||/||b|| 3.404876499238e-07
#  26 KSP unpreconditioned resid norm 3.142601957396e-11 true resid norm 3.142606752438e-11 ||r(i)||/||b|| 1.970463669102e-07
#  27 KSP unpreconditioned resid norm 1.796836394706e-11 true resid norm 1.796823497707e-11 ||r(i)||/||b|| 1.126636483955e-07
#  28 KSP unpreconditioned resid norm 1.093362024397e-11 true resid norm 1.093355181619e-11 ||r(i)||/||b|| 6.855508285069e-08
#  29 KSP unpreconditioned resid norm 6.205845340465e-12 true resid norm 6.205884200546e-12 ||r(i)||/||b|| 3.891186621534e-08
#  30 KSP unpreconditioned resid norm 3.782127884400e-12 true resid norm 3.782127884400e-12 ||r(i)||/||b|| 2.371453438241e-08
#  31 KSP unpreconditioned resid norm 2.720606021639e-12 true resid norm 2.720422348787e-12 ||r(i)||/||b|| 1.705747433636e-08
#  32 KSP unpreconditioned resid norm 1.669286609466e-12 true resid norm 1.669518966342e-12 ||r(i)||/||b|| 1.046814548305e-08
#  33 KSP unpreconditioned resid norm 1.011088754645e-12 true resid norm 1.010988507404e-12 ||r(i)||/||b|| 6.339056333326e-09
#  34 KSP unpreconditioned resid norm 5.753574991787e-13 true resid norm 5.752593302896e-13 ||r(i)||/||b|| 3.606966126984e-09
#  35 KSP unpreconditioned resid norm 3.338369764257e-13 true resid norm 3.340304324761e-13 ||r(i)||/||b|| 2.094423144282e-09
#  36 KSP unpreconditioned resid norm 1.927357467204e-13 true resid norm 1.926491507989e-13 ||r(i)||/||b|| 1.207940357915e-09
#  37 KSP unpreconditioned resid norm 1.111480044493e-13 true resid norm 1.111496746786e-13 ||r(i)||/||b|| 6.969258740907e-10
#  38 KSP unpreconditioned resid norm 6.326495087467e-14 true resid norm 6.330448783528e-14 ||r(i)||/||b|| 3.969290566621e-10
#  39 KSP unpreconditioned resid norm 3.542075898617e-14 true resid norm 3.568897966634e-14 ||r(i)||/||b|| 2.237754939121e-10
#  40 KSP unpreconditioned resid norm 2.009033443728e-14 true resid norm 2.049989351964e-14 ||r(i)||/||b|| 1.285375440932e-10
#  41 KSP unpreconditioned resid norm 1.132483316503e-14 true resid norm 1.207141831098e-14 ||r(i)||/||b|| 7.568968404292e-11
#  42 KSP unpreconditioned resid norm 6.688566511310e-15 true resid norm 8.565479875528e-15 ||r(i)||/||b|| 5.370690077611e-11
